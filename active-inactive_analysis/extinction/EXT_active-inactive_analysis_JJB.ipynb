# %%
"""
@Josh Boquiren
Ver. I
OTIS Lab MUSC
4.21.2023

README: 
- Revised version of "Population - PFC Self-Admin 7.2.ipynb"
- Better version for handling inactive data

POPULATION:
- Extinction, active and inactive analysis
"""

# %% [markdown]
# ## Population Analysis

# %% [markdown]
# Import libraries

# %%
#data manipulation
import numpy as np
import pandas as pd

#plotting
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

#directory and file manager
import os

#statistics
import scipy.stats as stats
import scipy.io as sio
from sklearn.metrics import roc_auc_score as auROC
import statsmodels.api as sm
from statsmodels.distributions.empirical_distribution import ECDF

# import subprocess
# import time
# import pickle
# import math
# from sklearn.decomposition import PCA
# from sklearn.preprocessing import StandardScaler
# from sklearn.svm import SVC, SVR, LinearSVC
# from sklearn.metrics import accuracy_score, silhouette_score, adjusted_rand_score, silhouette_sapltes
# from sklearn.cluster import AgglomerativeClustering, SpectralClustering, KMeans
# from sklearn.model_selection import KFold, LeaveOneOut, train_test_split
# from sklearn.model_selection import GridSearchCV
# from sklearn.kernel_ridge import KernelRidge
# from sklearn import linear_model
# from sklearn.manifold import TSNE

# from scipy import interpolate

# import statsmodels.formula.api as smf
# from patsy import (ModelDesc, EvalEnvironment, Term, EvalFactor, LookupFactor, dmatrices, INTERCEPT)

# import matplotlib.cm as cm
# import matplotlib.colors as colors
# import matplotlib.colorbar as colorbar
# import matplotlib.patches as mpatches
# import sys
# import re
# import random
# from IPython.core.display import display, HTML
# display(HTML("<style>.container { width:100% !important; }</style>"))

# np.set_printoptions(suppress=True)

# %%
#initialize directories

population = 'EXTINCTION'

basedir = r'C:\Users\jboqu\Dropbox\2P Imaging Projects\Beth\Josh\Project Datasets\PFC Self-Admin Analysis\PFC Self Admin Data'

earlybasedir = r'C:\Users\jboqu\Dropbox\2P Imaging Projects\Beth\Josh\Project Datasets\PFC Self-Admin Analysis\PFC Self Admin Data/EarlyExt'
middlebasedir = r'C:\Users\jboqu\Dropbox\2P Imaging Projects\Beth\Josh\Project Datasets\PFC Self-Admin Analysis\PFC Self Admin Data/LastExt'
latebasedir = r'C:\Users\jboqu\Dropbox\2P Imaging Projects\Beth\Josh\Project Datasets\PFC Self-Admin Analysis\PFC Self Admin Data/LastExt'

models = r'C:\Users\jboqu\Dropbox\2P Imaging Projects\Beth\Josh\Repositories\PFC_Self-Admin_Analysis\PFC_Self-Admin_Analysis\active-inactive_analysis\universal_models'
results = r'C:\Users\jboqu\Dropbox\2P Imaging Projects\Beth\Josh\Repositories\PFC_Self-Admin_Analysis\PFC_Self-Admin_Analysis\active-inactive_analysis\extinction\results'

#cluster list files
early_newlabels = np.load(os.path.join(earlybasedir, 'cluster_list_per_session_Extinction.npy')) #put clustering files in a folder to loop through
middle_newlabels = np.load(os.path.join(middlebasedir, 'cluster_list_per_session_Extinction.npy'))

#for later plot titles
plot_titles = ['EARLY', 'LATE', '(blank)']
population_title = "EXT"

#animals of interest
early_animals_of_interest = [
    'CTL1',
    'ER-L1','ER-L2',
    'LCDD-PGa1','LCDD-PGa4','LCDD-PGa6',
    'LCDD-PGa-T1','LCDD-PGa-T3','LCDD-PGa-T4',
    'PGa-T1','PGa-T2','PGa-T3'
    ]  
middle_animals_of_interest = [ #really late animals, but coded as middle
    #'ER-L1', #130 #NOT USED
    'LCDD-PGa1', #18
    'LCDD-PGa5', #215
    'LCDD-PGa-T2', #146
    'LCDD-PGa-T3', #106
    #'LCDD-PGa-T4', #117 #NOT USED
    'PGa-T1',#150
    'PGa-T2' #148

    #want 783

    #'CTL1', #doesn't work
    #'ER-L2' doesn't work
    #'LCDD-PGa-T5' #doesn't work
    ]  
late_animals_of_interest = []


### EARLY EXT MICE WITH > 2 ACTIVE PRESSES:
# 'CTL1','ER-L1','ER-L2','LCDD-PGa1','LCDD-PGa4','LCDD-PGa6','LCDD-PGa-T1','LCDD-PGa-T3','LCDD-PGa-T4','PGa-T1','PGa-T2','PGa-T3'

# %%
#frame rate variables
frameaveraging = 4
timebetweenframes = 33.3333
framerate = 30
framerate = timebetweenframes/frameaveraging #raw frame rate
averagedframerate = timebetweenframes/frameaveraging #averaged frame rate
print('Frame rate:', framerate)
print('Averaged frame rate:', averagedframerate)

#window size variables
pre_window_size = int(10*framerate) #How many frames per trial before origin to be plotted?
window_size =  int((pre_window_size*2)+(3*framerate)) #How many frames do you want to plot around the origin?
post_window_size = window_size - pre_window_size
baselinefirstframe = 0
baselinelastframe = int(1*framerate)
infusionframe = int(pre_window_size+(3*framerate))
print('Prewindow size:', pre_window_size)
print('Window size:', window_size)
print('Postwindow size:', post_window_size)

#set cell tracking
tracking = 'No' ### 'Yes' or 'No'
sorting = 'Yes' ### 'Yes' or 'No'
sorttoearly = 'No' ###'Yes' or 'No'; This is for sorting, but align to early data. 'Sorting' must also be Yes
csv_id_for_tracking = 'CUE-DRUG-TMT'

#tracking
if tracking == 'Yes':
    population_active_tracked_early = np.nan*np.ones((1,window_size))
    population_active_tracked_middle = np.nan*np.ones((1,window_size))
    population_active_tracked_late = np.nan*np.ones((1,window_size))
    print ('Cell Tracking')
else:
    print ('No Cell Tracking')
# Out:
# Frame rate: 8.333325
# Averaged frame rate: 8.333325
# Prewindow size: 83
# Window size: 190
# Postwindow size: 107
# No Cell Tracking

# %%
#method for fixing dropped frames
def fix_any_dropped_frames(frame_timestamps):
    first_frame = np.array([0])
    last_frame = np.array([int(np.max(frame_timestamps)+(500*timebetweenframes))])
    frame_index_temp = np.concatenate((first_frame,frame_timestamps, last_frame)) ###adds frame to timepoint '0' and an extra 500 frames at end
    frames_missed = [] ###creates empty list for us to add timestamps for missed frames
    for i in range(len(frame_index_temp)-1): ###iterates through each collected frame
            numframes_missed = int(np.round((frame_index_temp[i+1]-frame_index_temp[i])\
                /timebetweenframes)-1) ### number of missed frames per frame interval
            if numframes_missed > 0: 
                for j in range(numframes_missed):
                    frame_missed = np.array([frame_index_temp[i] + (int(timebetweenframes * (j+1)))])
                    frames_missed = np.concatenate((frames_missed, frame_missed))
    corrected_frame_index = np.array(sorted(np.concatenate((frame_index_temp, frames_missed))))
    return corrected_frame_index

#method for fixing assumed frames
def fix_assumed_frames(frames):
    dropped_frames = []
    diff_frames = np.diff(frames)
    inter_frame_interval = 33
    frame_drop_idx = np.where(diff_frames>1.5*inter_frame_interval)[0]
    for idx in frame_drop_idx:
        numframesdropped = int(np.round((frames[idx+1]-frames[idx])/(inter_frame_interval+0.0))-1)
        temp = [frames[idx]+a*inter_frame_interval for a in range(1,numframesdropped+1)]
        dropped_frames.extend(temp)
    corrected_frames = np.sort(np.concatenate((frames, np.array(dropped_frames))))
    return corrected_frames

#generate behavior data
try:
    assumed_frames = np.load(os.path.join(models, 'assumed_frames.npy'))
    assumed_frame_timestamps = np.load(os.path.join(models, 'assumed_frame_timestamps.npy'))
    print("Loaded behavior data.")
except:
    #load in data
    behaviordata_noframes = sio.loadmat(r"C:\Users\jboqu\Dropbox\2P Imaging Projects\Beth\Josh\Project Datasets\PFC Self-Admin Analysis\PFC Self Admin Data\Spreadsheets\matfile_noframes_3.mat")
    eventlog_noframes = np.squeeze(behaviordata_noframes['eventlog'])

    #parse desired data
    max_of_eventlog_noframes = max(eventlog_noframes[:,1]) #all rows, second column
    length_of_eventlog_noframes = len(eventlog_noframes[:,1])
    x = np.vstack((eventlog_noframes, eventlog_noframes, eventlog_noframes))
    x[length_of_eventlog_noframes:,1]= x[length_of_eventlog_noframes:,1]+max_of_eventlog_noframes
    x[length_of_eventlog_noframes*2:,1]= x[length_of_eventlog_noframes*2:,1]+(2*max_of_eventlog_noframes)
    eventlog_noframes = x

    assumed_frames = fix_any_dropped_frames(eventlog_noframes[eventlog_noframes[:,0]==9,1]) ###Fixes issue for finding behavior IF YOU DON"T HAVE FRAME INFO
    assumed_frame_timestamps = fix_assumed_frames(eventlog_noframes[eventlog_noframes[:,0]==9,1]) ###Fixes issue for finding behavior IF YOU DON"T HAVE FRAME INFO

    np.save(os.path.join(models, 'assumed_frames'), assumed_frames)
    np.save(os.path.join(models, 'assumed_frame_timestamps'), assumed_frame_timestamps)
    print("Behavior data processed and loaded.")
# Out:
# Loaded behavior data.

# %%
#various methods

def fit_regression(x, y):
    lm = sm.OLS(y, sm.add_constant(x)).fit()
    x_range = sm.add_constant(np.array([x.min(), x.max()]))
    x_range_pred = lm.predict(x_range)
    return lm.pvalues[1], lm.params[1], x_range[:,1], x_range_pred, lm.rsquared

def CDFplot(x, ax, color=None, label='', linetype='-'):
    x = np.array(x)
    ix=np.argsort(x)
    ax.plot(x[ix], ECDF(x)(x)[ix], linetype, color=color, label=label)
    return ax

def fit_regression_and_plot(x, y, ax, plot_label='', color='k', markersize=3):
    #linetype is a string like 'bo'
    pvalue, slope, temp, temppred, R2 = fit_regression(x, y)    
    ax.scatter(x, y, color=color, label='%s p=%.3f\nR$^2$=%.3f'% (plot_label, pvalue, R2), s=markersize)
    ax.plot(temp, temppred, color=color)
    return ax, slope, pvalue, R2


def ismembertol(x, y, tol=1E-6):
    # Are elements of x in y within tolerance of tol?
    # x and y must be 1d numpy arrays
    sortx = np.sort(x)
    orderofx = np.argsort(x)
    sorty = np.sort(y)
    current_y_idx = 0
    result = np.nan*np.zeros(x.shape)
    for i, elt in enumerate(sortx):
        temp = sorty[current_y_idx:]
        if np.any(np.abs(temp-elt)<=tol):
            result[orderofx[i]]=1
        else:
            result[orderofx[i]]=0
        temp = np.argwhere(sorty>elt)
        if temp.size>0:
            current_y_idx = temp[0][0]
    return result

def mkdir_p(path):
    #makes a new directory if it doesn't exist
    try:
        os.makedirs(path)
    except OSError as exc: # Python >2.5
        if exc.errno == errno.EEXIST and os.path.isdir(path):
            pass
        else:
            raise 
            
def framenumberforevent(event, frame_timestamps):
    framenumber = np.nan*np.zeros(event.shape)
    for ie, e in enumerate(event):
        #print('     e:', e)
        if np.isnan(e):
            framenumber[ie] = np.nan
        else:
            temp = np.nonzero(frame_timestamps<=e)[0]
            if temp.shape[0]>0:
                framenumber[ie] = np.nonzero(frame_timestamps<=e)[0][-1]
            else:
                framenumber[ie] = 0
    return framenumber

def calculate_num_licks_for_each_frame(framenumberforlicks, numframes):
    numlicksperframe = np.nan*np.ones((numframes,))
    for i in range(numframes):
        numlicksperframe[i] = np.sum(framenumberforlicks==i)
    return numlicksperframe

def calculate_auROC(x,y,offset_to_zero=True):
    U, p = stats.mannwhitneyu(x,y)
    labels = np.concatenate((np.ones(x.shape), np.zeros(y.shape)))
    data = np.concatenate((x,y))
    A = auROC(labels, data)
    if offset_to_zero:
        return (2*(A-0.5), p)
    else:
        return (A, p)
    
def Benjamini_Hochberg_correction(vector_of_pvals,
                                  alpha = 0.05):
    # This function ipltements the BH FDR correction
    
    # Parameters:
    # Vector of p values from the different tests
    # alpha:significance level
    
    # Returns: Corrected p values. All the p values that are above the FDR threshold are set to 1. 
    #          Remaining p values are unchanged.
    
    sortedpvals = np.sort(vector_of_pvals)
    orderofpvals = np.argsort(vector_of_pvals)
    m = sortedpvals[np.isfinite(sortedpvals)].shape[0] #Total number of hypotheses
    for i in range(m):
        if sortedpvals[i] > (i+1)*alpha/m:
            k = i
            break
        elif i == m-1:
            k = m-1
        
    correctedpvals = np.copy(vector_of_pvals)
    correctedpvals[orderofpvals[k:]] = 1
    correctedpvals[np.isnan(vector_of_pvals)] = np.nan
    return correctedpvals

# %%
#method for animal analysis
def analyze_single_session(indir, window_size, pre_window_size):    
    tempfiles = next(os.walk(indir))[2]
    npyfiles = [f for f in tempfiles if os.path.splitext(f)[1]=='.npy' 
        and 'extractedsignals_raw' in f]
    matfiles = [f for f in tempfiles if os.path.splitext(f)[1]=='.mat']

    if len(npyfiles) > 1:
        npyfile = [f for f in tempfiles if os.path.splitext(f)[1]=='.npy' 
            and 'extractedsignals_raw' in f 
            and not 'part2' in f 
            and not 'part3' in f 
            and not 'part4' in f]
        if npyfile[0][0]!='nan':
            npyfile = npyfile [0]
        matfile = [f for f in tempfiles if os.path.splitext(f)[1]=='.mat' 
            and not 'results' in f 
            and not 'part2' in f 
            and not 'part3' in f 
            and not 'part4' in f]
        matfile = matfile [0]
    else:
        npyfile = npyfiles[0]
        matfile = matfiles[0]
    
    signals = np.squeeze(np.load(os.path.join(indir, npyfile)))
    numneurons = signals.shape[0] 
   
    behaviordata = sio.loadmat(os.path.join(indir, matfile))
    eventlog = np.squeeze(behaviordata['eventlog'])
    licks = np.squeeze(behaviordata['licks'])
    lastframe_timestamp_part1 = np.max(eventlog)
    
    if len(npyfiles) > 1:
        npyfiles2 = [f for f in tempfiles if os.path.splitext(f)[1]=='.npy' and 'extractedsignals_raw'and 'part2' in f]
        matfiles2 = [f for f in tempfiles if os.path.splitext(f)[1]=='.mat' and 'part2' in f and not 'results' in f]
        npyfile2 = npyfiles2[0]
        matfile2 = matfiles2[0]
        signals2 = np.squeeze(np.load(os.path.join(indir, npyfile2))) 
        if signals2[0][0]!='nan':
            signals = np.hstack((signals, signals2))
        behaviordata2 = sio.loadmat(os.path.join(indir, matfile2))
        eventlog2 = np.squeeze(behaviordata2['eventlog'])
        eventlog2[:,1] = eventlog2[:,1]+lastframe_timestamp_part1  #adding the last frame to the second column of data in eventlog
        eventlog = np.concatenate((eventlog,eventlog2))
        lastframe_timestamp_part2 = np.max(eventlog)        
        licks2 = np.squeeze(behaviordata2['licks'])
        licks2 = licks2+lastframe_timestamp_part1
        licks = np.concatenate ([licks, licks2])
    if len(npyfiles) > 2:
        npyfiles3 = [f for f in tempfiles if os.path.splitext(f)[1]=='.npy' and 'extractedsignals_raw'and 'part3' in f]
        matfiles3 = [f for f in tempfiles if os.path.splitext(f)[1]=='.mat' and 'part3' in f and not 'results' in f]
        npyfile3 = npyfiles3[0]
        matfile3 = matfiles3[0]
        signals3 = np.squeeze(np.load(os.path.join(indir, npyfile3))) 
        if signals3[0][0]!='nan':
            signals = np.hstack((signals, signals3))
        behaviordata3 = sio.loadmat(os.path.join(indir, matfile3))
        eventlog3 = np.squeeze(behaviordata3['eventlog'])
        eventlog3[:,1] = eventlog3[:,1]+lastframe_timestamp_part2  #adding the last frame to the second column of data in eventlog
        eventlog = np.concatenate((eventlog,eventlog3))
        lastframe_timestamp_part3 = np.max(eventlog)
        licks3 = np.squeeze(behaviordata3['licks'])
        licks3 = licks3+lastframe_timestamp_part2
        licks = np.concatenate ([licks, licks3])
    if len(npyfiles) > 3:
        npyfiles4 = [f for f in tempfiles if os.path.splitext(f)[1]=='.npy' and 'extractedsignals_raw' and 'part4' in f]
        matfiles4 = [f for f in tempfiles if os.path.splitext(f)[1]=='.mat' and 'part4' in f and not 'results' in f]
        npyfile4 = npyfiles4[0]
        matfile4 = matfiles4[0]
        signals4 = np.squeeze(np.load(os.path.join(indir, npyfile4))) 
        if signals4[0][0]!='nan':
            signals = np.hstack((signals, signals4))
        behaviordata4 = sio.loadmat(os.path.join(indir, matfile4))
        eventlog4 = np.squeeze(behaviordata4['eventlog'])
        eventlog4[:,1] = eventlog4[:,1]+lastframe_timestamp_part3  #adding the last frame to the second column of data in eventlog
        eventlog = np.concatenate((eventlog,eventlog4))
        lastframe_timestamp_part4 = np.max(eventlog)
        licks4 = np.squeeze(behaviordata4['licks'])
        licks4 = licks4+lastframe_timestamp_part3
        licks = np.concatenate ([licks, licks4])
    #pulling data from eventlog
    activelever = eventlog[eventlog[:,0]==22,1]
    activelevertimeout = eventlog[eventlog[:,0]==222,1]
    inactivelever = eventlog[eventlog[:,0]==21,1]
    inactivelevertimeout = eventlog[eventlog[:,0]==212,1]
    cues = eventlog[eventlog[:,0]==7,1]
    infusions = eventlog[eventlog[:,0]==4,1]    

    signals /= np.mean(signals, axis=1)[:, None]
    signalsT = signals.T






    
    
    ###IF YOUR CODE LACKS FRAME INPUTS, WE CAN ATTEMPT TO PREDICT FRAME TIMING BY USING PREVIOUS FRAME TIMESTAMPS
    if animal == 'CTL1' or animal == 'ER-L1' or animal == 'ER-L2' or animal == 'IG-19' or animal == 'IG-28' or animal == 'PGa-T1' or animal == 'XYZ':
        frame_timestamps = assumed_frame_timestamps ###Fixes issue for finding behavior IF YOU DON"T HAVE FRAME INFO
    else:
        frame_timestamps = fix_any_dropped_frames(eventlog[eventlog[:,0]==9,1]) 
    frame_timestamps = frame_timestamps[::frameaveraging] ###incorporates averaging into timestamp array
    
    ###DISCARDS BEHAVIORAL EVENTS THAT WERE NOT FULLY MONITORED WITH IMAGING
    if signals.shape[1] > frame_timestamps.shape[0]:
        signals = signals[:,:frame_timestamps.shape[0]-1] ###cuts signals so it's not longer than the frame timestamps
        
    final_frame_timestamp = frame_timestamps[signals.shape[1]] #This is the timestamp of the final frame in milliseconds
    activelever = activelever[activelever<(final_frame_timestamp-(window_size/framerate*1000))]
    activelevertimeout = activelevertimeout[activelevertimeout<(final_frame_timestamp-(window_size/framerate*1000))]
    inactivelever = inactivelever[inactivelever<(final_frame_timestamp-(window_size/framerate*1000))]
    inactivelevertimeout = inactivelevertimeout[inactivelevertimeout<(final_frame_timestamp-(window_size/framerate*1000))]
    
    seconds_monitored = int(signals.shape[1]/averagedframerate) ###seconds monitored by 2p imaging
    seconds_behavior = int(max(activelever/1000)) ###final seconds to be monitored for behavior

    if seconds_monitored < seconds_behavior: #calculates last fully-monitored active lever press with 2p recording
        included_trials = []
        discarded_trials=[]
        for i in range(len(activelever)):
            if activelever[i]/1000<seconds_monitored:
                included_trials=np.append(included_trials, activelever[i])
            else:
                discarded_trials=np.append(discarded_trials,activelever[i]) #FIXME why is this even here?
        activelever=included_trials 
    #combines all presses
    activeleverall = np.hstack((activelever, activelevertimeout))
    inactiveleverall = np.hstack((inactivelever, inactivelevertimeout))

    #FIXME
    if activeleverall.shape[0] < 6:
        activeleverall =np.array([])
    if inactiveleverall.shape[0] < 6:
        inactiveleverall = np.array([])
    print('Signals.T:', signalsT.shape, 'Active:', activeleverall.shape, 'Inactive:',inactiveleverall.shape )
 
    #method for calculating aligned data
    def calculate_aligneddata_forevent(data, frame_after_event): #FIXME
        framenumberfor_eventofinterest = np.squeeze(framenumberforevent(frame_after_event, frame_timestamps))
        numtrials = framenumberfor_eventofinterest.shape[0]
        if data.size==signals.size:
            align = np.NAN*np.zeros([numtrials,window_size,numneurons])
            align_to_plot = np.NAN*np.zeros([numtrials,window_size,numneurons])###CHANGED ON AUGUST 20 2021
        else:
            align = np.NAN*np.zeros([numtrials,window_size])
            align_to_plot = np.NAN*np.zeros([numtrials,window_size])
        temp = data
        prevendindex = 0
        for i in range(numtrials):  ###CHANGED THIS SECTION ON AUGUST 20 2021
            print(i)
            tempindex = framenumberfor_eventofinterest[i]
            if np.isfinite(tempindex):
                tempindex = int(tempindex)
                tempstartindex = np.amin([pre_window_size, tempindex]).astype(int)
                startindex = np.amin([tempstartindex, tempindex-prevendindex]).astype(int)
                tempendindex = np.amin([len(frame_timestamps)-tempindex, post_window_size])
                print('  tempindex',tempindex)
                print('  tempstartindex',tempstartindex)
                print('  startindex',startindex)
                print('  tempendindex',tempendindex)
                if i<(numtrials-1) and np.isfinite(framenumberfor_eventofinterest[i+1]):
                    #endindex = np.amin([framenumberfor_eventofinterest[i+1]-tempindex, tempendindex]).astype(int)
                    #print('  endindex', endindex)
                    endindex = tempendindex
                    print('  endindex', endindex)
                else:
                    #endindex = tempendindex.astype(int) 
                    endindex = tempendindex
                    print('  endindex', endindex) 
                    prevendindex = tempindex+endindex
                if temp.shape[0]!=temp.size:
                    print('     T1 align to plot:', (align_to_plot[i,pre_window_size-startindex:pre_window_size+endindex,:]).shape)
                    print('     T2 temp:', (temp[tempindex-startindex:tempindex+endindex,:]).shape) #FIXME -> throwing index error
                    align_to_plot[i,pre_window_size-startindex:pre_window_size+endindex,:] = temp[tempindex-startindex:tempindex+endindex,:]
                    align[i,pre_window_size-tempstartindex:pre_window_size+endindex,:] = temp[tempindex-tempstartindex:tempindex+endindex,:]
                else: 
                    print((align_to_plot[i,pre_window_size-startindex:pre_window_size+endindex,:]).shape)
                    print((temp[tempindex-startindex:tempindex+endindex,:]).shape)
                    align_to_plot[i,pre_window_size-startindex:pre_window_size+endindex] = temp[tempindex-startindex:tempindex+endindex]
                    align[i,pre_window_size-tempstartindex:pre_window_size+endindex] = temp[tempindex-tempstartindex:tempindex+endindex]
            else:
                if temp.shape[0]!=temp.size:
                    align_to_plot[i,:,:] = np.nan*np.ones((window_size, numneurons))
                    align[i,:,:] = np.nan*np.ones((window_size, numneurons))
                else:
                    align_to_plot[i,:] = np.nan*np.ones((window_size))
                    align[i,:] = np.nan*np.ones((window_size))
        if temp.shape[0]!=temp.size:         
            align_to_plot = align_to_plot[np.where(np.isfinite(align_to_plot[:,0]))[0],:]     
        else:
            align_to_plot = align_to_plot[np.where(np.isfinite(align_to_plot[:,0]))[0],:]
        return align, align_to_plot, framenumberfor_eventofinterest
    
    print('start active calculation')
    align_activelever, align_to_plot_activelever, framenumberfor_frameafter_activelever = \
        calculate_aligneddata_forevent(signalsT, activeleverall)  
    populationdata_activelever = np.nanmean(align_activelever, axis=0).T-1
    print('end active calculation')

    print('start inactive calculation')
    align_inactivelever, align_to_plot_inactivelever, framenumberfor_frameafter_inactivelever = \
        calculate_aligneddata_forevent(signalsT, inactiveleverall) #FIXME
    populationdata_inactivelever = np.nanmean(align_inactivelever, axis=0).T-1
    print('end inactive calculation')
    
    for i in range(signals.shape[0]):
        if np.isnan(np.mean(signals[i,:])):
            print(animal, fov, 'IMAGE J ROI.ZIP CELL NUMBER %s HAS NaNs AND SHOULD BE CHANGED'%(i+1))
        
    return populationdata_activelever, populationdata_inactivelever, align_activelever, align_inactivelever, framerate

# %% [markdown]
# #### Making single session analysis files

# %%
#Early population
excluded = []
for animal in early_animals_of_interest:
    print('>>>', animal)
    FOVs = next(os.walk(os.path.join(earlybasedir, animal)))[1]
    for fov in sorted(FOVs):
        temp_active = np.nan*np.ones((1, window_size))
        temp_inactive = np.nan*np.ones((1, window_size))
        for fov in sorted(FOVs):
            try:
                temp1, temp2, temp3, temp4, framerate = analyze_single_session(
                    #analysis parameters
                    os.path.join(earlybasedir, animal, fov), 
                    window_size, 
                    pre_window_size
                    )
                #saving active and inactive signal data (includig NaN rows)
                temp_active = np.vstack((temp_active, temp1))
                temp_inactive = np.vstack((temp_inactive, temp2))
                #saving aligned active and inactive lever data
                temp_align_active_lever = temp3
                temp_align_inactive_lever = temp4
            except Exception as e:
                print('***ERROR:', e, '***')
                excluded.append(animal)
            #files for signal data with NaN's
            np.save(os.path.join(earlybasedir, animal, fov, "active"), temp_active[1:,:])
            np.save(os.path.join(earlybasedir, animal, fov, "inactive"), temp_inactive[1:,:])
            #files for aligned lever data
            np.save(os.path.join(earlybasedir, animal, fov, "aligned_active_lever_data"), temp_align_active_lever)
            np.save(os.path.join(earlybasedir, animal, fov, "aligned_inactive_lever_data"), temp_align_inactive_lever)
print('Early excluded animals:', excluded)
# Out:
# >>> CTL1
# Signals.T: (82421, 121) Active: (30,) Inactive: (0,)
# start active calculation
# 0
#   tempindex 1538
#   tempstartindex 83
#   startindex 83
#   tempendindex 107
#   endindex 107
#      T1 align to plot: (190, 121)
#      T2 temp: (190, 121)
# 1
#   tempindex 1539
#   tempstartindex 83
#   startindex 83
#   tempendindex 107
#   endindex 107
#      T1 align to plot: (190, 121)
#      T2 temp: (190, 121)
# 2
#   tempindex 1543
#   tempstartindex 83
#   startindex 83
#   tempendindex 107
#   endindex 107
#      T1 align to plot: (190, 121)
#      T2 temp: (190, 121)
# 3
#   tempindex 2285
#   tempstartindex 83
#   startindex 83
#   tempendindex 107
#   endindex 107
#      T1 align to plot: (190, 121)
#      T2 temp: (190, 121)
# 4
#   tempindex 5609
#   tempstartindex 83
#   startindex 83
#   tempendindex 107
#   endindex 107
#      T1 align to plot: (190, 121)
#      T2 temp: (190, 121)
# 5
#   tempindex 8930
#   tempstartindex 83
#   startindex 83
#   tempendindex 107
#   endindex 107
#      T1 align to plot: (190, 121)
#      T2 temp: (190, 121)
# 6
#   tempindex 8932
#   tempstartindex 83
#   startindex 83
#   tempendindex 107
#   endindex 107
#      T1 align to plot: (190, 121)
#      T2 temp: (190, 121)
# 7
#   tempindex 8972
#   tempstartindex 83
#   startindex 83
#   tempendindex 107
#   endindex 107
#      T1 align to plot: (190, 121)
#      T2 temp: (190, 121)
# 8
#   tempindex 13208
#   tempstartindex 83
#   startindex 83
#   tempendindex 107
#   endindex 107
#      T1 align to plot: (190, 121)
#      T2 temp: (190, 121)
# 9
#   tempindex 13212
#   tempstartindex 83
#   startindex 83
#   tempendindex 107
#   endindex 107
#      T1 align to plot: (190, 121)
#      T2 temp: (190, 121)
# 10
#   tempindex 13214
#   tempstartindex 83
#   startindex 83
#   tempendindex 107
#   endindex 107
#      T1 align to plot: (190, 121)
#      T2 temp: (190, 121)
# 11
#   tempindex 18678
#   tempstartindex 83
#   startindex 83
#   tempendindex 107
#   endindex 107
#      T1 align to plot: (190, 121)
#      T2 temp: (190, 121)
# 12
#   tempindex 18679
#   tempstartindex 83
#   startindex 83
#   tempendindex 107
#   endindex 107
#      T1 align to plot: (190, 121)
#      T2 temp: (190, 121)
# 13
#   tempindex 18688
#   tempstartindex 83
#   startindex 83
#   tempendindex 107
#   endindex 107
#      T1 align to plot: (190, 121)
#      T2 temp: (190, 121)
# 14
#   tempindex 20210
#   tempstartindex 83
#   startindex 83
#   tempendindex 107
#   endindex 107
#      T1 align to plot: (190, 121)
#      T2 temp: (190, 121)
# 15
#   tempindex 20212
#   tempstartindex 83
#   startindex 83
#   tempendindex 107
#   endindex 107
#      T1 align to plot: (190, 121)
#      T2 temp: (190, 121)
# 16
#   tempindex 20220
#   tempstartindex 83
#   startindex 83
#   tempendindex 107
#   endindex 107
#      T1 align to plot: (190, 121)
#      T2 temp: (190, 121)
# 17
#   tempindex 25937
#   tempstartindex 83
#   startindex 83
#   tempendindex 107
#   endindex 107
#      T1 align to plot: (190, 121)
#      T2 temp: (190, 121)
# 18
#   tempindex 29831
#   tempstartindex 83
#   startindex 83
#   tempendindex 107
#   endindex 107
#      T1 align to plot: (190, 121)
#      T2 temp: (190, 121)
# 19
#   tempindex 29834
#   tempstartindex 83
#   startindex 83
#   tempendindex 107
#   endindex 107
#      T1 align to plot: (190, 121)
#      T2 temp: (190, 121)
# 20
#   tempindex 35649
#   tempstartindex 83
#   startindex 83
#   tempendindex 107
#   endindex 107
#      T1 align to plot: (190, 121)
#      T2 temp: (190, 121)
# 21
#   tempindex 40891
#   tempstartindex 83
#   startindex 83
#   tempendindex 107
#   endindex 107
#      T1 align to plot: (190, 121)
#      T2 temp: (190, 121)
# 22
#   tempindex 44393
#   tempstartindex 83
#   startindex 83
#   tempendindex 107
#   endindex 107
#      T1 align to plot: (190, 121)
#      T2 temp: (190, 121)
# 23
#   tempindex 44593
#   tempstartindex 83
#   startindex 83
#   tempendindex 107
#   endindex 107
#      T1 align to plot: (190, 121)
#      T2 temp: (190, 121)
# 24
#   tempindex 44597
#   tempstartindex 83
#   startindex 83
#   tempendindex 107
#   endindex 107
#      T1 align to plot: (190, 121)
#      T2 temp: (190, 121)
# 25
#   tempindex 50578
#   tempstartindex 83
#   startindex 83
#   tempendindex 107
#   endindex 107
#      T1 align to plot: (190, 121)
#      T2 temp: (190, 121)
# 26
#   tempindex 57016
#   tempstartindex 83
#   startindex 83
#   tempendindex 107
#   endindex 107
#      T1 align to plot: (190, 121)
#      T2 temp: (190, 121)
# 27
#   tempindex 57021
#   tempstartindex 83
#   startindex 83
#   tempendindex 107
#   endindex 107
#      T1 align to plot: (190, 121)
#      T2 temp: (190, 121)
# 28
#   tempindex 62698
#   tempstartindex 83
#   startindex 83
#   tempendindex 107
#   endindex 107
#      T1 align to plot: (190, 121)
#      T2 temp: (190, 121)
# 29
#   tempindex 70530
#   tempstartindex 83
#   startindex 83
#   tempendindex 107
#   endindex 107
#      T1 align to plot: (190, 121)
#      T2 temp: (190, 121)
# end active calculation
# start inactive calculation
# end inactive calculation
# >>> ER-L1
# C:\Users\jboqu\AppData\Local\Temp\ipykernel_26344\2002071708.py:206: RuntimeWarning: Mean of empty slice
#   populationdata_inactivelever = np.nanmean(align_inactivelever, axis=0).T-1
# Signals.T: (80022, 257) Active: (28,) Inactive: (8,)
# start active calculation
# 0
#   tempindex 216
#   tempstartindex 83
#   startindex 83
#   tempendindex 107
#   endindex 107
#      T1 align to plot: (190, 257)
#      T2 temp: (190, 257)
# 1
#   tempindex 220
#   tempstartindex 83
#   startindex 83
#   tempendindex 107
#   endindex 107
#      T1 align to plot: (190, 257)
#      T2 temp: (190, 257)
# 2
#   tempindex 223
#   tempstartindex 83
#   startindex 83
#   tempendindex 107
#   endindex 107
#      T1 align to plot: (190, 257)
#      T2 temp: (190, 257)
# 3
#   tempindex 230
#   tempstartindex 83
#   startindex 83
#   tempendindex 107
#   endindex 107
#      T1 align to plot: (190, 257)
#      T2 temp: (190, 257)
# 4
#   tempindex 352
#   tempstartindex 83
#   startindex 83
#   tempendindex 107
#   endindex 107
#      T1 align to plot: (190, 257)
#      T2 temp: (190, 257)
# 5
#   tempindex 354
#   tempstartindex 83
#   startindex 83
#   tempendindex 107
#   endindex 107
#      T1 align to plot: (190, 257)
#      T2 temp: (190, 257)
# 6
#   tempindex 436
#   tempstartindex 83
#   startindex 83
#   tempendindex 107
#   endindex 107
#      T1 align to plot: (190, 257)
#      T2 temp: (190, 257)
# 7
#   tempindex 439
#   tempstartindex 83
#   startindex 83
#   tempendindex 107
#   endindex 107
#      T1 align to plot: (190, 257)
#      T2 temp: (190, 257)
# 8
#   tempindex 442
#   tempstartindex 83
#   startindex 83
#   tempendindex 107
#   endindex 107
#      T1 align to plot: (190, 257)
#      T2 temp: (190, 257)
# 9
#   tempindex 445
#   tempstartindex 83
#   startindex 83
#   tempendindex 107
#   endindex 107
#      T1 align to plot: (190, 257)
#      T2 temp: (190, 257)
# 10
#   tempindex 448
#   tempstartindex 83
#   startindex 83
#   tempendindex 107
#   endindex 107
#      T1 align to plot: (190, 257)
#      T2 temp: (190, 257)
# 11
#   tempindex 906
#   tempstartindex 83
#   startindex 83
#   tempendindex 107
#   endindex 107
#      T1 align to plot: (190, 257)
#      T2 temp: (190, 257)
# 12
#   tempindex 977
#   tempstartindex 83
#   startindex 83
#   tempendindex 107
#   endindex 107
#      T1 align to plot: (190, 257)
#      T2 temp: (190, 257)
# 13
#   tempindex 980
#   tempstartindex 83
#   startindex 83
#   tempendindex 107
#   endindex 107
#      T1 align to plot: (190, 257)
#      T2 temp: (190, 257)
# 14
#   tempindex 1351
#   tempstartindex 83
#   startindex 83
#   tempendindex 107
#   endindex 107
#      T1 align to plot: (190, 257)
#      T2 temp: (190, 257)
# 15
#   tempindex 1619
#   tempstartindex 83
#   startindex 83
#   tempendindex 107
#   endindex 107
#      T1 align to plot: (190, 257)
#      T2 temp: (190, 257)
# 16
#   tempindex 1620
#   tempstartindex 83
#   startindex 83
#   tempendindex 107
#   endindex 107
#      T1 align to plot: (190, 257)
#      T2 temp: (190, 257)
# 17
#   tempindex 1629
#   tempstartindex 83
#   startindex 83
#   tempendindex 107
#   endindex 107
#      T1 align to plot: (190, 257)
#      T2 temp: (190, 257)
# 18
#   tempindex 1638
#   tempstartindex 83
#   startindex 83
#   tempendindex 107
#   endindex 107
#      T1 align to plot: (190, 257)
#      T2 temp: (190, 257)
# 19
#   tempindex 2008
#   tempstartindex 83
#   startindex 83
#   tempendindex 107
#   endindex 107
#      T1 align to plot: (190, 257)
#      T2 temp: (190, 257)
# 20
#   tempindex 2012
#   tempstartindex 83
#   startindex 83
#   tempendindex 107
#   endindex 107
#      T1 align to plot: (190, 257)
#      T2 temp: (190, 257)
# 21
#   tempindex 2153
#   tempstartindex 83
#   startindex 83
#   tempendindex 107
#   endindex 107
#      T1 align to plot: (190, 257)
#      T2 temp: (190, 257)
# 22
#   tempindex 2155
#   tempstartindex 83
#   startindex 83
#   tempendindex 107
#   endindex 107
#      T1 align to plot: (190, 257)
#      T2 temp: (190, 257)
# 23
#   tempindex 2159
#   tempstartindex 83
#   startindex 83
#   tempendindex 107
#   endindex 107
#      T1 align to plot: (190, 257)
#      T2 temp: (190, 257)
# 24
#   tempindex 2160
#   tempstartindex 83
#   startindex 83
#   tempendindex 107
#   endindex 107
#      T1 align to plot: (190, 257)
#      T2 temp: (190, 257)
# 25
#   tempindex 2740
#   tempstartindex 83
#   startindex 83
#   tempendindex 107
#   endindex 107
#      T1 align to plot: (190, 257)
#      T2 temp: (190, 257)
# 26
#   tempindex 3614
#   tempstartindex 83
#   startindex 83
#   tempendindex 107
#   endindex 107
#      T1 align to plot: (190, 257)
#      T2 temp: (190, 257)
# 27
#   tempindex 3621
#   tempstartindex 83
#   startindex 83
#   tempendindex 107
#   endindex 107
#      T1 align to plot: (190, 257)
#      T2 temp: (190, 257)
# end active calculation
# start inactive calculation
# 0
#   tempindex 221
#   tempstartindex 83
#   startindex 83
#   tempendindex 107
#   endindex 107
#      T1 align to plot: (190, 257)
#      T2 temp: (190, 257)
# 1
#   tempindex 229
#   tempstartindex 83
#   startindex 83
#   tempendindex 107
#   endindex 107
#      T1 align to plot: (190, 257)
#      T2 temp: (190, 257)
# 2
#   tempindex 231
#   tempstartindex 83
#   startindex 83
#   tempendindex 107
#   endindex 107
#      T1 align to plot: (190, 257)
#      T2 temp: (190, 257)
# 3
#   tempindex 235
#   tempstartindex 83
#   startindex 83
#   tempendindex 107
#   endindex 107
#      T1 align to plot: (190, 257)
#      T2 temp: (190, 257)
# 4
#   tempindex 237
#   tempstartindex 83
#   startindex 83
#   tempendindex 107
#   endindex 107
#      T1 align to plot: (190, 257)
#      T2 temp: (190, 257)
# 5
#   tempindex 253
#   tempstartindex 83
#   startindex 83
#   tempendindex 107
#   endindex 107
#      T1 align to plot: (190, 257)
#      T2 temp: (190, 257)
# 6
#   tempindex 350
#   tempstartindex 83
#   startindex 83
#   tempendindex 107
#   endindex 107
#      T1 align to plot: (190, 257)
#      T2 temp: (190, 257)
# 7
#   tempindex 353
#   tempstartindex 83
#   startindex 83
#   tempendindex 107
#   endindex 107
#      T1 align to plot: (190, 257)
#      T2 temp: (190, 257)
# end inactive calculation
# >>> ER-L2
# Signals.T: (80040, 106) Active: (148,) Inactive: (11,)
# start active calculation
# 0
#   tempindex 2718
#   tempstartindex 83
#   startindex 83
#   tempendindex 107
#   endindex 107
#      T1 align to plot: (190, 106)
#      T2 temp: (190, 106)
# 1
#   tempindex 2734
#   tempstartindex 83
#   startindex 83
#   tempendindex 107
#   endindex 107
#      T1 align to plot: (190, 106)
#      T2 temp: (190, 106)
# 2
#   tempindex 7479
#   tempstartindex 83
#   startindex 83
#   tempendindex 107
#   endindex 107
#      T1 align to plot: (190, 106)
#      T2 temp: (190, 106)
# 3
#   tempindex 7485
#   tempstartindex 83
#   startindex 83
#   tempendindex 107
#   endindex 107
#      T1 align to plot: (190, 106)
#      T2 temp: (190, 106)
# 4
#   tempindex 7489
#   tempstartindex 83
#   startindex 83
#   tempendindex 107
#   endindex 107
#      T1 align to plot: (190, 106)
#      T2 temp: (190, 106)
# 5
#   tempindex 7492
#   tempstartindex 83
#   startindex 83
#   tempendindex 107
#   endindex 107
#      T1 align to plot: (190, 106)
#      T2 temp: (190, 106)
# 6
#   tempindex 10286
#   tempstartindex 83
#   startindex 83
#   tempendindex 107
#   endindex 107
#      T1 align to plot: (190, 106)
#      T2 temp: (190, 106)
# 7
#   tempindex 10299
#   tempstartindex 83
#   startindex 83
#   tempendindex 107
#   endindex 107
#      T1 align to plot: (190, 106)
#      T2 temp: (190, 106)
# 8
#   tempindex 10303
#   tempstartindex 83
#   startindex 83
#   tempendindex 107
#   endindex 107
#      T1 align to plot: (190, 106)
#      T2 temp: (190, 106)
# 9
#   tempindex 13779
#   tempstartindex 83
#   startindex 83
#   tempendindex 107
#   endindex 107
#      T1 align to plot: (190, 106)
#      T2 temp: (190, 106)
# 10
#   tempindex 13780
#   tempstartindex 83
#   startindex 83
#   tempendindex 107
#   endindex 107
#      T1 align to plot: (190, 106)
#      T2 temp: (190, 106)
# 11
#   tempindex 13794
#   tempstartindex 83
#   startindex 83
#   tempendindex 107
#   endindex 107
#      T1 align to plot: (190, 106)
#      T2 temp: (190, 106)
# 12
#   tempindex 13796
#   tempstartindex 83
#   startindex 83
#   tempendindex 107
#   endindex 107
#      T1 align to plot: (190, 106)
#      T2 temp: (190, 106)
# 13
#   tempindex 14129
#   tempstartindex 83
#   startindex 83
#   tempendindex 107
#   endindex 107
#      T1 align to plot: (190, 106)
#      T2 temp: (190, 106)
# 14
#   tempindex 17890
#   tempstartindex 83
#   startindex 83
#   tempendindex 107
#   endindex 107
#      T1 align to plot: (190, 106)
#      T2 temp: (190, 106)
# 15
#   tempindex 17891
#   tempstartindex 83
#   startindex 83
#   tempendindex 107
#   endindex 107
#      T1 align to plot: (190, 106)
#      T2 temp: (190, 106)
# 16
#   tempindex 17900
#   tempstartindex 83
#   startindex 83
#   tempendindex 107
#   endindex 107
#      T1 align to plot: (190, 106)
#      T2 temp: (190, 106)
# 17
#   tempindex 17902
#   tempstartindex 83
#   startindex 83
#   tempendindex 107
#   endindex 107
#      T1 align to plot: (190, 106)
#      T2 temp: (190, 106)
# 18
#   tempindex 17905
#   tempstartindex 83
#   startindex 83
#   tempendindex 107
#   endindex 107
#      T1 align to plot: (190, 106)
#      T2 temp: (190, 106)
# 19
#   tempindex 17908
#   tempstartindex 83
#   startindex 83
#   tempendindex 107
#   endindex 107
#      T1 align to plot: (190, 106)
#      T2 temp: (190, 106)
# 20
#   tempindex 17916
#   tempstartindex 83
#   startindex 83
#   tempendindex 107
#   endindex 107
#      T1 align to plot: (190, 106)
#      T2 temp: (190, 106)
# 21
#   tempindex 17936
#   tempstartindex 83
#   startindex 83
#   tempendindex 107
#   endindex 107
#      T1 align to plot: (190, 106)
#      T2 temp: (190, 106)
# 22
#   tempindex 18743
#   tempstartindex 83
#   startindex 83
#   tempendindex 107
#   endindex 107
#      T1 align to plot: (190, 106)
#      T2 temp: (190, 106)
# 23
#   tempindex 18770
#   tempstartindex 83
#   startindex 83
#   tempendindex 107
#   endindex 107
#      T1 align to plot: (190, 106)
#      T2 temp: (190, 106)
# 24
#   tempindex 18778
#   tempstartindex 83
#   startindex 83
#   tempendindex 107
#   endindex 107
#      T1 align to plot: (190, 106)
#      T2 temp: (190, 106)
# 25
#   tempindex 18838
#   tempstartindex 83
#   startindex 83
#   tempendindex 107
#   endindex 107
#      T1 align to plot: (190, 106)
#      T2 temp: (190, 106)
# 26
#   tempindex 22038
#   tempstartindex 83
#   startindex 83
#   tempendindex 107
#   endindex 107
#      T1 align to plot: (190, 106)
#      T2 temp: (190, 106)
# 27
#   tempindex 22044
#   tempstartindex 83
#   startindex 83
#   tempendindex 107
#   endindex 107
#      T1 align to plot: (190, 106)
#      T2 temp: (190, 106)
# 28
#   tempindex 22058
#   tempstartindex 83
#   startindex 83
#   tempendindex 107
#   endindex 107
#      T1 align to plot: (190, 106)
#      T2 temp: (190, 106)
# 29
#   tempindex 22067
#   tempstartindex 83
#   startindex 83
#   tempendindex 107
#   endindex 107
#      T1 align to plot: (190, 106)
#      T2 temp: (190, 106)
# 30
#   tempindex 22073
#   tempstartindex 83
#   startindex 83
#   tempendindex 107
#   endindex 107
#      T1 align to plot: (190, 106)
#      T2 temp: (190, 106)
# 31
#   tempindex 22145
#   tempstartindex 83
#   startindex 83
#   tempendindex 107
#   endindex 107
#      T1 align to plot: (190, 106)
#      T2 temp: (190, 106)
# 32
#   tempindex 22148
#   tempstartindex 83
#   startindex 83
#   tempendindex 107
#   endindex 107
#      T1 align to plot: (190, 106)
#      T2 temp: (190, 106)
# 33
#   tempindex 22152
#   tempstartindex 83
#   startindex 83
#   tempendindex 107
#   endindex 107
#      T1 align to plot: (190, 106)
#      T2 temp: (190, 106)
# 34
#   tempindex 22156
#   tempstartindex 83
#   startindex 83
#   tempendindex 107
#   endindex 107
#      T1 align to plot: (190, 106)
#      T2 temp: (190, 106)
# 35
#   tempindex 24316
#   tempstartindex 83
#   startindex 83
#   tempendindex 107
#   endindex 107
#      T1 align to plot: (190, 106)
#      T2 temp: (190, 106)
# 36
#   tempindex 24321
#   tempstartindex 83
#   startindex 83
#   tempendindex 107
#   endindex 107
#      T1 align to plot: (190, 106)
#      T2 temp: (190, 106)
# 37
#   tempindex 24326
#   tempstartindex 83
#   startindex 83
#   tempendindex 107
#   endindex 107
#      T1 align to plot: (190, 106)
#      T2 temp: (190, 106)
# 38
#   tempindex 24357
#   tempstartindex 83
#   startindex 83
#   tempendindex 107
#   endindex 107
#      T1 align to plot: (190, 106)
#      T2 temp: (190, 106)
# 39
#   tempindex 24385
#   tempstartindex 83
#   startindex 83
#   tempendindex 107
#   endindex 107
#      T1 align to plot: (190, 106)
#      T2 temp: (190, 106)
# 40
#   tempindex 24421
#   tempstartindex 83
#   startindex 83
#   tempendindex 107
#   endindex 107
#      T1 align to plot: (190, 106)
#      T2 temp: (190, 106)
# 41
#   tempindex 24429
#   tempstartindex 83
#   startindex 83
#   tempendindex 107
#   endindex 107
#      T1 align to plot: (190, 106)
#      T2 temp: (190, 106)
# 42
#   tempindex 24434
#   tempstartindex 83
#   startindex 83
#   tempendindex 107
#   endindex 107
#      T1 align to plot: (190, 106)
#      T2 temp: (190, 106)
# 43
#   tempindex 24442
#   tempstartindex 83
#   startindex 83
#   tempendindex 107
#   endindex 107
#      T1 align to plot: (190, 106)
#      T2 temp: (190, 106)
# 44
#   tempindex 24577
#   tempstartindex 83
#   startindex 83
#   tempendindex 107
#   endindex 107
#      T1 align to plot: (190, 106)
#      T2 temp: (190, 106)
# 45
#   tempindex 24643
#   tempstartindex 83
#   startindex 83
#   tempendindex 107
#   endindex 107
#      T1 align to plot: (190, 106)
#      T2 temp: (190, 106)
# 46
#   tempindex 26869
#   tempstartindex 83
#   startindex 83
#   tempendindex 107
#   endindex 107
#      T1 align to plot: (190, 106)
#      T2 temp: (190, 106)
# 47
#   tempindex 26888
#   tempstartindex 83
#   startindex 83
#   tempendindex 107
#   endindex 107
#      T1 align to plot: (190, 106)
#      T2 temp: (190, 106)
# 48
#   tempindex 26892
#   tempstartindex 83
#   startindex 83
#   tempendindex 107
#   endindex 107
#      T1 align to plot: (190, 106)
#      T2 temp: (190, 106)
# 49
#   tempindex 26898
#   tempstartindex 83
#   startindex 83
#   tempendindex 107
#   endindex 107
#      T1 align to plot: (190, 106)
#      T2 temp: (190, 106)
# 50
#   tempindex 26938
#   tempstartindex 83
#   startindex 83
#   tempendindex 107
#   endindex 107
#      T1 align to plot: (190, 106)
#      T2 temp: (190, 106)
# 51
#   tempindex 27102
#   tempstartindex 83
#   startindex 83
#   tempendindex 107
#   endindex 107
#      T1 align to plot: (190, 106)
#      T2 temp: (190, 106)
# 52
#   tempindex 30618
#   tempstartindex 83
#   startindex 83
#   tempendindex 107
#   endindex 107
#      T1 align to plot: (190, 106)
#      T2 temp: (190, 106)
# 53
#   tempindex 30634
#   tempstartindex 83
#   startindex 83
#   tempendindex 107
#   endindex 107
#      T1 align to plot: (190, 106)
#      T2 temp: (190, 106)
# 54
#   tempindex 30641
#   tempstartindex 83
#   startindex 83
#   tempendindex 107
#   endindex 107
#      T1 align to plot: (190, 106)
#      T2 temp: (190, 106)
# 55
#   tempindex 30683
#   tempstartindex 83
#   startindex 83
#   tempendindex 107
#   endindex 107
#      T1 align to plot: (190, 106)
#      T2 temp: (190, 106)
# 56
#   tempindex 30686
#   tempstartindex 83
#   startindex 83
#   tempendindex 107
#   endindex 107
#      T1 align to plot: (190, 106)
#      T2 temp: (190, 106)
# 57
#   tempindex 30689
#   tempstartindex 83
#   startindex 83
#   tempendindex 107
#   endindex 107
#      T1 align to plot: (190, 106)
#      T2 temp: (190, 106)
# 58
#   tempindex 30694
#   tempstartindex 83
#   startindex 83
#   tempendindex 107
#   endindex 107
#      T1 align to plot: (190, 106)
#      T2 temp: (190, 106)
# 59
#   tempindex 30822
#   tempstartindex 83
#   startindex 83
#   tempendindex 107
#   endindex 107
#      T1 align to plot: (190, 106)
#      T2 temp: (190, 106)
# 60
#   tempindex 30830
#   tempstartindex 83
#   startindex 83
#   tempendindex 107
#   endindex 107
#      T1 align to plot: (190, 106)
#      T2 temp: (190, 106)
# 61
#   tempindex 30929
#   tempstartindex 83
#   startindex 83
#   tempendindex 107
#   endindex 107
#      T1 align to plot: (190, 106)
#      T2 temp: (190, 106)
# 62
#   tempindex 30946
#   tempstartindex 83
#   startindex 83
#   tempendindex 107
#   endindex 107
#      T1 align to plot: (190, 106)
#      T2 temp: (190, 106)
# 63
#   tempindex 30991
#   tempstartindex 83
#   startindex 83
#   tempendindex 107
#   endindex 107
#      T1 align to plot: (190, 106)
#      T2 temp: (190, 106)
# 64
#   tempindex 31011
#   tempstartindex 83
#   startindex 83
#   tempendindex 107
#   endindex 107
#      T1 align to plot: (190, 106)
#      T2 temp: (190, 106)
# 65
#   tempindex 31016
#   tempstartindex 83
#   startindex 83
#   tempendindex 107
#   endindex 107
#      T1 align to plot: (190, 106)
#      T2 temp: (190, 106)
# 66
#   tempindex 31065
#   tempstartindex 83
#   startindex 83
#   tempendindex 107
#   endindex 107
#      T1 align to plot: (190, 106)
#      T2 temp: (190, 106)
# 67
#   tempindex 31101
#   tempstartindex 83
#   startindex 83
#   tempendindex 107
#   endindex 107
#      T1 align to plot: (190, 106)
#      T2 temp: (190, 106)
# 68
#   tempindex 31256
#   tempstartindex 83
#   startindex 83
#   tempendindex 107
#   endindex 107
#      T1 align to plot: (190, 106)
#      T2 temp: (190, 106)
# 69
#   tempindex 31290
#   tempstartindex 83
#   startindex 83
#   tempendindex 107
#   endindex 107
#      T1 align to plot: (190, 106)
#      T2 temp: (190, 106)
# 70
#   tempindex 31336
#   tempstartindex 83
#   startindex 83
#   tempendindex 107
#   endindex 107
#      T1 align to plot: (190, 106)
#      T2 temp: (190, 106)
# 71
#   tempindex 31337
#   tempstartindex 83
#   startindex 83
#   tempendindex 107
#   endindex 107
#      T1 align to plot: (190, 106)
#      T2 temp: (190, 106)
# 72
#   tempindex 31382
#   tempstartindex 83
#   startindex 83
#   tempendindex 107
#   endindex 107
#      T1 align to plot: (190, 106)
#      T2 temp: (190, 106)
# 73
#   tempindex 31390
#   tempstartindex 83
#   startindex 83
#   tempendindex 107
#   endindex 107
#      T1 align to plot: (190, 106)
#      T2 temp: (190, 106)
# 74
#   tempindex 31397
#   tempstartindex 83
#   startindex 83
#   tempendindex 107
#   endindex 107
#      T1 align to plot: (190, 106)
#      T2 temp: (190, 106)
# 75
#   tempindex 31401
#   tempstartindex 83
#   startindex 83
#   tempendindex 107
#   endindex 107
#      T1 align to plot: (190, 106)
#      T2 temp: (190, 106)
# 76
#   tempindex 32183
#   tempstartindex 83
#   startindex 83
#   tempendindex 107
#   endindex 107
#      T1 align to plot: (190, 106)
#      T2 temp: (190, 106)
# 77
#   tempindex 32530
#   tempstartindex 83
#   startindex 83
#   tempendindex 107
#   endindex 107
#      T1 align to plot: (190, 106)
#      T2 temp: (190, 106)
# 78
#   tempindex 32534
#   tempstartindex 83
#   startindex 83
#   tempendindex 107
#   endindex 107
#      T1 align to plot: (190, 106)
#      T2 temp: (190, 106)
# 79
#   tempindex 32538
#   tempstartindex 83
#   startindex 83
#   tempendindex 107
#   endindex 107
#      T1 align to plot: (190, 106)
#      T2 temp: (190, 106)
# 80
#   tempindex 33402
#   tempstartindex 83
#   startindex 83
#   tempendindex 107
#   endindex 107
#      T1 align to plot: (190, 106)
#      T2 temp: (190, 106)
# 81
#   tempindex 33406
#   tempstartindex 83
#   startindex 83
#   tempendindex 107
#   endindex 107
#      T1 align to plot: (190, 106)
#      T2 temp: (190, 106)
# 82
#   tempindex 33418
#   tempstartindex 83
#   startindex 83
#   tempendindex 107
#   endindex 107
#      T1 align to plot: (190, 106)
#      T2 temp: (190, 106)
# 83
#   tempindex 33422
#   tempstartindex 83
#   startindex 83
#   tempendindex 107
#   endindex 107
#      T1 align to plot: (190, 106)
#      T2 temp: (190, 106)
# 84
#   tempindex 33425
#   tempstartindex 83
#   startindex 83
#   tempendindex 107
#   endindex 107
#      T1 align to plot: (190, 106)
#      T2 temp: (190, 106)
# 85
#   tempindex 41649
#   tempstartindex 83
#   startindex 83
#   tempendindex 107
#   endindex 107
#      T1 align to plot: (190, 106)
#      T2 temp: (190, 106)
# 86
#   tempindex 41651
#   tempstartindex 83
#   startindex 83
#   tempendindex 107
#   endindex 107
#      T1 align to plot: (190, 106)
#      T2 temp: (190, 106)
# 87
#   tempindex 41658
#   tempstartindex 83
#   startindex 83
#   tempendindex 107
#   endindex 107
#      T1 align to plot: (190, 106)
#      T2 temp: (190, 106)
# 88
#   tempindex 41666
#   tempstartindex 83
#   startindex 83
#   tempendindex 107
#   endindex 107
#      T1 align to plot: (190, 106)
#      T2 temp: (190, 106)
# 89
#   tempindex 41670
#   tempstartindex 83
#   startindex 83
#   tempendindex 107
#   endindex 107
#      T1 align to plot: (190, 106)
#      T2 temp: (190, 106)
# 90
#   tempindex 41672
#   tempstartindex 83
#   startindex 83
#   tempendindex 107
#   endindex 107
#      T1 align to plot: (190, 106)
#      T2 temp: (190, 106)
# 91
#   tempindex 41678
#   tempstartindex 83
#   startindex 83
#   tempendindex 107
#   endindex 107
#      T1 align to plot: (190, 106)
#      T2 temp: (190, 106)
# 92
#   tempindex 41679
#   tempstartindex 83
#   startindex 83
#   tempendindex 107
#   endindex 107
#      T1 align to plot: (190, 106)
#      T2 temp: (190, 106)
# 93
#   tempindex 41907
#   tempstartindex 83
#   startindex 83
#   tempendindex 107
#   endindex 107
#      T1 align to plot: (190, 106)
#      T2 temp: (190, 106)
# 94
#   tempindex 41914
#   tempstartindex 83
#   startindex 83
#   tempendindex 107
#   endindex 107
#      T1 align to plot: (190, 106)
#      T2 temp: (190, 106)
# 95
#   tempindex 46321
#   tempstartindex 83
#   startindex 83
#   tempendindex 107
#   endindex 107
#      T1 align to plot: (190, 106)
#      T2 temp: (190, 106)
# 96
#   tempindex 46333
#   tempstartindex 83
#   startindex 83
#   tempendindex 107
#   endindex 107
#      T1 align to plot: (190, 106)
#      T2 temp: (190, 106)
# 97
#   tempindex 47296
#   tempstartindex 83
#   startindex 83
#   tempendindex 107
#   endindex 107
#      T1 align to plot: (190, 106)
#      T2 temp: (190, 106)
# 98
#   tempindex 49719
#   tempstartindex 83
#   startindex 83
#   tempendindex 107
#   endindex 107
#      T1 align to plot: (190, 106)
#      T2 temp: (190, 106)
# 99
#   tempindex 49723
#   tempstartindex 83
#   startindex 83
#   tempendindex 107
#   endindex 107
#      T1 align to plot: (190, 106)
#      T2 temp: (190, 106)
# 100
#   tempindex 49732
#   tempstartindex 83
#   startindex 83
#   tempendindex 107
#   endindex 107
#      T1 align to plot: (190, 106)
#      T2 temp: (190, 106)
# 101
#   tempindex 49735
#   tempstartindex 83
#   startindex 83
#   tempendindex 107
#   endindex 107
#      T1 align to plot: (190, 106)
#      T2 temp: (190, 106)
# 102
#   tempindex 49738
#   tempstartindex 83
#   startindex 83
#   tempendindex 107
#   endindex 107
#      T1 align to plot: (190, 106)
#      T2 temp: (190, 106)
# 103
#   tempindex 49741
#   tempstartindex 83
#   startindex 83
#   tempendindex 107
#   endindex 107
#      T1 align to plot: (190, 106)
#      T2 temp: (190, 106)
# 104
#   tempindex 49744
#   tempstartindex 83
#   startindex 83
#   tempendindex 107
#   endindex 107
#      T1 align to plot: (190, 106)
#      T2 temp: (190, 106)
# 105
#   tempindex 49749
#   tempstartindex 83
#   startindex 83
#   tempendindex 107
#   endindex 107
#      T1 align to plot: (190, 106)
#      T2 temp: (190, 106)
# 106
#   tempindex 49835
#   tempstartindex 83
#   startindex 83
#   tempendindex 107
#   endindex 107
#      T1 align to plot: (190, 106)
#      T2 temp: (190, 106)
# 107
#   tempindex 49840
#   tempstartindex 83
#   startindex 83
#   tempendindex 107
#   endindex 107
#      T1 align to plot: (190, 106)
#      T2 temp: (190, 106)
# 108
#   tempindex 53719
#   tempstartindex 83
#   startindex 83
#   tempendindex 107
#   endindex 107
#      T1 align to plot: (190, 106)
#      T2 temp: (190, 106)
# 109
#   tempindex 53721
#   tempstartindex 83
#   startindex 83
#   tempendindex 107
#   endindex 107
#      T1 align to plot: (190, 106)
#      T2 temp: (190, 106)
# 110
#   tempindex 53729
#   tempstartindex 83
#   startindex 83
#   tempendindex 107
#   endindex 107
#      T1 align to plot: (190, 106)
#      T2 temp: (190, 106)
# 111
#   tempindex 53741
#   tempstartindex 83
#   startindex 83
#   tempendindex 107
#   endindex 107
#      T1 align to plot: (190, 106)
#      T2 temp: (190, 106)
# 112
#   tempindex 53815
#   tempstartindex 83
#   startindex 83
#   tempendindex 107
#   endindex 107
#      T1 align to plot: (190, 106)
#      T2 temp: (190, 106)
# 113
#   tempindex 53818
#   tempstartindex 83
#   startindex 83
#   tempendindex 107
#   endindex 107
#      T1 align to plot: (190, 106)
#      T2 temp: (190, 106)
# 114
#   tempindex 57801
#   tempstartindex 83
#   startindex 83
#   tempendindex 107
#   endindex 107
#      T1 align to plot: (190, 106)
#      T2 temp: (190, 106)
# 115
#   tempindex 57818
#   tempstartindex 83
#   startindex 83
#   tempendindex 107
#   endindex 107
#      T1 align to plot: (190, 106)
#      T2 temp: (190, 106)
# 116
#   tempindex 57822
#   tempstartindex 83
#   startindex 83
#   tempendindex 107
#   endindex 107
#      T1 align to plot: (190, 106)
#      T2 temp: (190, 106)
# 117
#   tempindex 62517
#   tempstartindex 83
#   startindex 83
#   tempendindex 107
#   endindex 107
#      T1 align to plot: (190, 106)
#      T2 temp: (190, 106)
# 118
#   tempindex 62522
#   tempstartindex 83
#   startindex 83
#   tempendindex 107
#   endindex 107
#      T1 align to plot: (190, 106)
#      T2 temp: (190, 106)
# 119
#   tempindex 62532
#   tempstartindex 83
#   startindex 83
#   tempendindex 107
#   endindex 107
#      T1 align to plot: (190, 106)
#      T2 temp: (190, 106)
# 120
#   tempindex 62539
#   tempstartindex 83
#   startindex 83
#   tempendindex 107
#   endindex 107
#      T1 align to plot: (190, 106)
#      T2 temp: (190, 106)
# 121
#   tempindex 62547
#   tempstartindex 83
#   startindex 83
#   tempendindex 107
#   endindex 107
#      T1 align to plot: (190, 106)
#      T2 temp: (190, 106)
# 122
#   tempindex 62636
#   tempstartindex 83
#   startindex 83
#   tempendindex 107
#   endindex 107
#      T1 align to plot: (190, 106)
#      T2 temp: (190, 106)
# 123
#   tempindex 62643
#   tempstartindex 83
#   startindex 83
#   tempendindex 107
#   endindex 107
#      T1 align to plot: (190, 106)
#      T2 temp: (190, 106)
# 124
#   tempindex 62653
#   tempstartindex 83
#   startindex 83
#   tempendindex 107
#   endindex 107
#      T1 align to plot: (190, 106)
#      T2 temp: (190, 106)
# 125
#   tempindex 62683
#   tempstartindex 83
#   startindex 83
#   tempendindex 107
#   endindex 107
#      T1 align to plot: (190, 106)
#      T2 temp: (190, 106)
# 126
#   tempindex 62701
#   tempstartindex 83
#   startindex 83
#   tempendindex 107
#   endindex 107
#      T1 align to plot: (190, 106)
#      T2 temp: (190, 106)
# 127
#   tempindex 62704
#   tempstartindex 83
#   startindex 83
#   tempendindex 107
#   endindex 107
#      T1 align to plot: (190, 106)
#      T2 temp: (190, 106)
# 128
#   tempindex 65210
#   tempstartindex 83
#   startindex 83
#   tempendindex 107
#   endindex 107
#      T1 align to plot: (190, 106)
#      T2 temp: (190, 106)
# 129
#   tempindex 65220
#   tempstartindex 83
#   startindex 83
#   tempendindex 107
#   endindex 107
#      T1 align to plot: (190, 106)
#      T2 temp: (190, 106)
# 130
#   tempindex 65224
#   tempstartindex 83
#   startindex 83
#   tempendindex 107
#   endindex 107
#      T1 align to plot: (190, 106)
#      T2 temp: (190, 106)
# 131
#   tempindex 69078
#   tempstartindex 83
#   startindex 83
#   tempendindex 107
#   endindex 107
#      T1 align to plot: (190, 106)
#      T2 temp: (190, 106)
# 132
#   tempindex 69091
#   tempstartindex 83
#   startindex 83
#   tempendindex 107
#   endindex 107
#      T1 align to plot: (190, 106)
#      T2 temp: (190, 106)
# 133
#   tempindex 69093
#   tempstartindex 83
#   startindex 83
#   tempendindex 107
#   endindex 107
#      T1 align to plot: (190, 106)
#      T2 temp: (190, 106)
# 134
#   tempindex 69136
#   tempstartindex 83
#   startindex 83
#   tempendindex 107
#   endindex 107
#      T1 align to plot: (190, 106)
#      T2 temp: (190, 106)
# 135
#   tempindex 69231
#   tempstartindex 83
#   startindex 83
#   tempendindex 107
#   endindex 107
#      T1 align to plot: (190, 106)
#      T2 temp: (190, 106)
# 136
#   tempindex 69257
#   tempstartindex 83
#   startindex 83
#   tempendindex 107
#   endindex 107
#      T1 align to plot: (190, 106)
#      T2 temp: (190, 106)
# 137
#   tempindex 69268
#   tempstartindex 83
#   startindex 83
#   tempendindex 107
#   endindex 107
#      T1 align to plot: (190, 106)
#      T2 temp: (190, 106)
# 138
#   tempindex 69277
#   tempstartindex 83
#   startindex 83
#   tempendindex 107
#   endindex 107
#      T1 align to plot: (190, 106)
#      T2 temp: (190, 106)
# 139
#   tempindex 69386
#   tempstartindex 83
#   startindex 83
#   tempendindex 107
#   endindex 107
#      T1 align to plot: (190, 106)
#      T2 temp: (190, 106)
# 140
#   tempindex 69389
#   tempstartindex 83
#   startindex 83
#   tempendindex 107
#   endindex 107
#      T1 align to plot: (190, 106)
#      T2 temp: (190, 106)
# 141
#   tempindex 69434
#   tempstartindex 83
#   startindex 83
#   tempendindex 107
#   endindex 107
#      T1 align to plot: (190, 106)
#      T2 temp: (190, 106)
# 142
#   tempindex 69441
#   tempstartindex 83
#   startindex 83
#   tempendindex 107
#   endindex 107
#      T1 align to plot: (190, 106)
#      T2 temp: (190, 106)
# 143
#   tempindex 69462
#   tempstartindex 83
#   startindex 83
#   tempendindex 107
#   endindex 107
#      T1 align to plot: (190, 106)
#      T2 temp: (190, 106)
# 144
#   tempindex 69548
#   tempstartindex 83
#   startindex 83
#   tempendindex 107
#   endindex 107
#      T1 align to plot: (190, 106)
#      T2 temp: (190, 106)
# 145
#   tempindex 69563
#   tempstartindex 83
#   startindex 83
#   tempendindex 107
#   endindex 107
#      T1 align to plot: (190, 106)
#      T2 temp: (190, 106)
# 146
#   tempindex 71544
#   tempstartindex 83
#   startindex 83
#   tempendindex 107
#   endindex 107
#      T1 align to plot: (190, 106)
#      T2 temp: (190, 106)
# 147
#   tempindex 71547
#   tempstartindex 83
#   startindex 83
#   tempendindex 107
#   endindex 107
#      T1 align to plot: (190, 106)
#      T2 temp: (190, 106)
# end active calculation
# start inactive calculation
# 0
#   tempindex 18104
#   tempstartindex 83
#   startindex 83
#   tempendindex 107
#   endindex 107
#      T1 align to plot: (190, 106)
#      T2 temp: (190, 106)
# 1
#   tempindex 18772
#   tempstartindex 83
#   startindex 83
#   tempendindex 107
#   endindex 107
#      T1 align to plot: (190, 106)
#      T2 temp: (190, 106)
# 2
#   tempindex 18778
#   tempstartindex 83
#   startindex 83
#   tempendindex 107
#   endindex 107
#      T1 align to plot: (190, 106)
#      T2 temp: (190, 106)
# 3
#   tempindex 18844
#   tempstartindex 83
#   startindex 83
#   tempendindex 107
#   endindex 107
#      T1 align to plot: (190, 106)
#      T2 temp: (190, 106)
# 4
#   tempindex 19213
#   tempstartindex 83
#   startindex 83
#   tempendindex 107
#   endindex 107
#      T1 align to plot: (190, 106)
#      T2 temp: (190, 106)
# 5
#   tempindex 21663
#   tempstartindex 83
#   startindex 83
#   tempendindex 107
#   endindex 107
#      T1 align to plot: (190, 106)
#      T2 temp: (190, 106)
# 6
#   tempindex 24540
#   tempstartindex 83
#   startindex 83
#   tempendindex 107
#   endindex 107
#      T1 align to plot: (190, 106)
#      T2 temp: (190, 106)
# 7
#   tempindex 32180
#   tempstartindex 83
#   startindex 83
#   tempendindex 107
#   endindex 107
#      T1 align to plot: (190, 106)
#      T2 temp: (190, 106)
# 8
#   tempindex 32184
#   tempstartindex 83
#   startindex 83
#   tempendindex 107
#   endindex 107
#      T1 align to plot: (190, 106)
#      T2 temp: (190, 106)
# 9
#   tempindex 32186
#   tempstartindex 83
#   startindex 83
#   tempendindex 107
#   endindex 107
#      T1 align to plot: (190, 106)
#      T2 temp: (190, 106)
# 10
#   tempindex 47297
#   tempstartindex 83
#   startindex 83
#   tempendindex 107
#   endindex 107
#      T1 align to plot: (190, 106)
#      T2 temp: (190, 106)
# end inactive calculation
# >>> LCDD-PGa1
# Signals.T: (53919, 19) Active: (87,) Inactive: (0,)
# start active calculation
# 0
#   tempindex 634
#   tempstartindex 83
#   startindex 83
#   tempendindex 107
#   endindex 107
#      T1 align to plot: (190, 19)
#      T2 temp: (190, 19)
# 1
#   tempindex 2202
#   tempstartindex 83
#   startindex 83
#   tempendindex 107
#   endindex 107
#      T1 align to plot: (190, 19)
#      T2 temp: (190, 19)
# 2
#   tempindex 2214
#   tempstartindex 83
#   startindex 83
#   tempendindex 107
#   endindex 107
#      T1 align to plot: (190, 19)
#      T2 temp: (190, 19)
# 3
#   tempindex 2253
#   tempstartindex 83
#   startindex 83
#   tempendindex 107
#   endindex 107
#      T1 align to plot: (190, 19)
#      T2 temp: (190, 19)
# 4
#   tempindex 2265
#   tempstartindex 83
#   startindex 83
#   tempendindex 107
#   endindex 107
#      T1 align to plot: (190, 19)
#      T2 temp: (190, 19)
# 5
#   tempindex 2777
#   tempstartindex 83
#   startindex 83
#   tempendindex 107
#   endindex 107
#      T1 align to plot: (190, 19)
#      T2 temp: (190, 19)
# 6
#   tempindex 2789
#   tempstartindex 83
#   startindex 83
#   tempendindex 107
#   endindex 107
#      T1 align to plot: (190, 19)
#      T2 temp: (190, 19)
# 7
#   tempindex 2807
#   tempstartindex 83
#   startindex 83
#   tempendindex 107
#   endindex 107
#      T1 align to plot: (190, 19)
#      T2 temp: (190, 19)
# 8
#   tempindex 2812
#   tempstartindex 83
#   startindex 83
#   tempendindex 107
#   endindex 107
#      T1 align to plot: (190, 19)
#      T2 temp: (190, 19)
# 9
#   tempindex 3025
#   tempstartindex 83
#   startindex 83
#   tempendindex 107
#   endindex 107
#      T1 align to plot: (190, 19)
#      T2 temp: (190, 19)
# 10
#   tempindex 3031
#   tempstartindex 83
#   startindex 83
#   tempendindex 107
#   endindex 107
#      T1 align to plot: (190, 19)
#      T2 temp: (190, 19)
# 11
#   tempindex 3638
#   tempstartindex 83
#   startindex 83
#   tempendindex 107
#   endindex 107
#      T1 align to plot: (190, 19)
#      T2 temp: (190, 19)
# 12
#   tempindex 3789
#   tempstartindex 83
#   startindex 83
#   tempendindex 107
#   endindex 107
#      T1 align to plot: (190, 19)
#      T2 temp: (190, 19)
# 13
#   tempindex 3827
#   tempstartindex 83
#   startindex 83
#   tempendindex 107
#   endindex 107
#      T1 align to plot: (190, 19)
#      T2 temp: (190, 19)
# 14
#   tempindex 3835
#   tempstartindex 83
#   startindex 83
#   tempendindex 107
#   endindex 107
#      T1 align to plot: (190, 19)
#      T2 temp: (190, 19)
# 15
#   tempindex 3838
#   tempstartindex 83
#   startindex 83
#   tempendindex 107
#   endindex 107
#      T1 align to plot: (190, 19)
#      T2 temp: (190, 19)
# 16
#   tempindex 3841
#   tempstartindex 83
#   startindex 83
#   tempendindex 107
#   endindex 107
#      T1 align to plot: (190, 19)
#      T2 temp: (190, 19)
# 17
#   tempindex 3843
#   tempstartindex 83
#   startindex 83
#   tempendindex 107
#   endindex 107
#      T1 align to plot: (190, 19)
#      T2 temp: (190, 19)
# 18
#   tempindex 3845
#   tempstartindex 83
#   startindex 83
#   tempendindex 107
#   endindex 107
#      T1 align to plot: (190, 19)
#      T2 temp: (190, 19)
# 19
#   tempindex 3852
#   tempstartindex 83
#   startindex 83
#   tempendindex 107
#   endindex 107
#      T1 align to plot: (190, 19)
#      T2 temp: (190, 19)
# 20
#   tempindex 3854
#   tempstartindex 83
#   startindex 83
#   tempendindex 107
#   endindex 107
#      T1 align to plot: (190, 19)
#      T2 temp: (190, 19)
# 21
#   tempindex 3862
#   tempstartindex 83
#   startindex 83
#   tempendindex 107
#   endindex 107
#      T1 align to plot: (190, 19)
#      T2 temp: (190, 19)
# 22
#   tempindex 3969
#   tempstartindex 83
#   startindex 83
#   tempendindex 107
#   endindex 107
#      T1 align to plot: (190, 19)
#      T2 temp: (190, 19)
# 23
#   tempindex 3981
#   tempstartindex 83
#   startindex 83
#   tempendindex 107
#   endindex 107
#      T1 align to plot: (190, 19)
#      T2 temp: (190, 19)
# 24
#   tempindex 4049
#   tempstartindex 83
#   startindex 83
#   tempendindex 107
#   endindex 107
#      T1 align to plot: (190, 19)
#      T2 temp: (190, 19)
# 25
#   tempindex 4065
#   tempstartindex 83
#   startindex 83
#   tempendindex 107
#   endindex 107
#      T1 align to plot: (190, 19)
#      T2 temp: (190, 19)
# 26
#   tempindex 4735
#   tempstartindex 83
#   startindex 83
#   tempendindex 107
#   endindex 107
#      T1 align to plot: (190, 19)
#      T2 temp: (190, 19)
# 27
#   tempindex 4742
#   tempstartindex 83
#   startindex 83
#   tempendindex 107
#   endindex 107
#      T1 align to plot: (190, 19)
#      T2 temp: (190, 19)
# 28
#   tempindex 5557
#   tempstartindex 83
#   startindex 83
#   tempendindex 107
#   endindex 107
#      T1 align to plot: (190, 19)
#      T2 temp: (190, 19)
# 29
#   tempindex 6976
#   tempstartindex 83
#   startindex 83
#   tempendindex 107
#   endindex 107
#      T1 align to plot: (190, 19)
#      T2 temp: (190, 19)
# 30
#   tempindex 7011
#   tempstartindex 83
#   startindex 83
#   tempendindex 107
#   endindex 107
#      T1 align to plot: (190, 19)
#      T2 temp: (190, 19)
# 31
#   tempindex 7427
#   tempstartindex 83
#   startindex 83
#   tempendindex 107
#   endindex 107
#      T1 align to plot: (190, 19)
#      T2 temp: (190, 19)
# 32
#   tempindex 7451
#   tempstartindex 83
#   startindex 83
#   tempendindex 107
#   endindex 107
#      T1 align to plot: (190, 19)
#      T2 temp: (190, 19)
# 33
#   tempindex 7456
#   tempstartindex 83
#   startindex 83
#   tempendindex 107
#   endindex 107
#      T1 align to plot: (190, 19)
#      T2 temp: (190, 19)
# 34
#   tempindex 7460
#   tempstartindex 83
#   startindex 83
#   tempendindex 107
#   endindex 107
#      T1 align to plot: (190, 19)
#      T2 temp: (190, 19)
# 35
#   tempindex 8424
#   tempstartindex 83
#   startindex 83
#   tempendindex 107
#   endindex 107
#      T1 align to plot: (190, 19)
#      T2 temp: (190, 19)
# 36
#   tempindex 8438
#   tempstartindex 83
#   startindex 83
#   tempendindex 107
#   endindex 107
#      T1 align to plot: (190, 19)
#      T2 temp: (190, 19)
# 37
#   tempindex 8643
#   tempstartindex 83
#   startindex 83
#   tempendindex 107
#   endindex 107
#      T1 align to plot: (190, 19)
#      T2 temp: (190, 19)
# 38
#   tempindex 12319
#   tempstartindex 83
#   startindex 83
#   tempendindex 107
#   endindex 107
#      T1 align to plot: (190, 19)
#      T2 temp: (190, 19)
# 39
#   tempindex 14607
#   tempstartindex 83
#   startindex 83
#   tempendindex 107
#   endindex 107
#      T1 align to plot: (190, 19)
#      T2 temp: (190, 19)
# 40
#   tempindex 14629
#   tempstartindex 83
#   startindex 83
#   tempendindex 107
#   endindex 107
#      T1 align to plot: (190, 19)
#      T2 temp: (190, 19)
# 41
#   tempindex 16341
#   tempstartindex 83
#   startindex 83
#   tempendindex 107
#   endindex 107
#      T1 align to plot: (190, 19)
#      T2 temp: (190, 19)
# 42
#   tempindex 16348
#   tempstartindex 83
#   startindex 83
#   tempendindex 107
#   endindex 107
#      T1 align to plot: (190, 19)
#      T2 temp: (190, 19)
# 43
#   tempindex 16350
#   tempstartindex 83
#   startindex 83
#   tempendindex 107
#   endindex 107
#      T1 align to plot: (190, 19)
#      T2 temp: (190, 19)
# 44
#   tempindex 16353
#   tempstartindex 83
#   startindex 83
#   tempendindex 107
#   endindex 107
#      T1 align to plot: (190, 19)
#      T2 temp: (190, 19)
# 45
#   tempindex 16368
#   tempstartindex 83
#   startindex 83
#   tempendindex 107
#   endindex 107
#      T1 align to plot: (190, 19)
#      T2 temp: (190, 19)
# 46
#   tempindex 16372
#   tempstartindex 83
#   startindex 83
#   tempendindex 107
#   endindex 107
#      T1 align to plot: (190, 19)
#      T2 temp: (190, 19)
# 47
#   tempindex 16388
#   tempstartindex 83
#   startindex 83
#   tempendindex 107
#   endindex 107
#      T1 align to plot: (190, 19)
#      T2 temp: (190, 19)
# 48
#   tempindex 16405
#   tempstartindex 83
#   startindex 83
#   tempendindex 107
#   endindex 107
#      T1 align to plot: (190, 19)
#      T2 temp: (190, 19)
# 49
#   tempindex 18518
#   tempstartindex 83
#   startindex 83
#   tempendindex 107
#   endindex 107
#      T1 align to plot: (190, 19)
#      T2 temp: (190, 19)
# 50
#   tempindex 25669
#   tempstartindex 83
#   startindex 83
#   tempendindex 107
#   endindex 107
#      T1 align to plot: (190, 19)
#      T2 temp: (190, 19)
# 51
#   tempindex 26365
#   tempstartindex 83
#   startindex 83
#   tempendindex 107
#   endindex 107
#      T1 align to plot: (190, 19)
#      T2 temp: (190, 19)
# 52
#   tempindex 27552
#   tempstartindex 83
#   startindex 83
#   tempendindex 107
#   endindex 107
#      T1 align to plot: (190, 19)
#      T2 temp: (190, 19)
# 53
#   tempindex 28210
#   tempstartindex 83
#   startindex 83
#   tempendindex 107
#   endindex 107
#      T1 align to plot: (190, 19)
#      T2 temp: (190, 19)
# 54
#   tempindex 31884
#   tempstartindex 83
#   startindex 83
#   tempendindex 107
#   endindex 107
#      T1 align to plot: (190, 19)
#      T2 temp: (190, 19)
# 55
#   tempindex 31907
#   tempstartindex 83
#   startindex 83
#   tempendindex 107
#   endindex 107
#      T1 align to plot: (190, 19)
#      T2 temp: (190, 19)
# 56
#   tempindex 31918
#   tempstartindex 83
#   startindex 83
#   tempendindex 107
#   endindex 107
#      T1 align to plot: (190, 19)
#      T2 temp: (190, 19)
# 57
#   tempindex 31932
#   tempstartindex 83
#   startindex 83
#   tempendindex 107
#   endindex 107
#      T1 align to plot: (190, 19)
#      T2 temp: (190, 19)
# 58
#   tempindex 31939
#   tempstartindex 83
#   startindex 83
#   tempendindex 107
#   endindex 107
#      T1 align to plot: (190, 19)
#      T2 temp: (190, 19)
# 59
#   tempindex 31948
#   tempstartindex 83
#   startindex 83
#   tempendindex 107
#   endindex 107
#      T1 align to plot: (190, 19)
#      T2 temp: (190, 19)
# 60
#   tempindex 37885
#   tempstartindex 83
#   startindex 83
#   tempendindex 107
#   endindex 107
#      T1 align to plot: (190, 19)
#      T2 temp: (190, 19)
# 61
#   tempindex 37892
#   tempstartindex 83
#   startindex 83
#   tempendindex 107
#   endindex 107
#      T1 align to plot: (190, 19)
#      T2 temp: (190, 19)
# 62
#   tempindex 39284
#   tempstartindex 83
#   startindex 83
#   tempendindex 107
#   endindex 107
#      T1 align to plot: (190, 19)
#      T2 temp: (190, 19)
# 63
#   tempindex 40322
#   tempstartindex 83
#   startindex 83
#   tempendindex 107
#   endindex 107
#      T1 align to plot: (190, 19)
#      T2 temp: (190, 19)
# 64
#   tempindex 40324
#   tempstartindex 83
#   startindex 83
#   tempendindex 107
#   endindex 107
#      T1 align to plot: (190, 19)
#      T2 temp: (190, 19)
# 65
#   tempindex 40467
#   tempstartindex 83
#   startindex 83
#   tempendindex 107
#   endindex 107
#      T1 align to plot: (190, 19)
#      T2 temp: (190, 19)
# 66
#   tempindex 43146
#   tempstartindex 83
#   startindex 83
#   tempendindex 107
#   endindex 107
#      T1 align to plot: (190, 19)
#      T2 temp: (190, 19)
# 67
#   tempindex 43149
#   tempstartindex 83
#   startindex 83
#   tempendindex 107
#   endindex 107
#      T1 align to plot: (190, 19)
#      T2 temp: (190, 19)
# 68
#   tempindex 43259
#   tempstartindex 83
#   startindex 83
#   tempendindex 107
#   endindex 107
#      T1 align to plot: (190, 19)
#      T2 temp: (190, 19)
# 69
#   tempindex 43280
#   tempstartindex 83
#   startindex 83
#   tempendindex 107
#   endindex 107
#      T1 align to plot: (190, 19)
#      T2 temp: (190, 19)
# 70
#   tempindex 43491
#   tempstartindex 83
#   startindex 83
#   tempendindex 107
#   endindex 107
#      T1 align to plot: (190, 19)
#      T2 temp: (190, 19)
# 71
#   tempindex 43507
#   tempstartindex 83
#   startindex 83
#   tempendindex 107
#   endindex 107
#      T1 align to plot: (190, 19)
#      T2 temp: (190, 19)
# 72
#   tempindex 43508
#   tempstartindex 83
#   startindex 83
#   tempendindex 107
#   endindex 107
#      T1 align to plot: (190, 19)
#      T2 temp: (190, 19)
# 73
#   tempindex 43518
#   tempstartindex 83
#   startindex 83
#   tempendindex 107
#   endindex 107
#      T1 align to plot: (190, 19)
#      T2 temp: (190, 19)
# 74
#   tempindex 44164
#   tempstartindex 83
#   startindex 83
#   tempendindex 107
#   endindex 107
#      T1 align to plot: (190, 19)
#      T2 temp: (190, 19)
# 75
#   tempindex 44897
#   tempstartindex 83
#   startindex 83
#   tempendindex 107
#   endindex 107
#      T1 align to plot: (190, 19)
#      T2 temp: (190, 19)
# 76
#   tempindex 45050
#   tempstartindex 83
#   startindex 83
#   tempendindex 107
#   endindex 107
#      T1 align to plot: (190, 19)
#      T2 temp: (190, 19)
# 77
#   tempindex 45066
#   tempstartindex 83
#   startindex 83
#   tempendindex 107
#   endindex 107
#      T1 align to plot: (190, 19)
#      T2 temp: (190, 19)
# 78
#   tempindex 47161
#   tempstartindex 83
#   startindex 83
#   tempendindex 107
#   endindex 107
#      T1 align to plot: (190, 19)
#      T2 temp: (190, 19)
# 79
#   tempindex 47171
#   tempstartindex 83
#   startindex 83
#   tempendindex 107
#   endindex 107
#      T1 align to plot: (190, 19)
#      T2 temp: (190, 19)
# 80
#   tempindex 47178
#   tempstartindex 83
#   startindex 83
#   tempendindex 107
#   endindex 107
#      T1 align to plot: (190, 19)
#      T2 temp: (190, 19)
# 81
#   tempindex 47184
#   tempstartindex 83
#   startindex 83
#   tempendindex 107
#   endindex 107
#      T1 align to plot: (190, 19)
#      T2 temp: (190, 19)
# 82
#   tempindex 47189
#   tempstartindex 83
#   startindex 83
#   tempendindex 107
#   endindex 107
#      T1 align to plot: (190, 19)
#      T2 temp: (190, 19)
# 83
#   tempindex 47194
#   tempstartindex 83
#   startindex 83
#   tempendindex 107
#   endindex 107
#      T1 align to plot: (190, 19)
#      T2 temp: (190, 19)
# 84
#   tempindex 47210
#   tempstartindex 83
#   startindex 83
#   tempendindex 107
#   endindex 107
#      T1 align to plot: (190, 19)
#      T2 temp: (190, 19)
# 85
#   tempindex 48101
#   tempstartindex 83
#   startindex 83
#   tempendindex 107
#   endindex 107
#      T1 align to plot: (190, 19)
#      T2 temp: (190, 19)
# 86
#   tempindex 48157
#   tempstartindex 83
#   startindex 83
#   tempendindex 107
#   endindex 107
#      T1 align to plot: (190, 19)
#      T2 temp: (190, 19)
# end active calculation
# start inactive calculation
# end inactive calculation
# >>> LCDD-PGa4
# Signals.T: (53919, 70) Active: (18,) Inactive: (0,)
# start active calculation
# 0
#   tempindex 172
#   tempstartindex 83
#   startindex 83
#   tempendindex 107
#   endindex 107
#      T1 align to plot: (190, 70)
#      T2 temp: (190, 70)
# 1
#   tempindex 174
#   tempstartindex 83
#   startindex 83
#   tempendindex 107
#   endindex 107
#      T1 align to plot: (190, 70)
#      T2 temp: (190, 70)
# 2
#   tempindex 178
#   tempstartindex 83
#   startindex 83
#   tempendindex 107
#   endindex 107
#      T1 align to plot: (190, 70)
#      T2 temp: (190, 70)
# 3
#   tempindex 2845
#   tempstartindex 83
#   startindex 83
#   tempendindex 107
#   endindex 107
#      T1 align to plot: (190, 70)
# ...
#   tempendindex 107
#   endindex 107
#      T1 align to plot: (190, 118)
#      T2 temp: (190, 118)
# 131
#   tempindex 38843
#   tempstartindex 83
#   startindex 83
#   tempendindex 107
#   endindex 107
#      T1 align to plot: (190, 118)
#      T2 temp: (190, 118)
# 132
#   tempindex 38846
#   tempstartindex 83
#   startindex 83
#   tempendindex 107
#   endindex 107
#      T1 align to plot: (190, 118)
#      T2 temp: (190, 118)
# 133
#   tempindex 38853
#   tempstartindex 83
#   startindex 83
#   tempendindex 107
#   endindex 107
#      T1 align to plot: (190, 118)
#      T2 temp: (190, 118)
# 134
#   tempindex 38954
#   tempstartindex 83
#   startindex 83
#   tempendindex 107
#   endindex 107
#      T1 align to plot: (190, 118)
#      T2 temp: (190, 118)
# 135
#   tempindex 39484
#   tempstartindex 83
#   startindex 83
#   tempendindex 107
#   endindex 107
#      T1 align to plot: (190, 118)
#      T2 temp: (190, 118)
# 136
#   tempindex 39489
#   tempstartindex 83
#   startindex 83
#   tempendindex 107
#   endindex 107
#      T1 align to plot: (190, 118)
#      T2 temp: (190, 118)
# 137
#   tempindex 39491
#   tempstartindex 83
#   startindex 83
#   tempendindex 107
#   endindex 107
#      T1 align to plot: (190, 118)
#      T2 temp: (190, 118)
# 138
#   tempindex 39493
#   tempstartindex 83
#   startindex 83
#   tempendindex 107
#   endindex 107
#      T1 align to plot: (190, 118)
#      T2 temp: (190, 118)
# 139
#   tempindex 39497
#   tempstartindex 83
#   startindex 83
#   tempendindex 107
#   endindex 107
#      T1 align to plot: (190, 118)
#      T2 temp: (190, 118)
# 140
#   tempindex 39512
#   tempstartindex 83
#   startindex 83
#   tempendindex 107
#   endindex 107
#      T1 align to plot: (190, 118)
#      T2 temp: (190, 118)
# 141
#   tempindex 39671
#   tempstartindex 83
#   startindex 83
#   tempendindex 107
#   endindex 107
#      T1 align to plot: (190, 118)
#      T2 temp: (190, 118)
# 142
#   tempindex 39677
#   tempstartindex 83
#   startindex 83
#   tempendindex 107
#   endindex 107
#      T1 align to plot: (190, 118)
#      T2 temp: (190, 118)
# 143
#   tempindex 39958
#   tempstartindex 83
#   startindex 83
#   tempendindex 107
#   endindex 107
#      T1 align to plot: (190, 118)
#      T2 temp: (190, 118)
# 144
#   tempindex 40477
#   tempstartindex 83
#   startindex 83
#   tempendindex 107
#   endindex 107
#      T1 align to plot: (190, 118)
#      T2 temp: (190, 118)
# 145
#   tempindex 40814
#   tempstartindex 83
#   startindex 83
#   tempendindex 107
#   endindex 107
#      T1 align to plot: (190, 118)
#      T2 temp: (190, 118)
# 146
#   tempindex 40817
#   tempstartindex 83
#   startindex 83
#   tempendindex 107
#   endindex 107
#      T1 align to plot: (190, 118)
#      T2 temp: (190, 118)
# 147
#   tempindex 41329
#   tempstartindex 83
#   startindex 83
#   tempendindex 107
#   endindex 107
#      T1 align to plot: (190, 118)
#      T2 temp: (190, 118)
# 148
#   tempindex 41604
#   tempstartindex 83
#   startindex 83
#   tempendindex 107
#   endindex 107
#      T1 align to plot: (190, 118)
#      T2 temp: (190, 118)
# 149
#   tempindex 43673
#   tempstartindex 83
#   startindex 83
#   tempendindex 107
#   endindex 107
#      T1 align to plot: (190, 118)
#      T2 temp: (190, 118)
# 150
#   tempindex 43683
#   tempstartindex 83
#   startindex 83
#   tempendindex 107
#   endindex 107
#      T1 align to plot: (190, 118)
#      T2 temp: (190, 118)
# 151
#   tempindex 43698
#   tempstartindex 83
#   startindex 83
#   tempendindex 107
#   endindex 107
#      T1 align to plot: (190, 118)
#      T2 temp: (190, 118)
# 152
#   tempindex 43962
#   tempstartindex 83
#   startindex 83
#   tempendindex 107
#   endindex 107
#      T1 align to plot: (190, 118)
#      T2 temp: (190, 118)
# 153
#   tempindex 44481
#   tempstartindex 83
#   startindex 83
#   tempendindex 107
#   endindex 107
#      T1 align to plot: (190, 118)
#      T2 temp: (190, 118)
# 154
#   tempindex 45141
#   tempstartindex 83
#   startindex 83
#   tempendindex 107
#   endindex 107
#      T1 align to plot: (190, 118)
#      T2 temp: (190, 118)
# 155
#   tempindex 45149
#   tempstartindex 83
#   startindex 83
#   tempendindex 107
#   endindex 107
#      T1 align to plot: (190, 118)
#      T2 temp: (190, 118)
# 156
#   tempindex 45543
#   tempstartindex 83
#   startindex 83
#   tempendindex 107
#   endindex 107
#      T1 align to plot: (190, 118)
#      T2 temp: (190, 118)
# 157
#   tempindex 45551
#   tempstartindex 83
#   startindex 83
#   tempendindex 107
#   endindex 107
#      T1 align to plot: (190, 118)
#      T2 temp: (190, 118)
# 158
#   tempindex 46730
#   tempstartindex 83
#   startindex 83
#   tempendindex 107
#   endindex 107
#      T1 align to plot: (190, 118)
#      T2 temp: (190, 118)
# end active calculation
# start inactive calculation
# end inactive calculation
# >>> LCDD-PGa-T3
# Signals.T: (53920, 103) Active: (24,) Inactive: (0,)
# start active calculation
# 0
#   tempindex 10933
#   tempstartindex 83
#   startindex 83
#   tempendindex 107
#   endindex 107
#      T1 align to plot: (190, 103)
#      T2 temp: (190, 103)
# 1
#   tempindex 10940
#   tempstartindex 83
#   startindex 83
#   tempendindex 107
#   endindex 107
#      T1 align to plot: (190, 103)
#      T2 temp: (190, 103)
# 2
#   tempindex 21910
#   tempstartindex 83
#   startindex 83
#   tempendindex 107
#   endindex 107
#      T1 align to plot: (190, 103)
#      T2 temp: (190, 103)
# 3
#   tempindex 21913
#   tempstartindex 83
#   startindex 83
#   tempendindex 107
#   endindex 107
#      T1 align to plot: (190, 103)
#      T2 temp: (190, 103)
# 4
#   tempindex 21916
#   tempstartindex 83
#   startindex 83
#   tempendindex 107
#   endindex 107
#      T1 align to plot: (190, 103)
#      T2 temp: (190, 103)
# 5
#   tempindex 29914
#   tempstartindex 83
#   startindex 83
#   tempendindex 107
#   endindex 107
#      T1 align to plot: (190, 103)
#      T2 temp: (190, 103)
# 6
#   tempindex 29921
#   tempstartindex 83
#   startindex 83
#   tempendindex 107
#   endindex 107
#      T1 align to plot: (190, 103)
#      T2 temp: (190, 103)
# 7
#   tempindex 34204
#   tempstartindex 83
#   startindex 83
#   tempendindex 107
#   endindex 107
#      T1 align to plot: (190, 103)
#      T2 temp: (190, 103)
# 8
#   tempindex 34205
#   tempstartindex 83
#   startindex 83
#   tempendindex 107
#   endindex 107
#      T1 align to plot: (190, 103)
#      T2 temp: (190, 103)
# 9
#   tempindex 34211
#   tempstartindex 83
#   startindex 83
#   tempendindex 107
#   endindex 107
#      T1 align to plot: (190, 103)
#      T2 temp: (190, 103)
# 10
#   tempindex 38692
#   tempstartindex 83
#   startindex 83
#   tempendindex 107
#   endindex 107
#      T1 align to plot: (190, 103)
#      T2 temp: (190, 103)
# 11
#   tempindex 40888
#   tempstartindex 83
#   startindex 83
#   tempendindex 107
#   endindex 107
#      T1 align to plot: (190, 103)
#      T2 temp: (190, 103)
# 12
#   tempindex 40890
#   tempstartindex 83
#   startindex 83
#   tempendindex 107
#   endindex 107
#      T1 align to plot: (190, 103)
#      T2 temp: (190, 103)
# 13
#   tempindex 44115
#   tempstartindex 83
#   startindex 83
#   tempendindex 107
#   endindex 107
#      T1 align to plot: (190, 103)
#      T2 temp: (190, 103)
# 14
#   tempindex 44117
#   tempstartindex 83
#   startindex 83
#   tempendindex 107
#   endindex 107
#      T1 align to plot: (190, 103)
#      T2 temp: (190, 103)
# 15
#   tempindex 44118
#   tempstartindex 83
#   startindex 83
#   tempendindex 107
#   endindex 107
#      T1 align to plot: (190, 103)
#      T2 temp: (190, 103)
# 16
#   tempindex 44125
#   tempstartindex 83
#   startindex 83
#   tempendindex 107
#   endindex 107
#      T1 align to plot: (190, 103)
#      T2 temp: (190, 103)
# 17
#   tempindex 44126
#   tempstartindex 83
#   startindex 83
#   tempendindex 107
#   endindex 107
#      T1 align to plot: (190, 103)
#      T2 temp: (190, 103)
# 18
#   tempindex 44430
#   tempstartindex 83
#   startindex 83
#   tempendindex 107
#   endindex 107
#      T1 align to plot: (190, 103)
#      T2 temp: (190, 103)
# 19
#   tempindex 45322
#   tempstartindex 83
#   startindex 83
#   tempendindex 107
#   endindex 107
#      T1 align to plot: (190, 103)
#      T2 temp: (190, 103)
# 20
#   tempindex 46261
#   tempstartindex 83
#   startindex 83
#   tempendindex 107
#   endindex 107
#      T1 align to plot: (190, 103)
#      T2 temp: (190, 103)
# 21
#   tempindex 46715
#   tempstartindex 83
#   startindex 83
#   tempendindex 107
#   endindex 107
#      T1 align to plot: (190, 103)
#      T2 temp: (190, 103)
# 22
#   tempindex 46758
#   tempstartindex 83
#   startindex 83
#   tempendindex 107
#   endindex 107
#      T1 align to plot: (190, 103)
#      T2 temp: (190, 103)
# 23
#   tempindex 46875
#   tempstartindex 83
#   startindex 83
#   tempendindex 107
#   endindex 107
#      T1 align to plot: (190, 103)
#      T2 temp: (190, 103)
# end active calculation
# start inactive calculation
# end inactive calculation
# >>> LCDD-PGa-T4
# Signals.T: (53921, 123) Active: (48,) Inactive: (0,)
# start active calculation
# 0
#   tempindex 16
#   tempstartindex 16
#   startindex 16
#   tempendindex 107
#   endindex 107
#      T1 align to plot: (123, 123)
#      T2 temp: (123, 123)
# 1
#   tempindex 27
#   tempstartindex 27
#   startindex 27
#   tempendindex 107
#   endindex 107
#      T1 align to plot: (134, 123)
#      T2 temp: (134, 123)
# 2
#   tempindex 96
#   tempstartindex 83
#   startindex 83
#   tempendindex 107
#   endindex 107
#      T1 align to plot: (190, 123)
#      T2 temp: (190, 123)
# 3
#   tempindex 231
#   tempstartindex 83
#   startindex 83
#   tempendindex 107
#   endindex 107
#      T1 align to plot: (190, 123)
#      T2 temp: (190, 123)
# 4
#   tempindex 609
#   tempstartindex 83
#   startindex 83
#   tempendindex 107
#   endindex 107
#      T1 align to plot: (190, 123)
#      T2 temp: (190, 123)
# 5
#   tempindex 4004
#   tempstartindex 83
#   startindex 83
#   tempendindex 107
#   endindex 107
#      T1 align to plot: (190, 123)
#      T2 temp: (190, 123)
# 6
#   tempindex 4056
#   tempstartindex 83
#   startindex 83
#   tempendindex 107
#   endindex 107
#      T1 align to plot: (190, 123)
#      T2 temp: (190, 123)
# 7
#   tempindex 8272
#   tempstartindex 83
#   startindex 83
#   tempendindex 107
#   endindex 107
#      T1 align to plot: (190, 123)
#      T2 temp: (190, 123)
# 8
#   tempindex 8303
#   tempstartindex 83
#   startindex 83
#   tempendindex 107
#   endindex 107
#      T1 align to plot: (190, 123)
#      T2 temp: (190, 123)
# 9
#   tempindex 17324
#   tempstartindex 83
#   startindex 83
#   tempendindex 107
#   endindex 107
#      T1 align to plot: (190, 123)
#      T2 temp: (190, 123)
# 10
#   tempindex 19055
#   tempstartindex 83
#   startindex 83
#   tempendindex 107
#   endindex 107
#      T1 align to plot: (190, 123)
#      T2 temp: (190, 123)
# 11
#   tempindex 19113
#   tempstartindex 83
#   startindex 83
#   tempendindex 107
#   endindex 107
#      T1 align to plot: (190, 123)
#      T2 temp: (190, 123)
# 12
#   tempindex 19205
#   tempstartindex 83
#   startindex 83
#   tempendindex 107
#   endindex 107
#      T1 align to plot: (190, 123)
#      T2 temp: (190, 123)
# 13
#   tempindex 19479
#   tempstartindex 83
#   startindex 83
#   tempendindex 107
#   endindex 107
#      T1 align to plot: (190, 123)
#      T2 temp: (190, 123)
# 14
#   tempindex 20128
#   tempstartindex 83
#   startindex 83
#   tempendindex 107
#   endindex 107
#      T1 align to plot: (190, 123)
#      T2 temp: (190, 123)
# 15
#   tempindex 20264
#   tempstartindex 83
#   startindex 83
#   tempendindex 107
#   endindex 107
#      T1 align to plot: (190, 123)
#      T2 temp: (190, 123)
# 16
#   tempindex 21311
#   tempstartindex 83
#   startindex 83
#   tempendindex 107
#   endindex 107
#      T1 align to plot: (190, 123)
#      T2 temp: (190, 123)
# 17
#   tempindex 22437
#   tempstartindex 83
#   startindex 83
#   tempendindex 107
#   endindex 107
#      T1 align to plot: (190, 123)
#      T2 temp: (190, 123)
# 18
#   tempindex 24747
#   tempstartindex 83
#   startindex 83
#   tempendindex 107
#   endindex 107
#      T1 align to plot: (190, 123)
#      T2 temp: (190, 123)
# 19
#   tempindex 24748
#   tempstartindex 83
#   startindex 83
#   tempendindex 107
#   endindex 107
#      T1 align to plot: (190, 123)
#      T2 temp: (190, 123)
# 20
#   tempindex 24750
#   tempstartindex 83
#   startindex 83
#   tempendindex 107
#   endindex 107
#      T1 align to plot: (190, 123)
#      T2 temp: (190, 123)
# 21
#   tempindex 30531
#   tempstartindex 83
#   startindex 83
#   tempendindex 107
#   endindex 107
#      T1 align to plot: (190, 123)
#      T2 temp: (190, 123)
# 22
#   tempindex 30845
#   tempstartindex 83
#   startindex 83
#   tempendindex 107
#   endindex 107
#      T1 align to plot: (190, 123)
#      T2 temp: (190, 123)
# 23
#   tempindex 31168
#   tempstartindex 83
#   startindex 83
#   tempendindex 107
#   endindex 107
#      T1 align to plot: (190, 123)
#      T2 temp: (190, 123)
# 24
#   tempindex 34335
#   tempstartindex 83
#   startindex 83
#   tempendindex 107
#   endindex 107
#      T1 align to plot: (190, 123)
#      T2 temp: (190, 123)
# 25
#   tempindex 34369
#   tempstartindex 83
#   startindex 83
#   tempendindex 107
#   endindex 107
#      T1 align to plot: (190, 123)
#      T2 temp: (190, 123)
# 26
#   tempindex 37631
#   tempstartindex 83
#   startindex 83
#   tempendindex 107
#   endindex 107
#      T1 align to plot: (190, 123)
#      T2 temp: (190, 123)
# 27
#   tempindex 37642
#   tempstartindex 83
#   startindex 83
#   tempendindex 107
#   endindex 107
#      T1 align to plot: (190, 123)
#      T2 temp: (190, 123)
# 28
#   tempindex 37717
#   tempstartindex 83
#   startindex 83
#   tempendindex 107
#   endindex 107
#      T1 align to plot: (190, 123)
#      T2 temp: (190, 123)
# 29
#   tempindex 40714
#   tempstartindex 83
#   startindex 83
#   tempendindex 107
#   endindex 107
#      T1 align to plot: (190, 123)
#      T2 temp: (190, 123)
# 30
#   tempindex 40741
#   tempstartindex 83
#   startindex 83
#   tempendindex 107
#   endindex 107
#      T1 align to plot: (190, 123)
#      T2 temp: (190, 123)
# 31
#   tempindex 41218
#   tempstartindex 83
#   startindex 83
#   tempendindex 107
#   endindex 107
#      T1 align to plot: (190, 123)
#      T2 temp: (190, 123)
# 32
#   tempindex 41479
#   tempstartindex 83
#   startindex 83
#   tempendindex 107
#   endindex 107
#      T1 align to plot: (190, 123)
#      T2 temp: (190, 123)
# 33
#   tempindex 42798
#   tempstartindex 83
#   startindex 83
#   tempendindex 107
#   endindex 107
#      T1 align to plot: (190, 123)
#      T2 temp: (190, 123)
# 34
#   tempindex 42799
#   tempstartindex 83
#   startindex 83
#   tempendindex 107
#   endindex 107
#      T1 align to plot: (190, 123)
#      T2 temp: (190, 123)
# 35
#   tempindex 43628
#   tempstartindex 83
#   startindex 83
#   tempendindex 107
#   endindex 107
#      T1 align to plot: (190, 123)
#      T2 temp: (190, 123)
# 36
#   tempindex 45296
#   tempstartindex 83
#   startindex 83
#   tempendindex 107
#   endindex 107
#      T1 align to plot: (190, 123)
#      T2 temp: (190, 123)
# 37
#   tempindex 45311
#   tempstartindex 83
#   startindex 83
#   tempendindex 107
#   endindex 107
#      T1 align to plot: (190, 123)
#      T2 temp: (190, 123)
# 38
#   tempindex 45313
#   tempstartindex 83
#   startindex 83
#   tempendindex 107
#   endindex 107
#      T1 align to plot: (190, 123)
#      T2 temp: (190, 123)
# 39
#   tempindex 46056
#   tempstartindex 83
#   startindex 83
#   tempendindex 107
#   endindex 107
#      T1 align to plot: (190, 123)
#      T2 temp: (190, 123)
# 40
#   tempindex 46301
#   tempstartindex 83
#   startindex 83
#   tempendindex 107
#   endindex 107
#      T1 align to plot: (190, 123)
#      T2 temp: (190, 123)
# 41
#   tempindex 46303
#   tempstartindex 83
#   startindex 83
#   tempendindex 107
#   endindex 107
#      T1 align to plot: (190, 123)
#      T2 temp: (190, 123)
# 42
#   tempindex 47171
#   tempstartindex 83
#   startindex 83
#   tempendindex 107
#   endindex 107
#      T1 align to plot: (190, 123)
#      T2 temp: (190, 123)
# 43
#   tempindex 47196
#   tempstartindex 83
#   startindex 83
#   tempendindex 107
#   endindex 107
#      T1 align to plot: (190, 123)
#      T2 temp: (190, 123)
# 44
#   tempindex 47832
#   tempstartindex 83
#   startindex 83
#   tempendindex 107
#   endindex 107
#      T1 align to plot: (190, 123)
#      T2 temp: (190, 123)
# 45
#   tempindex 47835
#   tempstartindex 83
#   startindex 83
#   tempendindex 107
#   endindex 107
#      T1 align to plot: (190, 123)
#      T2 temp: (190, 123)
# 46
#   tempindex 47851
#   tempstartindex 83
#   startindex 83
#   tempendindex 107
#   endindex 107
#      T1 align to plot: (190, 123)
#      T2 temp: (190, 123)
# 47
#   tempindex 47852
#   tempstartindex 83
#   startindex 83
#   tempendindex 107
#   endindex 107
#      T1 align to plot: (190, 123)
#      T2 temp: (190, 123)
# end active calculation
# start inactive calculation
# end inactive calculation
# >>> LCDD-PGaT2
# ---------------------------------------------------------------------------
# StopIteration                             Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_26344\2976067412.py in <module>
#       3 for animal in early_animals_of_interest:
#       4     print('>>>', animal)
# ----> 5     FOVs = next(os.walk(os.path.join(earlybasedir, animal)))[1]
#       6     for fov in sorted(FOVs):
#       7         temp_active = np.nan*np.ones((1, window_size))
#
# StopIteration:

# %%
#Middle population
excluded = []
for animal in middle_animals_of_interest:
    print('\n>>>', animal)
    FOVs = next(os.walk(os.path.join(middlebasedir, animal)))[1]
    for fov in sorted(FOVs):
            temp_active = np.nan*np.ones((1, window_size))
            temp_inactive = np.nan*np.ones((1, window_size))
            try:
                for fov in sorted(FOVs):
                    temp1, temp2, temp3, temp4, framerate = analyze_single_session(
                        #analysis parameters
                        os.path.join(middlebasedir, animal, fov), 
                        window_size, 
                        pre_window_size
                        )
                    #saving active and inactive signal data (includig NaN rows)
                    temp_active = np.vstack((temp_active, temp1))
                    temp_inactive = np.vstack((temp_inactive, temp2))
                    #saving aligned active and inactive lever data
                    temp_align_active_lever = temp3
                    temp_align_inactive_lever = temp4
            except Exception as e:
                    print('***ERROR:', e, '***')
                    excluded.append(animal)
            #files for signal data without NaN's
            np.save(os.path.join(middlebasedir, animal, fov, "active"), temp_active[1:,:])
            np.save(os.path.join(middlebasedir, animal, fov, "inactive"), temp_inactive[1:,:])
            #files for aligned lever data
            np.save(os.path.join(middlebasedir, animal, fov, "aligned_active_lever_data"), temp_align_active_lever)
            np.save(os.path.join(middlebasedir, animal, fov, "aligned_inactive_lever_data"), temp_align_inactive_lever)
print('Middle excluded animals:', excluded)
# Out:
# >>> LCDD-PGa1
# Signals.T: (53919, 18) Active: (6,) Inactive: (0,)
# start active calculation
# 0
#   tempindex 11379
#   tempstartindex 83
#   startindex 83
#   tempendindex 107
#   endindex 107
#      T1 align to plot: (190, 18)
#      T2 temp: (190, 18)
# 1
#   tempindex 11385
#   tempstartindex 83
#   startindex 83
#   tempendindex 107
#   endindex 107
#      T1 align to plot: (190, 18)
#      T2 temp: (190, 18)
# 2
#   tempindex 41539
#   tempstartindex 83
#   startindex 83
#   tempendindex 107
#   endindex 107
#      T1 align to plot: (190, 18)
#      T2 temp: (190, 18)
# 3
#   tempindex 41562
#   tempstartindex 83
#   startindex 83
#   tempendindex 107
#   endindex 107
#      T1 align to plot: (190, 18)
#      T2 temp: (190, 18)
# 4
#   tempindex 45193
#   tempstartindex 83
#   startindex 83
#   tempendindex 107
#   endindex 107
#      T1 align to plot: (190, 18)
#      T2 temp: (190, 18)
# 5
#   tempindex 45329
#   tempstartindex 83
#   startindex 83
#   tempendindex 107
#   endindex 107
#      T1 align to plot: (190, 18)
#      T2 temp: (190, 18)
# end active calculation
# start inactive calculation
# end inactive calculation
#
# >>> LCDD-PGa5
# C:\Users\jboqu\AppData\Local\Temp\ipykernel_26344\2002071708.py:206: RuntimeWarning: Mean of empty slice
#   populationdata_inactivelever = np.nanmean(align_inactivelever, axis=0).T-1
# Signals.T: (53919, 215) Active: (6,) Inactive: (0,)
# start active calculation
# 0
#   tempindex 459
#   tempstartindex 83
#   startindex 83
#   tempendindex 107
#   endindex 107
#      T1 align to plot: (190, 215)
#      T2 temp: (190, 215)
# 1
#   tempindex 490
#   tempstartindex 83
#   startindex 83
#   tempendindex 107
#   endindex 107
#      T1 align to plot: (190, 215)
#      T2 temp: (190, 215)
# 2
#   tempindex 533
#   tempstartindex 83
#   startindex 83
#   tempendindex 107
#   endindex 107
#      T1 align to plot: (190, 215)
#      T2 temp: (190, 215)
# 3
#   tempindex 545
#   tempstartindex 83
#   startindex 83
#   tempendindex 107
#   endindex 107
#      T1 align to plot: (190, 215)
#      T2 temp: (190, 215)
# 4
#   tempindex 9224
#   tempstartindex 83
#   startindex 83
#   tempendindex 107
#   endindex 107
#      T1 align to plot: (190, 215)
#      T2 temp: (190, 215)
# 5
#   tempindex 38931
#   tempstartindex 83
#   startindex 83
#   tempendindex 107
#   endindex 107
#      T1 align to plot: (190, 215)
#      T2 temp: (190, 215)
# end active calculation
# start inactive calculation
# end inactive calculation
#
# >>> LCDD-PGa-T2
# Signals.T: (53921, 146) Active: (0,) Inactive: (0,)
# start active calculation
# end active calculation
# start inactive calculation
# end inactive calculation
#
# >>> LCDD-PGa-T3
# C:\Users\jboqu\AppData\Local\Temp\ipykernel_26344\2002071708.py:200: RuntimeWarning: Mean of empty slice
#   populationdata_activelever = np.nanmean(align_activelever, axis=0).T-1
# Signals.T: (53919, 106) Active: (7,) Inactive: (14,)
# start active calculation
# 0
#   tempindex 41981
#   tempstartindex 83
#   startindex 83
#   tempendindex 107
#   endindex 107
#      T1 align to plot: (190, 106)
#      T2 temp: (190, 106)
# 1
#   tempindex 45498
#   tempstartindex 83
#   startindex 83
#   tempendindex 107
#   endindex 107
#      T1 align to plot: (190, 106)
#      T2 temp: (190, 106)
# 2
#   tempindex 45501
#   tempstartindex 83
#   startindex 83
#   tempendindex 107
#   endindex 107
#      T1 align to plot: (190, 106)
#      T2 temp: (190, 106)
# 3
#   tempindex 46850
#   tempstartindex 83
#   startindex 83
#   tempendindex 107
#   endindex 107
#      T1 align to plot: (190, 106)
#      T2 temp: (190, 106)
# 4
#   tempindex 47039
#   tempstartindex 83
#   startindex 83
#   tempendindex 107
#   endindex 107
#      T1 align to plot: (190, 106)
#      T2 temp: (190, 106)
# 5
#   tempindex 47053
#   tempstartindex 83
#   startindex 83
#   tempendindex 107
#   endindex 107
#      T1 align to plot: (190, 106)
#      T2 temp: (190, 106)
# 6
#   tempindex 47055
#   tempstartindex 83
#   startindex 83
#   tempendindex 107
#   endindex 107
#      T1 align to plot: (190, 106)
#      T2 temp: (190, 106)
# end active calculation
# start inactive calculation
# 0
#   tempindex 16758
#   tempstartindex 83
#   startindex 83
#   tempendindex 107
#   endindex 107
#      T1 align to plot: (190, 106)
#      T2 temp: (190, 106)
# 1
#   tempindex 16759
#   tempstartindex 83
#   startindex 83
#   tempendindex 107
#   endindex 107
#      T1 align to plot: (190, 106)
#      T2 temp: (190, 106)
# 2
#   tempindex 34646
#   tempstartindex 83
#   startindex 83
#   tempendindex 107
#   endindex 107
#      T1 align to plot: (190, 106)
#      T2 temp: (190, 106)
# 3
#   tempindex 41981
#   tempstartindex 83
#   startindex 83
#   tempendindex 107
#   endindex 107
#      T1 align to plot: (190, 106)
#      T2 temp: (190, 106)
# 4
#   tempindex 45498
#   tempstartindex 83
#   startindex 83
#   tempendindex 107
#   endindex 107
#      T1 align to plot: (190, 106)
#      T2 temp: (190, 106)
# 5
#   tempindex 45501
#   tempstartindex 83
#   startindex 83
#   tempendindex 107
#   endindex 107
#      T1 align to plot: (190, 106)
#      T2 temp: (190, 106)
# 6
#   tempindex 46850
#   tempstartindex 83
#   startindex 83
#   tempendindex 107
#   endindex 107
#      T1 align to plot: (190, 106)
#      T2 temp: (190, 106)
# 7
#   tempindex 47039
#   tempstartindex 83
#   startindex 83
#   tempendindex 107
#   endindex 107
#      T1 align to plot: (190, 106)
#      T2 temp: (190, 106)
# 8
#   tempindex 47053
#   tempstartindex 83
#   startindex 83
#   tempendindex 107
#   endindex 107
#      T1 align to plot: (190, 106)
#      T2 temp: (190, 106)
# 9
#   tempindex 47055
#   tempstartindex 83
#   startindex 83
#   tempendindex 107
#   endindex 107
#      T1 align to plot: (190, 106)
#      T2 temp: (190, 106)
# 10
#   tempindex 48402
#   tempstartindex 83
#   startindex 83
#   tempendindex 107
#   endindex 107
#      T1 align to plot: (190, 106)
#      T2 temp: (190, 106)
# 11
#   tempindex 48408
#   tempstartindex 83
#   startindex 83
#   tempendindex 107
#   endindex 107
#      T1 align to plot: (190, 106)
#      T2 temp: (190, 106)
# 12
#   tempindex 48409
#   tempstartindex 83
#   startindex 83
#   tempendindex 107
#   endindex 107
#      T1 align to plot: (190, 106)
#      T2 temp: (190, 106)
# 13
#   tempindex 52110
#   tempstartindex 83
#   startindex 83
#   tempendindex 107
#   endindex 107
#      T1 align to plot: (190, 106)
#      T2 temp: (190, 106)
# end inactive calculation
#
# >>> PGa-T1
# Signals.T: (53806, 150) Active: (7,) Inactive: (0,)
# start active calculation
# 0
#   tempindex 22840
#   tempstartindex 83
#   startindex 83
#   tempendindex 107
#   endindex 107
#      T1 align to plot: (190, 150)
#      T2 temp: (190, 150)
# 1
#   tempindex 29777
#   tempstartindex 83
#   startindex 83
#   tempendindex 107
#   endindex 107
#      T1 align to plot: (190, 150)
#      T2 temp: (190, 150)
# 2
#   tempindex 31203
#   tempstartindex 83
#   startindex 83
#   tempendindex 107
#   endindex 107
#      T1 align to plot: (190, 150)
#      T2 temp: (190, 150)
# 3
#   tempindex 31293
#   tempstartindex 83
#   startindex 83
#   tempendindex 107
#   endindex 107
#      T1 align to plot: (190, 150)
#      T2 temp: (190, 150)
# 4
#   tempindex 36386
#   tempstartindex 83
#   startindex 83
#   tempendindex 107
#   endindex 107
#      T1 align to plot: (190, 150)
#      T2 temp: (190, 150)
# 5
#   tempindex 39252
#   tempstartindex 83
#   startindex 83
#   tempendindex 107
#   endindex 107
#      T1 align to plot: (190, 150)
#      T2 temp: (190, 150)
# 6
#   tempindex 41297
#   tempstartindex 83
#   startindex 83
#   tempendindex 107
#   endindex 107
#      T1 align to plot: (190, 150)
#      T2 temp: (190, 150)
# end active calculation
# start inactive calculation
# end inactive calculation
#
# >>> PGa-T2
# Signals.T: (54000, 148) Active: (6,) Inactive: (0,)
# start active calculation
# 0
#   tempindex 17287
#   tempstartindex 83
#   startindex 83
#   tempendindex 107
#   endindex 107
#      T1 align to plot: (190, 148)
#      T2 temp: (190, 148)
# 1
#   tempindex 25193
#   tempstartindex 83
#   startindex 83
#   tempendindex 107
#   endindex 107
#      T1 align to plot: (190, 148)
#      T2 temp: (190, 148)
# 2
#   tempindex 33692
#   tempstartindex 83
#   startindex 83
#   tempendindex 107
#   endindex 107
#      T1 align to plot: (190, 148)
#      T2 temp: (190, 148)
# 3
#   tempindex 34906
#   tempstartindex 83
#   startindex 83
#   tempendindex 107
#   endindex 107
#      T1 align to plot: (190, 148)
#      T2 temp: (190, 148)
# 4
#   tempindex 40249
#   tempstartindex 83
#   startindex 83
#   tempendindex 107
#   endindex 107
#      T1 align to plot: (190, 148)
#      T2 temp: (190, 148)
# 5
#   tempindex 44293
#   tempstartindex 83
#   startindex 83
#   tempendindex 107
#   endindex 107
#      T1 align to plot: (190, 148)
#      T2 temp: (190, 148)
# end active calculation
# start inactive calculation
# end inactive calculation
# Middle excluded animals: []

# %%
#Late population
excluded = []
for animal in late_animals_of_interest:
    print('>>>', animal)
    FOVs = next(os.walk(os.path.join(latebasedir, animal)))[1]
    for fov in sorted(FOVs):
            temp_active = np.nan*np.ones((1, window_size))
            temp_inactive = np.nan*np.ones((1, window_size))
            for fov in sorted(FOVs):
                try:
                    temp1, temp2, temp3, temp4, framerate = analyze_single_session(
                        #analysis parameters
                        os.path.join(latebasedir, animal, fov), 
                        window_size, 
                        pre_window_size
                        )
                    #saving active and inactive signal data (includig NaN rows)
                    print('Temp active shape:', temp_active.shape, 'Temp1 shape:', temp1.shape)
                    temp_active = np.vstack((temp_active, temp1))
                    temp_inactive = np.vstack((temp_inactive, temp2))
                    #saving aligned active and inactive lever data
                    temp_align_active_lever = temp3
                    temp_align_inactive_lever = temp4
                except Exception as e:
                    print('***ERROR:', e, '***')
                    excluded.append(animal)
                #files for signal data without NaN's
                np.save(os.path.join(latebasedir, animal, fov, "active"), temp_active[1:,:])
                np.save(os.path.join(latebasedir, animal, fov, "inactive"), temp_inactive[1:,:])
                #files for aligned lever data
                np.save(os.path.join(latebasedir, animal, fov, "aligned_active_lever_data"), temp_align_active_lever)
                np.save(os.path.join(latebasedir, animal, fov, "aligned_inactive_lever_data"), temp_align_inactive_lever)
print('Late excluded animals:', excluded)
# Out:
# Late excluded animals: []

# %% [markdown]
# ### Stacking data

# %% [markdown]
# #### All population data

# %%
#method for stacking data
def stack_data(indir, animals_of_interest, window, signals_file, aligned_levers_file):
    temp_data = np.nan*np.ones((1, window))
    for animal in animals_of_interest:
            FOVs = next(os.walk(os.path.join(indir, animal)))[1]
            for fov in sorted(FOVs):
                    try:
                        #load in data
                        signal_data = np.load(os.path.join(indir, animal, fov, signals_file))
                        lever_data = np.load(os.path.join(indir, animal, fov, aligned_levers_file))
                        #stack data
                        temp_data = np.vstack((temp_data, signal_data))
                    except Exception as e:
                        print('***ERROR:', e, ' ***')
    data = temp_data[1:,:]
    return(data, lever_data)

# %%
#stacking early data

#early active data
temp_early_active, early_active_levers = stack_data(earlybasedir, early_animals_of_interest, window_size, "active.npy", 'aligned_active_lever_data.npy')

#num neurons
numneurons_early_active = temp_early_active.shape[0]

#calculating population data - baseline
baseline = np.mean(temp_early_active[:,baselinefirstframe:baselinelastframe], axis=1)
early_active = temp_early_active - baseline[:,None]

#sorting data
tempresponse = np.nanmean(early_active[:,pre_window_size-(1*int(framerate)):pre_window_size+1*int(framerate)], axis=1)
sortresponse_early_active = np.argsort(tempresponse)[::-1]

#calculating the mean using pandas
early_active_mean = np.nanmean(early_active, axis=0)


#early inactive data
temp_early_inactive, early_inactive_levers = stack_data(earlybasedir, early_animals_of_interest, window_size, "inactive.npy", 'aligned_inactive_lever_data.npy')

#num neurons
numneurons_early_inactive = temp_early_inactive.shape[0]

#calculating population data - baseline
baseline = np.mean(temp_early_inactive[:,baselinefirstframe:baselinelastframe], axis=1)
early_inactive = temp_early_inactive - baseline[:,None]

#sorting data
tempresponse = np.nanmean(early_inactive[:,pre_window_size-(1*int(framerate)):pre_window_size+1*int(framerate)], axis=1)
sortresponse_early_inactive = np.argsort(tempresponse)[::-1]

#calculating the mean using pandas
early_inactive_mean = np.nanmean(early_inactive, axis=0)

print('Active shape:', early_active.shape)
print('Active lever shape:', early_active_levers.shape)
print('Inative shape:', early_inactive.shape)
print('Inctive lever shape:', early_inactive_levers.shape)
# Out:
# Active shape: (1401, 190)
# Active lever shape: (7, 190, 110)
# Inative shape: (1401, 190)
# Inctive lever shape: (0, 190, 110)
# C:\Users\jboqu\AppData\Local\Temp\ipykernel_5372\2332505228.py:32: RuntimeWarning: Mean of empty slice
#   tempresponse = np.nanmean(early_inactive[:,pre_window_size-(1*int(framerate)):pre_window_size+1*int(framerate)], axis=1)

# %%
#stacking middle data

#middle active data
temp_middle_active, middle_active_levers = stack_data(middlebasedir, middle_animals_of_interest, window_size, "active.npy", 'aligned_active_lever_data.npy')

#num neurons is length of data
numneurons_middle_active = temp_middle_active.shape[0]

#calculating population data - baseline
baseline = np.mean(temp_middle_active[:,baselinefirstframe:baselinelastframe], axis=1)
middle_active = temp_middle_active - baseline[:,None]

#sorting data
tempresponse = np.nanmean(middle_active[:,pre_window_size-(1*int(framerate)):pre_window_size+1*int(framerate)], axis=1)
sortresponse_middle_active = np.argsort(tempresponse)[::-1]

#calculating the mean
middle_active_mean = np.nanmean(middle_active, axis=0)


#middle inactive data
temp_middle_inactive, middle_inactive_levers = stack_data(middlebasedir, middle_animals_of_interest, window_size, "inactive.npy", 'aligned_inactive_lever_data.npy')

#num neurons is length of data
numneurons_middle_inactive = temp_middle_inactive.shape[0]

#calculating population data - baseline
baseline = np.mean(temp_middle_inactive[:,baselinefirstframe:baselinelastframe], axis=1)
middle_inactive = temp_middle_inactive - baseline[:,None]

#sorting data
tempresponse = np.nanmean(middle_inactive[:,pre_window_size-(1*int(framerate)):pre_window_size+1*int(framerate)], axis=1)
sortresponse_middle_inactive = np.argsort(tempresponse)[::-1]

#calculating the mean
middle_inactive_mean = np.nanmean(middle_inactive, axis=0)

print('Active shape:', middle_active.shape)
print('Active lever shape:', middle_active_levers.shape)
print('Inative shape:', middle_inactive.shape)
print('Inctive lever shape:', middle_inactive_levers.shape)
# Out:
# Active shape: (783, 190)
# Active lever shape: (6, 190, 148)
# Inative shape: (783, 190)
# Inctive lever shape: (0, 190, 148)
# C:\Users\jboqu\AppData\Local\Temp\ipykernel_5372\1902834105.py:14: RuntimeWarning: Mean of empty slice
#   tempresponse = np.nanmean(middle_active[:,pre_window_size-(1*int(framerate)):pre_window_size+1*int(framerate)], axis=1)
# C:\Users\jboqu\AppData\Local\Temp\ipykernel_5372\1902834105.py:32: RuntimeWarning: Mean of empty slice
#   tempresponse = np.nanmean(middle_inactive[:,pre_window_size-(1*int(framerate)):pre_window_size+1*int(framerate)], axis=1)

# %% [markdown]
# #### Population data based on lever presses

# %%
#method for matching neurons to clusters based on criteria
def find_indexes(indir, sub_animals_of_interest_array, original_full_stack, signal_file, cluster_labels_file):
    indexes = []
    for animal in sub_animals_of_interest_array:
        FOVs = next(os.walk(os.path.join(indir, animal)))[1]
        for fov in sorted(FOVs):
            signal_data = np.load(os.path.join(indir, animal, fov, signal_file))
            for neuron in range(len(signal_data)):
                for row in range(len(original_full_stack)):
                    if np.equal(signal_data[neuron], original_full_stack[row])[0]==True:
                        indexes.append({'Animal': animal, 'Stack index': row, 'Cluster': cluster_labels_file[row]})
    indexes = pd.DataFrame(indexes)
    return(indexes)

# %%
#creating array of animals that meet lever press requirement

req_presses = 6

#early animals
sub_early = []
for animal in early_animals_of_interest:
    FOVs = next(os.walk(os.path.join(earlybasedir, animal)))[1]
    for fov in sorted(FOVs):
        lever_data = np.load(os.path.join(earlybasedir, animal, fov, 'aligned_inactive_lever_data.npy'))
        num_presses = lever_data.shape[0]
        if num_presses > req_presses:
            sub_early.append(animal)

#middle animals
sub_middle = []
for animal in middle_animals_of_interest:
    FOVs = next(os.walk(os.path.join(middlebasedir, animal)))[1]
    for fov in sorted(FOVs):
        lever_data = np.load(os.path.join(middlebasedir, animal, fov, 'aligned_inactive_lever_data.npy'))
        num_presses = lever_data.shape[0]
        if num_presses > req_presses:
            sub_middle.append(animal)

print('Early animals with sufficient presses:', sub_early)
print('Middle animals with sufficient presses:', sub_middle)
# Out:
# Early animals with sufficient presses: ['ER-L1', 'ER-L2', 'PGa-T2']
# Middle animals with sufficient presses: ['LCDD-PGa-T3']

# %%
#early data

#dataframe of female animal active data indexes
sub_early_active_df = find_indexes(earlybasedir, sub_early, temp_early_active, 'active.npy', early_newlabels)

temp_stack = np.nan*np.ones((1, window_size))
for index in sub_early_active_df['Stack index']:
    temp_stack = np.vstack((temp_stack, early_active[index]))
sub_early_active = temp_stack[1:,:]

#num neurons
numneurons_sub_early_active = sub_early_active.shape[0]

#calculating population data - baseline
baseline = np.mean(sub_early_active[:,baselinefirstframe:baselinelastframe], axis=1)
sub_early_active_minus_baseline = sub_early_active - baseline[:,None]

#sorting data
tempresponse = np.nanmean(sub_early_active_minus_baseline[:,pre_window_size-(1*int(framerate)):pre_window_size+1*int(framerate)], axis=1)
sortresponse_sub_early_active = np.argsort(tempresponse)[::-1]

#calculating the mean using pandas
sub_early_active_mean = np.nanmean(sub_early_active, axis=0)



#dataframe of female animal active data indexes
sub_early_inactive_df = find_indexes(earlybasedir, sub_early, temp_early_inactive, 'inactive.npy', early_newlabels)

temp_stack = np.nan*np.ones((1, window_size))
for index in sub_early_inactive_df['Stack index']:
    temp_stack = np.vstack((temp_stack, early_inactive[index]))
sub_early_inactive = temp_stack[1:,:]

#num neurons
numneurons_sub_early_inactive = sub_early_inactive.shape[0]

#calculating population data - baseline
baseline = np.mean(sub_early_inactive[:,baselinefirstframe:baselinelastframe], axis=1)
sub_early_inactive_minus_baseline = sub_early_inactive - baseline[:,None]

#sorting data
tempresponse = np.nanmean(sub_early_inactive_minus_baseline[:,pre_window_size-(1*int(framerate)):pre_window_size+1*int(framerate)], axis=1)
sortresponse_sub_early_inactive = np.argsort(tempresponse)[::-1]

#calculating the mean using pandas
sub_early_inactive_mean = np.nanmean(sub_early_inactive, axis=0)

# %%
#middle data

#dataframe of female animal active data indexes
sub_middle_active_df = find_indexes(middlebasedir, sub_middle, temp_middle_active, 'active.npy', middle_newlabels)

temp_stack = np.nan*np.ones((1, window_size))
for index in sub_middle_active_df['Stack index']:
    temp_stack = np.vstack((temp_stack, middle_active[index]))
sub_middle_active = temp_stack[1:,:]

#num neurons
numneurons_sub_middle_active = sub_middle_active.shape[0]

#calculating population data - baseline
baseline = np.mean(sub_middle_active[:,baselinefirstframe:baselinelastframe], axis=1)
sub_middle_active_minus_baseline = sub_middle_active - baseline[:,None]

#sorting data
tempresponse = np.nanmean(sub_middle_active_minus_baseline[:,pre_window_size-(1*int(framerate)):pre_window_size+1*int(framerate)], axis=1)
sortresponse_sub_middle_active = np.argsort(tempresponse)[::-1]

#calculating the mean using pandas
sub_middle_active_mean = np.nanmean(sub_middle_active, axis=0)



#dataframe of female animal active data indexes
sub_middle_inactive_df = find_indexes(middlebasedir, sub_middle, temp_middle_inactive, 'inactive.npy', middle_newlabels)

temp_stack = np.nan*np.ones((1, window_size))
for index in sub_middle_inactive_df['Stack index']:
    temp_stack = np.vstack((temp_stack, middle_inactive[index]))
sub_middle_inactive = temp_stack[1:,:]

#num neurons
numneurons_sub_middle_inactive = sub_middle_inactive.shape[0]

#calculating population data - baseline
baseline = np.mean(sub_middle_inactive[:,baselinefirstframe:baselinelastframe], axis=1)
sub_middle_inactive_minus_baseline = sub_middle_inactive - baseline[:,None]

#sorting data
tempresponse = np.nanmean(sub_middle_inactive_minus_baseline[:,pre_window_size-(1*int(framerate)):pre_window_size+1*int(framerate)], axis=1)
sortresponse_sub_middle_inactive = np.argsort(tempresponse)[::-1]

#calculating the mean using pandas
sub_middle_inactive_mean = np.nanmean(sub_middle_inactive, axis=0)

# %% [markdown]
# ### Plots

# %% [markdown]
# #### All data

# %%
#filter out the NaN values
def filter_NAN(processed_data, windowsize, prewindowsize, framerate):
        filtered_stack = np.nan*np.ones((1, windowsize))
        for row in processed_data:
                if np.isfinite(row[0]):
                        filtered_stack = np.vstack((filtered_stack, row))
        filtered_stack = filtered_stack[1:,:]
        response = np.nanmean(filtered_stack[:,prewindowsize-(1*int(framerate)):prewindowsize+1*int(framerate)], axis=1)
        sortresponse = np.argsort(response)[::-1]
        return(filtered_stack, sortresponse)

# %%
#plot

# initialize the plot
# 2 rows and 3 columns of graphs; may end up with blank column
fig, axs = plt.subplots(3, 2, figsize=(11, 11))
sns.set_style('white')

# setting max/min variables
cmax = .1
cmin = -cmax
ymax = .1
ymin = -ymax

# early active plots
ax = axs[0, 0]

# heatmap
hm = sns.heatmap(early_active[sortresponse_early_active,:], ax=ax, vmax=cmax, vmin=cmin, linewidth=0,
                 cmap=sns.diverging_palette(
                     154, 308, n=230, s=100, sep=50, center='dark'),
                 cbar_kws={'label': '$\Delta$F/F'}, xticklabels=False,  yticklabels=False)  # sets tick label increments

# color bar
cbar = hm.collections[0].colorbar
cbar.set_ticks([-.1, .1])
cbar.set_ticklabels([cmin, cmax])
ax.set(xticks=[0, pre_window_size, window_size-1]) #<-- set tick index
ax.set(xticklabels=["-10", "0", "13"]) #<-- set tick labels

#lines and labels
ax.grid(False)
ax.set_title(plot_titles[0]+"-ACTIVE", fontweight="bold", fontsize=14)
ax.set_ylabel('%s Neurons' % numneurons_sub_early_active, fontsize=12)
ax.plot([pre_window_size, pre_window_size],
        [0, numneurons_early_active], '--k', linewidth=1.5, color='white') #leverpress line <-- change line color

# line plot
ax = axs[2, 0]
ax.plot(early_active_mean)
ax.plot(early_inactive_mean)
ax.set_ylim([-.07, .07])
ax.plot([0, window_size], [0, 0], '--k', linewidth=0.5)
ax.axvline(pre_window_size, color='black', linestyle='--')
ax.legend(['Active', 'Inactive'])

# early inactive plots (sorted to active plot)
ax = axs[1, 0]

#filtering NaN's
sorted_early_inactive, inactive_sort = filter_NAN(early_inactive, window_size, pre_window_size, framerate)

# heatmap
hm = sns.heatmap(sorted_early_inactive[inactive_sort,:], ax=ax, vmax=cmax, vmin=cmin, linewidth=0,
                 cmap=sns.diverging_palette(
                     154, 308, n=230, s=100, sep=50, center='dark'),
                 cbar_kws={'label': '$\Delta$F/F'}, xticklabels=False,  yticklabels=False)  # sets tick label increments

# colorbar
cbar = hm.collections[0].colorbar
cbar.set_ticks([-.1, .1])
cbar.set_ticklabels([cmin, cmax])
ax.set(xticks=[0, pre_window_size, window_size-1])
ax.set(xticklabels=["-10", "0","13"])

#lines and labels
ax.grid(False)
ax.set_title(plot_titles[0]+"-INACTIVE", fontweight="bold", fontsize=14)
ax.set_ylabel('%s Neurons' % sorted_early_inactive.shape[0], fontsize=12)
ax.set_xlabel('Time (sec)', fontsize=12)
ax.plot([pre_window_size, pre_window_size],
        [0, numneurons_early_inactive], '--', linewidth=1.5, color='white')

# middle active plots
ax = axs[0, 1]

sorted_middle_active, active_sort = filter_NAN(middle_active, window_size, pre_window_size, framerate)

# heatmap
hm = sns.heatmap(sorted_middle_active[active_sort, :], ax=ax, vmax=cmax, vmin=cmin, linewidth=0,
                 cmap=sns.diverging_palette(
                     154, 308, n=230, s=100, sep=50, center='dark'),
                 cbar_kws={'label': '$\Delta$F/F'}, xticklabels=False,  yticklabels=False)  # sets tick label increments

# color bar
cbar = hm.collections[0].colorbar
cbar.set_ticks([-.1, .1])
cbar.set_ticklabels([cmin, cmax])
ax.set(xticks=[0, pre_window_size, window_size-1])
ax.set(xticklabels=["-10", "0","13"])

#lines and labels
ax.grid(False)
ax.set_title(plot_titles[1]+"-ACTIVE", fontweight="bold", fontsize=14)
ax.set_ylabel('%s Neurons' % numneurons_middle_active, fontsize=12)
ax.plot([pre_window_size, pre_window_size],
        [0, numneurons_middle_active], '--', linewidth=1.5, color='white')

# line plot
ax = axs[2, 1]
ax.plot(middle_active_mean)
ax.plot(middle_inactive_mean)
ax.set_ylim([-.07, .07])
ax.plot([0, window_size], [0, 0], '--k', linewidth=0.5)
ax.axvline(pre_window_size, color='black', linestyle='--')
ax.legend(['Active', 'Inactive'])

# middle inactive plots
ax = axs[1, 1]

#filtering NaN's
sorted_middle_inactive, inactive_sort = filter_NAN(middle_inactive, window_size, pre_window_size, framerate)

# heatmap
hm = sns.heatmap(sorted_middle_inactive[inactive_sort,:], ax=ax, vmax=cmax, vmin=cmin, linewidth=0,
                 cmap=sns.diverging_palette(
                     154, 308, n=230, s=100, sep=50, center='dark'),
                 cbar_kws={'label': '$\Delta$F/F'}, xticklabels=False,  yticklabels=False)  # sets tick label increments

# colorbar
cbar = hm.collections[0].colorbar
cbar.set_ticks([-.1, .1])
cbar.set_ticklabels([cmin, cmax])
ax.set(xticks=[0, pre_window_size, window_size-1])
ax.set(xticklabels=["-10", "0","13"])

#lines and labels
ax.grid(False)
ax.set_title(plot_titles[1]+"-INACTIVE", fontweight="bold", fontsize=14)
ax.set_ylabel('%s Neurons' % sorted_middle_inactive.shape[0], fontsize=12)
ax.set_xlabel('Time (sec)', fontsize=12)
ax.plot([pre_window_size, pre_window_size],
        [0, numneurons_middle_inactive], '--', linewidth=1.5, color='white')
# Out:
# C:\Users\jboqu\AppData\Local\Temp\ipykernel_8340\2414145257.py:34: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "--k" (-> color='k'). The keyword argument will take precedence.
#   ax.plot([pre_window_size, pre_window_size],

# %%
#save fig
fig.savefig(os.path.join(results, 'population', 'active-inactive-all', 'PFC_HEROIN_SA_Extinction_active-inactive-all_population_heatmaps.PDF'), format='PDF')
fig.savefig(os.path.join(results, 'population', 'active-inactive-all', 'PFC_HEROIN_SA_Extinction_active-inactive-all_population_heatmaps.PNG'), format='PNG')

# %% [markdown]
# #### Population data based on lever presses

# %%
#plot

# initialize the plot
# 2 rows and 3 columns of graphs; may end up with blank column
fig, axs = plt.subplots(3, 2, figsize=(11, 11))
sns.set_style('white')

# setting max/min variables
cmax = .1
cmin = -cmax
ymax = .1
ymin = -ymax

# early active plots
ax = axs[0, 0]

# heatmap
hm = sns.heatmap(sub_early_active[sortresponse_sub_early_active,:], ax=ax, vmax=cmax, vmin=cmin, linewidth=0,
                 cmap=sns.diverging_palette(
                     154, 308, n=230, s=100, sep=50, center='dark'),
                 cbar_kws={'label': '$\Delta$F/F'}, xticklabels=False,  yticklabels=False)  # sets tick label increments

# color bar
cbar = hm.collections[0].colorbar
cbar.set_ticks([-.1, .1])
cbar.set_ticklabels([cmin, cmax])
ax.set(xticks=[0, pre_window_size, window_size-1]) #<-- set tick index
ax.set(xticklabels=["-10", "0", "13"]) #<-- set tick labels

#lines and labels
ax.grid(False)
ax.set_title(plot_titles[0]+"-ACTIVE", fontweight="bold", fontsize=14)
ax.set_ylabel('%s Neurons' % numneurons_sub_early_active, fontsize=12)
ax.plot([pre_window_size, pre_window_size],
        [0, numneurons_sub_early_active], '--k', linewidth=1.5, color='white') #leverpress line <-- change line color

# line plot
ax = axs[2, 0]
ax.plot(sub_early_active_mean)
ax.plot(sub_early_inactive_mean)
ax.set_ylim([-.07, .07])
ax.plot([0, window_size], [0, 0], '--k', linewidth=0.5)
ax.axvline(pre_window_size, color='black', linestyle='--')
ax.legend(['Active', 'Inactive'])

# early inactive plots (sorted to active plot)
ax = axs[1, 0]

#filtering NaN's
sorted_sub_early_inactive, inactive_sort = filter_NAN(sub_early_inactive, window_size, pre_window_size, framerate)

# heatmap
hm = sns.heatmap(sorted_sub_early_inactive[inactive_sort,:], ax=ax, vmax=cmax, vmin=cmin, linewidth=0,
                 cmap=sns.diverging_palette(
                     154, 308, n=230, s=100, sep=50, center='dark'),
                 cbar_kws={'label': '$\Delta$F/F'}, xticklabels=False,  yticklabels=False)  # sets tick label increments

# colorbar
cbar = hm.collections[0].colorbar
cbar.set_ticks([-.1, .1])
cbar.set_ticklabels([cmin, cmax])
ax.set(xticks=[0, pre_window_size, window_size-1])
ax.set(xticklabels=["-10", "0","13"])

#lines and labels
ax.grid(False)
ax.set_title(plot_titles[0]+"-INACTIVE", fontweight="bold", fontsize=14)
ax.set_ylabel('%s Neurons' % sorted_sub_early_inactive.shape[0], fontsize=12)
ax.set_xlabel('Time (sec)', fontsize=12)
ax.plot([pre_window_size, pre_window_size],
        [0, numneurons_sub_early_inactive], '--', linewidth=1.5, color='white')

# middle active plots
ax = axs[0, 1]

# heatmap
hm = sns.heatmap(sub_middle_active[sortresponse_sub_middle_active, :], ax=ax, vmax=cmax, vmin=cmin, linewidth=0,
                 cmap=sns.diverging_palette(
                     154, 308, n=230, s=100, sep=50, center='dark'),
                 cbar_kws={'label': '$\Delta$F/F'}, xticklabels=False,  yticklabels=False)  # sets tick label increments

# color bar
cbar = hm.collections[0].colorbar
cbar.set_ticks([-.1, .1])
cbar.set_ticklabels([cmin, cmax])
ax.set(xticks=[0, pre_window_size, window_size-1])
ax.set(xticklabels=["-10", "0","13"])

#lines and labels
ax.grid(False)
ax.set_title(plot_titles[1]+"-ACTIVE", fontweight="bold", fontsize=14)
ax.set_ylabel('%s Neurons' % numneurons_sub_middle_active, fontsize=12)
ax.plot([pre_window_size, pre_window_size],
        [0, numneurons_sub_middle_active], '--', linewidth=1.5, color='white')

# line plot
ax = axs[2, 1]
ax.plot(sub_middle_active_mean)
ax.plot(sub_middle_inactive_mean)
ax.set_ylim([-.07, .07])
ax.plot([0, window_size], [0, 0], '--k', linewidth=0.5)
ax.axvline(pre_window_size, color='black', linestyle='--')
ax.legend(['Active', 'Inactive'])

# middle inactive plots
ax = axs[1, 1]

#filtering NaN's
sorted_sub_middle_inactive, inactive_sort = filter_NAN(sub_middle_inactive, window_size, pre_window_size, framerate)

# heatmap
hm = sns.heatmap(sorted_sub_middle_inactive[inactive_sort,:], ax=ax, vmax=cmax, vmin=cmin, linewidth=0,
                 cmap=sns.diverging_palette(
                     154, 308, n=230, s=100, sep=50, center='dark'),
                 cbar_kws={'label': '$\Delta$F/F'}, xticklabels=False,  yticklabels=False)  # sets tick label increments

# colorbar
cbar = hm.collections[0].colorbar
cbar.set_ticks([-.1, .1])
cbar.set_ticklabels([cmin, cmax])
ax.set(xticks=[0, pre_window_size, window_size-1])
ax.set(xticklabels=["-10", "0","13"])

#lines and labels
ax.grid(False)
ax.set_title(plot_titles[1]+"-INACTIVE", fontweight="bold", fontsize=14)
ax.set_ylabel('%s Neurons' % sorted_sub_middle_inactive.shape[0], fontsize=12)
ax.set_xlabel('Time (sec)', fontsize=12)
ax.plot([pre_window_size, pre_window_size],
        [0, numneurons_sub_middle_inactive], '--', linewidth=1.5, color='white')
# Out:
# C:\Users\jboqu\AppData\Local\Temp\ipykernel_8340\2537301821.py:34: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "--k" (-> color='k'). The keyword argument will take precedence.
#   ax.plot([pre_window_size, pre_window_size],

# %%
#save fig
fig.savefig(os.path.join(results, 'population', 'active-inactive-sub6', 'PFC_HEROIN_SA_Extinction_active-inactive-sub6_population_heatmaps.PDF'), format='PDF')
fig.savefig(os.path.join(results, 'population', 'active-inactive-sub6', 'PFC_HEROIN_SA_Extinction_active-inactive-sub6_population_heatmaps.PNG'), format='PNG')

# %% [markdown]
# ## Cluster Analysis

# %% [markdown]
# ### Plotting clusters

# %% [markdown]
# #### All population data

# %%
#inactive data
early_populationdata = early_inactive
middle_populationdata = middle_inactive

##active data
#early_populationdata = early_active
#middle_populationdata = middle_active

#num neurons
early_numneurons = early_populationdata.shape[0]
middle_numneurons = middle_populationdata.shape[0]

print('Early population num neurons:', early_numneurons)
print('Middle population num neurons:', middle_numneurons)
print()

#the label values should match the num of neurons
print('Early labels shape:', early_newlabels.shape)
print('Middle labels shape:', middle_newlabels.shape)
# Out:
# Early population num neurons: 1401
# Middle population num neurons: 783
#
# Early labels shape: (1401,)
# Middle labels shape: (783,)

# %%
#cluster heatmaps

sessions = ['early', 'middle'] ###SET TO THE DIFFERENT TIME POINTS THAT WERE USED FOR TRACKING
numclusters = 4 ###SET TO NUMBER OF CLUSTERS FOR DATASET
uniquelabels = np.arange(numclusters)

sortwindow = {}
for cluster, cluster in enumerate(uniquelabels):
    sortwindow[cluster] = {}
    if cluster == 0:
        sortwindow[cluster] = [pre_window_size, infusionframe+int(3*framerate)]
    if cluster == 1:
        sortwindow[cluster] = [infusionframe+int(1*framerate), -1]
    if cluster == 2:
        sortwindow[cluster] = [pre_window_size, infusionframe+int(3*framerate)]
    if cluster == 3:
        sortwindow[cluster] = [pre_window_size, infusionframe+int(3*framerate)]
    
cmax = 0.1

fig, axs = plt.subplots(len(sessions),len(uniquelabels),
                        figsize=(2*len(uniquelabels),2*len(sessions)))
cbar_ax = fig.add_axes([.94, .3, .01, .4])
cbar_ax.tick_params(width=0.5) 

numneuronsincluster = np.nan*np.ones((len(uniquelabels),))

for cluster, cluster in enumerate(uniquelabels):
    for s, session in enumerate(sessions):
        if session == 'early':
            temp = early_populationdata[np.where(early_newlabels==cluster)[0],:]
            temp = temp[np.where(np.isfinite(temp[:,0]))[0],:]
        elif session == 'middle':
            temp = middle_populationdata[np.where(middle_newlabels==cluster)[0],:]
            temp = temp[np.where(np.isfinite(temp[:,0]))[0],:]
        numneuronsincluster[cluster] = temp.shape[0]
        sortresponse = np.argsort(np.mean(temp[:,sortwindow[cluster][0]:sortwindow[cluster][1]], axis=1))[::-1]
        hm = sns.heatmap(
                    temp[sortresponse],
                    ax=axs[s, cluster],
                    cmap=sns.diverging_palette(154, 308,n=230,s=100,sep=50,center='dark'),
                    vmin=-cmax,
                    vmax=cmax,
                    cbar=(cluster==0),
                    cbar_ax=cbar_ax if (cluster==0) else None,
                    cbar_kws={'label': 'Normalized fluorescence', 'ticks': [cmax, cmin]}
                    )
        axs[s, cluster].grid(False)
        if s==len(sessions)-1:
            axs[s, cluster].set_xticks([0, pre_window_size, infusionframe, window_size])
        else:
            axs[s, cluster].set_xticks([])
        axs[s, cluster].tick_params(width=0.5)    
        axs[s, cluster].set_xticklabels([])
        axs[s, cluster].set_yticks([])
        axs[s, cluster].axvline(pre_window_size, linestyle='--', color='white', linewidth=1.5)
        if cluster==0:
            axs[s, 0].set_ylabel('%s\nNeurons'%(session))
    axs[0, cluster].set_title('Cluster %d'%(cluster+1))

fig.text(0.5, 0.05, 'Time (sec)', fontsize=12,
         horizontalalignment='center', verticalalignment='center', rotation='horizontal')
fig.tight_layout()

fig.subplots_adjust(wspace=0.1, hspace=0.1)
fig.subplots_adjust(left=0.03)
fig.subplots_adjust(right=0.93)
fig.subplots_adjust(bottom=0.2)
fig.subplots_adjust(top=0.83)
# Out:
# C:\Users\jboqu\AppData\Local\Temp\ipykernel_8340\3694234445.py:63: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   fig.tight_layout()

# %%
#save fig
fig.savefig(os.path.join(results, 'clusters', 'active-all', 'PFC_HEROIN_SA_Extinction_active-all_clusters_heatmaps.PDF'), format='PDF')
fig.savefig(os.path.join(results, 'clusters', 'active-all', 'PFC_HEROIN_SA_Extinction_active-all_clsters_heatmaps.PNG'), format='PNG')

# %%
#cluster line plots

fig, axs = plt.subplots(len(sessions), len(uniquelabels),
                        figsize=(2*len(uniquelabels),3*len(sessions)))

numneuronsincluster = np.nan*np.ones((len(uniquelabels),))

colors_for_key = ['red','blue','purple','green']

for cluster, cluster in enumerate(uniquelabels):
    for s, session in enumerate(sessions):
        if session == 'early':
            temp = early_populationdata[np.where(early_newlabels==cluster)[0],:]
            temp = temp[np.where(np.isfinite(temp[:,0]))[0],:] #FIXME
        elif session == 'middle':
            temp = middle_populationdata[np.where(middle_newlabels==cluster)[0],:]
            temp = temp[np.where(np.isfinite(temp[:,0]))[0],:] #FIXME
        numneuronsincluster[cluster] = temp.shape[0]
        temp = np.mean(temp, axis = 0)        
        sns.lineplot(data = temp, dashes = False, color = colors_for_key[s],
                    ax=axs[s, cluster])
        axs[s, cluster].grid(False)
        if s==len(sessions)-1:
            axs[s, cluster].set_xticks([0, pre_window_size,  window_size])
        else:
            axs[s, cluster].set_xticks([])
        axs[s, cluster].tick_params(width=0.5)    
        axs[s, cluster].set_yticks([])
        axs[s, cluster].set(ylim=(-.2, .2))
        axs[s, cluster].text(x = s, y = .1, s = 'n = %d'%(numneuronsincluster[cluster]))
        
        axs[s, cluster].axvline(pre_window_size, linestyle='--', color='k', linewidth=1.5)
        axs[s, cluster].axhline(0, linestyle='--', color='k', linewidth=0.5)
        if cluster==0:
            axs[s, 0].set_ylabel(session)
    axs[0, cluster].set_title('Cluster %d'%(cluster+1))
    
fig.text(0.5, 0.05, 'Time from cue (s)', fontsize=12,horizontalalignment='center', verticalalignment='center', rotation='horizontal')
fig.tight_layout()

fig.subplots_adjust(wspace=0.1, hspace=0.1)
fig.subplots_adjust(left=0.03)
fig.subplots_adjust(right=0.93)
fig.subplots_adjust(bottom=0.2)
fig.subplots_adjust(top=0.83)

# %%
#save fig
fig.savefig(os.path.join(results, 'clusters', 'inactive-all', 'PFC_HEROIN_SA_Extinction_inactive-all_clusters_polylines.PDF'), format='PDF')
fig.savefig(os.path.join(results, 'clusters', 'inactive-all', 'PFC_HEROIN_SA_Extinction_inactive-all_clsters_polylines.PNG'), format='PNG')

# %% [markdown]
# #### Population data based on lever presses

# %% [markdown]
# ##### Active clustering

# %%
#active data
early_populationdata = early_active
middle_populationdata = middle_active

#num neurons
early_numneurons = early_populationdata.shape[0]
middle_numneurons = middle_populationdata.shape[0]

print('Early population num neurons:', early_numneurons)
print('Middle population num neurons:', middle_numneurons)
print()

#the label values should match the num of neurons
print('Early labels shape:', early_newlabels.shape)
print('Middle labels shape:', middle_newlabels.shape)
# Out:
# Early population num neurons: 1401
# Middle population num neurons: 783
#
# Early labels shape: (1401,)
# Middle labels shape: (783,)

# %%
#cluster heatmaps

sessions = ['early', 'middle'] ###SET TO THE DIFFERENT TIME POINTS THAT WERE USED FOR TRACKING
numclusters = 4 ###SET TO NUMBER OF CLUSTERS FOR DATASET
uniquelabels = np.arange(numclusters)

sortwindow = {}
for cluster, cluster in enumerate(uniquelabels):
    sortwindow[cluster] = {}
    if cluster == 0:
        sortwindow[cluster] = [pre_window_size, infusionframe+int(3*framerate)]
    if cluster == 1:
        sortwindow[cluster] = [infusionframe+int(1*framerate), -1]
    if cluster == 2:
        sortwindow[cluster] = [pre_window_size, infusionframe+int(3*framerate)]
    if cluster == 3:
        sortwindow[cluster] = [pre_window_size, infusionframe+int(3*framerate)]
    
cmax = 0.1

fig, axs = plt.subplots(len(sessions),len(uniquelabels),
                        figsize=(2*len(uniquelabels),2*len(sessions)))
cbar_ax = fig.add_axes([.94, .3, .01, .4])
cbar_ax.tick_params(width=0.5) 

numneuronsincluster = np.nan*np.ones((len(uniquelabels),))

for cluster, cluster in enumerate(uniquelabels):
    for s, session in enumerate(sessions):
        if session == 'early':
            df_reference = sub_early_active_df['Stack index'][np.where(sub_early_active_df['Cluster']==cluster)[0]]
            temp = early_populationdata[df_reference]
            temp = temp[np.where(np.isfinite(temp[:,0]))[0],:]
        elif session == 'middle':
            df_reference = sub_middle_active_df['Stack index'][np.where(sub_middle_active_df['Cluster']==cluster)[0]]
            temp = middle_populationdata[df_reference]
            temp = temp[np.where(np.isfinite(temp[:,0]))[0],:]
        numneuronsincluster[cluster] = temp.shape[0]
        sortresponse = np.argsort(np.mean(temp[:,sortwindow[cluster][0]:sortwindow[cluster][1]], axis=1))[::-1]
        hm = sns.heatmap(
                    temp[sortresponse],
                    ax=axs[s, cluster],
                    cmap=sns.diverging_palette(154, 308,n=230,s=100,sep=50,center='dark'),
                    vmin=-cmax,
                    vmax=cmax,
                    cbar=(cluster==0),
                    cbar_ax=cbar_ax if (cluster==0) else None,
                    cbar_kws={'label': 'Normalized fluorescence', 'ticks': [cmax, cmin]}
                    )
        axs[s, cluster].grid(False)
        if s==len(sessions)-1:
            axs[s, cluster].set_xticks([0, pre_window_size, infusionframe, window_size])
        else:
            axs[s, cluster].set_xticks([])
        axs[s, cluster].tick_params(width=0.5)    
        axs[s, cluster].set_xticklabels([])
        axs[s, cluster].set_yticks([])
        axs[s, cluster].axvline(pre_window_size, linestyle='--', color='white', linewidth=1.5)
        if cluster==0:
            axs[s, 0].set_ylabel('%s\nNeurons'%(session))
    axs[0, cluster].set_title('Cluster %d'%(cluster+1))

fig.text(0.5, 0.05, 'Time (sec)', fontsize=12,
         horizontalalignment='center', verticalalignment='center', rotation='horizontal')
fig.tight_layout()

fig.subplots_adjust(wspace=0.1, hspace=0.1)
fig.subplots_adjust(left=0.03)
fig.subplots_adjust(right=0.93)
fig.subplots_adjust(bottom=0.2)
fig.subplots_adjust(top=0.83)
# Out:
# C:\Users\jboqu\AppData\Local\Temp\ipykernel_8340\4282067.py:65: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   fig.tight_layout()

# %%
#save fig
fig.savefig(os.path.join(results, 'clusters', 'sub6', 'active-sub6', 'PFC_HEROIN_SA_Extinction_active-sub6_clusters_heatmaps.PDF'), format='PDF')
fig.savefig(os.path.join(results, 'clusters', 'sub6', 'active-sub6', 'PFC_HEROIN_SA_Extinction_active-sub6_clsters_heatmaps.PNG'), format='PNG')

# %%
#cluster line plots

fig, axs = plt.subplots(len(sessions), len(uniquelabels),
                        figsize=(2*len(uniquelabels),3*len(sessions)))

numneuronsincluster = np.nan*np.ones((len(uniquelabels),))

colors_for_key = ['red','blue','purple','green']

for cluster, cluster in enumerate(uniquelabels):
    for s, session in enumerate(sessions):
        if session == 'early':
            df_reference = sub_early_active_df['Stack index'][np.where(sub_early_active_df['Cluster']==cluster)[0]]
            temp = early_populationdata[df_reference]
            temp = temp[np.where(np.isfinite(temp[:,0]))[0],:]
        elif session == 'middle':
            df_reference = sub_middle_active_df['Stack index'][np.where(sub_middle_active_df['Cluster']==cluster)[0]]
            temp = middle_populationdata[df_reference]
            temp = temp[np.where(np.isfinite(temp[:,0]))[0],:]
        numneuronsincluster[cluster] = temp.shape[0]
        temp = np.mean(temp, axis = 0)        
        sns.lineplot(data = temp, dashes = False, color = colors_for_key[s],
                    ax=axs[s, cluster])

        axs[s, cluster].grid(False)
        if s==len(sessions)-1:
            axs[s, cluster].set_xticks([0, pre_window_size, infusionframe, window_size])
        else:
            axs[s, cluster].set_xticks([])
        axs[s, cluster].tick_params(width=0.5)    
        axs[s, cluster].set_yticks([])
        axs[s, cluster].set(ylim=(-.2, .2))
        axs[s, cluster].text(x = s, y = .1, s = 'n = %d'%(numneuronsincluster[cluster]))
        
        axs[s, cluster].axvline(pre_window_size, linestyle='--', color='k', linewidth=1.5)
        axs[s, cluster].axhline(0, linestyle='--', color='k', linewidth=0.5)
        if cluster==0:
            axs[s, 0].set_ylabel(session)
    axs[0, cluster].set_title('Cluster %d'%(cluster+1))
    
fig.text(0.5, 0.05, 'Time from cue (s)', fontsize=12,horizontalalignment='center', verticalalignment='center', rotation='horizontal')
fig.tight_layout()

fig.subplots_adjust(wspace=0.1, hspace=0.1)
fig.subplots_adjust(left=0.03)
fig.subplots_adjust(right=0.93)
fig.subplots_adjust(bottom=0.2)
fig.subplots_adjust(top=0.83)

# %%
#save fig
fig.savefig(os.path.join(results, 'clusters', 'sub6', 'active-sub6', 'PFC_HEROIN_SA_Extinction_active-sub6_clusters_polylines.PDF'), format='PDF')
fig.savefig(os.path.join(results, 'clusters', 'sub6', 'active-sub6', 'PFC_HEROIN_SA_Extinction_active-sub6_clsters_polylines.PNG'), format='PNG')

# %% [markdown]
# ##### Inactive clustering

# %%
#inactive data
early_populationdata = early_inactive
middle_populationdata = middle_inactive

#num neurons
early_numneurons = early_populationdata.shape[0]
middle_numneurons = middle_populationdata.shape[0]

print('Early population num neurons:', early_numneurons)
print('Middle population num neurons:', middle_numneurons)
print()

#the label values should match the num of neurons
print('Early labels shape:', early_newlabels.shape)
print('Middle labels shape:', middle_newlabels.shape)
# Out:
# Early population num neurons: 1401
# Middle population num neurons: 783
#
# Early labels shape: (1401,)
# Middle labels shape: (783,)

# %%
#cluster heatmaps

sessions = ['early', 'middle'] ###SET TO THE DIFFERENT TIME POINTS THAT WERE USED FOR TRACKING
numclusters = 4 ###SET TO NUMBER OF CLUSTERS FOR DATASET
uniquelabels = np.arange(numclusters)

sortwindow = {}
for cluster, cluster in enumerate(uniquelabels):
    sortwindow[cluster] = {}
    if cluster == 0:
        sortwindow[cluster] = [pre_window_size, infusionframe+int(3*framerate)]
    if cluster == 1:
        sortwindow[cluster] = [infusionframe+int(1*framerate), -1]
    if cluster == 2:
        sortwindow[cluster] = [pre_window_size, infusionframe+int(3*framerate)]
    if cluster == 3:
        sortwindow[cluster] = [pre_window_size, infusionframe+int(3*framerate)]
    
cmax = 0.1

fig, axs = plt.subplots(len(sessions),len(uniquelabels),
                        figsize=(2*len(uniquelabels),2*len(sessions)))
cbar_ax = fig.add_axes([.94, .3, .01, .4])
cbar_ax.tick_params(width=0.5) 

numneuronsincluster = np.nan*np.ones((len(uniquelabels),))

for cluster, cluster in enumerate(uniquelabels):
    for s, session in enumerate(sessions):
        if session == 'early':
            df_reference = sub_early_inactive_df['Stack index'][np.where(sub_early_inactive_df['Cluster']==cluster)[0]]
            temp = early_populationdata[df_reference]
            temp = temp[np.where(np.isfinite(temp[:,0]))[0],:]
        elif session == 'middle':
            df_reference = sub_middle_inactive_df['Stack index'][np.where(sub_middle_inactive_df['Cluster']==cluster)[0]]
            temp = middle_populationdata[df_reference]
            temp = temp[np.where(np.isfinite(temp[:,0]))[0],:]
        numneuronsincluster[cluster] = temp.shape[0]
        sortresponse = np.argsort(np.mean(temp[:,sortwindow[cluster][0]:sortwindow[cluster][1]], axis=1))[::-1]
        hm = sns.heatmap(
                    temp[sortresponse],
                    ax=axs[s, cluster],
                    cmap=sns.diverging_palette(154, 308,n=230,s=100,sep=50,center='dark'),
                    vmin=-cmax,
                    vmax=cmax,
                    cbar=(cluster==0),
                    cbar_ax=cbar_ax if (cluster==0) else None,
                    cbar_kws={'label': 'Normalized fluorescence', 'ticks': [cmax, cmin]}
                    )
        axs[s, cluster].grid(False)
        if s==len(sessions)-1:
            axs[s, cluster].set_xticks([0, pre_window_size, infusionframe, window_size])
        else:
            axs[s, cluster].set_xticks([])
        axs[s, cluster].tick_params(width=0.5)    
        axs[s, cluster].set_xticklabels([])
        axs[s, cluster].set_yticks([])
        axs[s, cluster].axvline(pre_window_size, linestyle='--', color='white', linewidth=1.5)
        if cluster==0:
            axs[s, 0].set_ylabel('%s\nNeurons'%(session))
    axs[0, cluster].set_title('Cluster %d'%(cluster+1))

fig.text(0.5, 0.05, 'Time (sec)', fontsize=12,
         horizontalalignment='center', verticalalignment='center', rotation='horizontal')
fig.tight_layout()

fig.subplots_adjust(wspace=0.1, hspace=0.1)
fig.subplots_adjust(left=0.03)
fig.subplots_adjust(right=0.93)
fig.subplots_adjust(bottom=0.2)
fig.subplots_adjust(top=0.83)
# Out:
# C:\Users\jboqu\AppData\Local\Temp\ipykernel_8340\693848019.py:65: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   fig.tight_layout()

# %%
#save fig
fig.savefig(os.path.join(results, 'clusters', 'sub6', 'inactive-sub6', 'PFC_HEROIN_SA_Extinction_inactive-sub6_clusters_heatmaps.PDF'), format='PDF')
fig.savefig(os.path.join(results, 'clusters', 'sub6', 'inactive-sub6', 'PFC_HEROIN_SA_Extinction_inactive-sub6_clsters_heatmaps.PNG'), format='PNG')

# %%
#cluster line plots

fig, axs = plt.subplots(len(sessions), len(uniquelabels),
                        figsize=(2*len(uniquelabels),3*len(sessions)))

numneuronsincluster = np.nan*np.ones((len(uniquelabels),))

colors_for_key = ['red','blue','purple','green']

for cluster, cluster in enumerate(uniquelabels):
    for s, session in enumerate(sessions):
        if session == 'early':
            df_reference = sub_early_inactive_df['Stack index'][np.where(sub_early_inactive_df['Cluster']==cluster)[0]]
            temp = early_populationdata[df_reference]
            temp = temp[np.where(np.isfinite(temp[:,0]))[0],:]
        elif session == 'middle':
            df_reference = sub_middle_inactive_df['Stack index'][np.where(sub_middle_inactive_df['Cluster']==cluster)[0]]
            temp = middle_populationdata[df_reference]
            temp = temp[np.where(np.isfinite(temp[:,0]))[0],:]
        numneuronsincluster[cluster] = temp.shape[0]
        temp = np.mean(temp, axis = 0)        
        sns.lineplot(data = temp, dashes = False, color = colors_for_key[s],
                    ax=axs[s, cluster])

        axs[s, cluster].grid(False)
        if s==len(sessions)-1:
            axs[s, cluster].set_xticks([0, pre_window_size, infusionframe, window_size])
        else:
            axs[s, cluster].set_xticks([])
        axs[s, cluster].tick_params(width=0.5)    
        axs[s, cluster].set_yticks([])
        axs[s, cluster].set(ylim=(-.2, .2))
        axs[s, cluster].text(x = s, y = .1, s = 'n = %d'%(numneuronsincluster[cluster]))
        
        axs[s, cluster].axvline(pre_window_size, linestyle='--', color='k', linewidth=1.5)
        axs[s, cluster].axhline(0, linestyle='--', color='k', linewidth=0.5)
        if cluster==0:
            axs[s, 0].set_ylabel(session)
    axs[0, cluster].set_title('Cluster %d'%(cluster+1))
    
fig.text(0.5, 0.05, 'Time from cue (s)', fontsize=12,horizontalalignment='center', verticalalignment='center', rotation='horizontal')
fig.tight_layout()

fig.subplots_adjust(wspace=0.1, hspace=0.1)
fig.subplots_adjust(left=0.03)
fig.subplots_adjust(right=0.93)
fig.subplots_adjust(bottom=0.2)
fig.subplots_adjust(top=0.83)

# %%
#save fig
fig.savefig(os.path.join(results, 'clusters', 'sub6', 'inactive-sub6', 'PFC_HEROIN_SA_Extinction_inactive-sub6_clusters_polylines.PDF'), format='PDF')
fig.savefig(os.path.join(results, 'clusters', 'sub6', 'inactive-sub6', 'PFC_HEROIN_SA_Extinction_inactive-sub6_clsters_polylines.PNG'), format='PNG')

# %% [markdown]
# ## Multivoxel Pattern Analysis *(decoding)*

# %%
#import libraries
decoding_dict_results_dir = os.path.join(results,'decoding','dictionaries')

import subprocess
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from statsmodels.distributions.empirical_distribution import ECDF
from sklearn.model_selection import GridSearchCV


import pickle
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
from sklearn.svm import SVC, SVR, LinearSVC
from sklearn.metrics import silhouette_score
from sklearn.cluster import AgglomerativeClustering, SpectralClustering, KMeans
from sklearn.model_selection import KFold, LeaveOneOut, train_test_split
from sklearn.kernel_ridge import KernelRidge
from sklearn import linear_model
from sklearn.manifold import TSNE
from scipy import interpolate
import statsmodels.formula.api as smf
from patsy import (ModelDesc, EvalEnvironment, Term, EvalFactor, LookupFactor, dmatrices, INTERCEPT)

import matplotlib.pyplot as plt

from alive_progress import alive_bar
import time

# %%
#various methods

def binaryclassifier(y, X, cv_val):
    hyperparameters = {'kernel': ['rbf'], 
                       'gamma': [1e-2, 1e-1, 1e0, 1e1, 1e2],
                       'C': [1e-2, 1e-1, 1e0, 1e1, 1e2]}
    try:
        clf = GridSearchCV(SVC(), hyperparameters, cv=cv_val)
        clf.fit(X, y)
        accuracy = clf.best_score_
        return accuracy
    except Exception as e:
        print('*** ERROR:', e, '***')

def svmregression(y, X):
    hyperparameters = {'kernel': ['rbf'], 'cluster': np.logspace(-3, 3, 5),
                      'epsilon': np.logspace(-3, 3, 5),
                      'gamma': np.logspace(-5, 5, 10)}
    clf = GridSearchCV(SVR(), hyperparameters, cv=10)
    if np.all(np.isnan(X)):
        R2=np.nan
    else:
        clf.fit(X, y)
        R2 = clf.best_score_
    #reference for 10-fold cross-validation http://web.cs.iastate.edu/~jtian/cs573/Papers/Kohavi-IJCAI-95.pdf
    return R2

def calculate_t(x, y):
    Sp= np.sqrt((np.nanstd(x)**2 + np.nanstd(y)**2)/2)
    denominator = Sp*(np.sqrt(2/len(x)))
    numerator = np.nanmean(x) - np.nanmean(y)
    t = numerator/denominator
    return t

# %% [markdown]
# ### Decoding: Neuron, ActivePress-all

# %%
#MAKING DICTIONARIES

groups = ['Early','Middle'] ###INSERT YOUR GROUPS (E.G., EARLY AND LATE LEARNING)
animals_of_interest_list = [early_animals_of_interest, middle_animals_of_interest]
indir_list = [earlybasedir, middlebasedir]

##TEST DATA
#early_animals_of_interest_TEST = ['PGa-T3']
#middle_animals_of_interest_TEST = ['LCDD-PGa-T2']
#groups = ['Early','Middle'] ###INSERT YOUR GROUPS (E.G., EARLY AND LATE LEARNING)
#animals_of_interest_list = [early_animals_of_interest_TEST, middle_animals_of_interest_TEST]
#indir_list = [earlybasedir, middlebasedir]

session_analysis_split_by_ensemble = ['Yes'] ###SET TO ['Yes'] OR TO ['No']
decoding = ['Neuron', 'Trial'] ###SET TO Neuron or Session and Trial or Lick
numclusters = 4 ###SET TO NUMBER OF CLUSTERS

baseline = [1, 8]  ###These variables are for assigning neuronal data epochs
leverresponse = [pre_window_size-9, pre_window_size-1]

numshuffles = 1 
classification_accuracy = {}
uniquelabels = np.arange(numclusters)
numneuronsincluster = np.nan*np.ones((numclusters,))

print('========== STARTING ==========')
datadir=0
for index in range(len(groups)):
    group = groups[index]
    classification_accuracy[group] = {}
    classification_accuracy[group]['individualneurons'] = {}
    classification_accuracy[group]['individualneurons']['shuffled'] = {}
    classification_accuracy[group]['individualneurons']['unshuffled'] = {}

    animals_of_interest = animals_of_interest_list[index]
    indir = indir_list[index]

    numneuronstillnow = 0 
    for animal in animals_of_interest:
        fovs = next(os.walk(os.path.join(indir, animal)))[1]
        for fov in sorted(fovs):
            trials = np.load(os.path.join(indir, animal, fov, 'aligned_active_lever_data.npy'))
            ###THIS SECTION DELETES ANY TRIALS WITH NANs
            for i in reversed(range(trials.shape[0])): ###reversed to prevent deletion from messing up indexing
                if np.isnan(np.mean(trials[i,:,:])):
                    trials = np.delete(trials, i, axis = 0)
        
            ###THIS SECTION ALIGNS DATA FOR DECODING        
            numtrials = trials.shape[0]
            numsapltes = trials.shape[1]
            numneuronsinfov = trials.shape[2]

            baseline_inactive = np.nan*np.ones((numtrials,numneuronsinfov))
            response_inactive = np.nan*np.ones((numtrials,numneuronsinfov))

            activeflag = np.hstack((np.zeros((numtrials)), np.ones((numtrials))))
            if numtrials < 9 and numtrials > 0:
                for neuron in range(numneuronsinfov):
                    print('Group:', group, 
                        '\nAnimal:', animal,
                        '\nTrials:', numtrials, 
                        '\nNeuron:', neuron, 'of', numneuronsinfov)
                    baseline_inactive[:,neuron] = np.nanmean(trials[:,baseline[0]:baseline[1],neuron], axis=1)
                    response_inactive[:,neuron] = np.nanmean(trials[:,leverresponse[0]:leverresponse[1],neuron], axis=1)
                    
                    cv = numtrials
                    ###CHANGE THESE VARIABLES TO ADJUST WHAT YOU ARE DECODING AND ENSURE IT ALIGNS WITH YOUR FLAGS
                    neuralactivity_trialtype = np.vstack((baseline_inactive, response_inactive)) ###FOR COMPARING TRIAL TYPES
                    ##TRIAL DECODING IN SINGLE NEURONS
                    print('-----\nbinaryclassifier unshuffled')
                    print('y:', activeflag.shape)
                    print('X:', np.expand_dims(neuralactivity_trialtype[:,neuron], axis=1).shape)
                    classification_accuracy[group]['individualneurons']['unshuffled'][numneuronstillnow+neuron] = binaryclassifier(activeflag, np.expand_dims(neuralactivity_trialtype[:,neuron], axis=1), cv)
                    #print('Unshuffled accuracy:', classification_accuracy[group]['individualneurons']['unshuffled'][numneuronstillnow+neuron])

                    shuffledresults = np.nan*np.ones((numshuffles,))
                    for shuffleid in range(numshuffles):
                        shuffled_flag = np.random.permutation(activeflag)
                        print('-----\nbinaryclassifier shuffled')
                        print('y:', shuffled_flag.shape)
                        print('X:', np.expand_dims(neuralactivity_trialtype[:,neuron], axis=1).shape)
                        shuffledresults[shuffleid] = binaryclassifier(shuffled_flag, np.expand_dims(neuralactivity_trialtype[:,neuron], axis=1), cv)
                    classification_accuracy[group]['individualneurons']['shuffled'][numneuronstillnow+neuron] = shuffledresults
                    print('Shuffled accuracy:', classification_accuracy[group]['individualneurons']['shuffled'][numneuronstillnow+neuron][0],'\n-----')
                    print()
                    numneuronstillnow += numneuronsinfov
            elif numtrials == 0:
                print('Group:', group, 
                    '\nAnimal:', animal,
                    '\nTrials:', numtrials)
                print('*** ERROR: Insufficient trials ***')
            else:
                for neuron in range(numneuronsinfov):
                    print('Group:', group, 
                        '\nAnimal:', animal,
                        '\nTrials:', numtrials, 
                        '\nNeuron:', neuron, 'of', numneuronsinfov)
                    baseline_inactive[:,neuron] = np.nanmean(trials[:,baseline[0]:baseline[1],neuron], axis=1)
                    response_inactive[:,neuron] = np.nanmean(trials[:,leverresponse[0]:leverresponse[1],neuron], axis=1)
                    
                    cv = 10
                    ###CHANGE THESE VARIABLES TO ADJUST WHAT YOU ARE DECODING AND ENSURE IT ALIGNS WITH YOUR FLAGS
                    neuralactivity_trialtype = np.vstack((baseline_inactive, response_inactive)) ###FOR COMPARING TRIAL TYPES
                    ##TRIAL DECODING IN SINGLE NEURONS
                    print('-----\nbinaryclassifier unshuffled')
                    print('y:', activeflag.shape)
                    print('X:', np.expand_dims(neuralactivity_trialtype[:,neuron], axis=1).shape)
                    classification_accuracy[group]['individualneurons']['unshuffled'][numneuronstillnow+neuron] = binaryclassifier(activeflag, np.expand_dims(neuralactivity_trialtype[:,neuron], axis=1), cv)
                    print('Unshuffled accuracy:', classification_accuracy[group]['individualneurons']['unshuffled'][numneuronstillnow+neuron])

                    shuffledresults = np.nan*np.ones((numshuffles,))
                    for shuffleid in range(numshuffles):
                        shuffled_flag = np.random.permutation(activeflag)
                        print('-----\nbinaryclassifier shuffled')
                        print('y:', shuffled_flag.shape)
                        print('X:', np.expand_dims(neuralactivity_trialtype[:,neuron], axis=1).shape)
                        shuffledresults[shuffleid] = binaryclassifier(shuffled_flag, np.expand_dims(neuralactivity_trialtype[:,neuron], axis=1), cv)
                    classification_accuracy[group]['individualneurons']['shuffled'][numneuronstillnow+neuron] = shuffledresults
                    print('Shuffled accuracy:', classification_accuracy[group]['individualneurons']['shuffled'][numneuronstillnow+neuron][0],'\n-----')
                    print()
                    numneuronstillnow += numneuronsinfov
    print('END:', group,'\n')
print('========== FINISHED ==========')
# Out:
# ========== STARTING ==========
# Group: Early
# Animal: CTL1
# Trials: 30
# Neuron: 0 of 121
# -----
# binaryclassifier unshuffled
# y: (60,)
# X: (60, 1)
# Unshuffled accuracy: 0.6
# -----
# binaryclassifier shuffled
# y: (60,)
# X: (60, 1)
# Shuffled accuracy: 0.5833333333333333
# -----
#
# Group: Early
# Animal: CTL1
# Trials: 30
# Neuron: 1 of 121
# -----
# binaryclassifier unshuffled
# y: (60,)
# X: (60, 1)
# Unshuffled accuracy: 0.6
# -----
# binaryclassifier shuffled
# y: (60,)
# X: (60, 1)
# Shuffled accuracy: 0.6
# -----
#
# Group: Early
# Animal: CTL1
# Trials: 30
# Neuron: 2 of 121
# -----
# binaryclassifier unshuffled
# y: (60,)
# X: (60, 1)
# Unshuffled accuracy: 0.6833333333333333
# -----
# binaryclassifier shuffled
# y: (60,)
# X: (60, 1)
# Shuffled accuracy: 0.5166666666666666
# -----
#
# Group: Early
# Animal: CTL1
# Trials: 30
# Neuron: 3 of 121
# -----
# binaryclassifier unshuffled
# y: (60,)
# X: (60, 1)
# Unshuffled accuracy: 0.9
# -----
# binaryclassifier shuffled
# y: (60,)
# X: (60, 1)
# Shuffled accuracy: 0.6333333333333334
# -----
#
# Group: Early
# Animal: CTL1
# Trials: 30
# Neuron: 4 of 121
# -----
# binaryclassifier unshuffled
# y: (60,)
# X: (60, 1)
# Unshuffled accuracy: 0.6666666666666667
# -----
# binaryclassifier shuffled
# y: (60,)
# X: (60, 1)
# Shuffled accuracy: 0.5333333333333333
# -----
#
# Group: Early
# Animal: CTL1
# Trials: 30
# Neuron: 5 of 121
# -----
# binaryclassifier unshuffled
# y: (60,)
# X: (60, 1)
# Unshuffled accuracy: 0.7333333333333332
# -----
# binaryclassifier shuffled
# y: (60,)
# X: (60, 1)
# Shuffled accuracy: 0.6000000000000001
# -----
#
# Group: Early
# Animal: CTL1
# Trials: 30
# Neuron: 6 of 121
# -----
# binaryclassifier unshuffled
# y: (60,)
# X: (60, 1)
# Unshuffled accuracy: 0.6666666666666667
# -----
# binaryclassifier shuffled
# y: (60,)
# X: (60, 1)
# Shuffled accuracy: 0.6333333333333333
# -----
#
# Group: Early
# Animal: CTL1
# Trials: 30
# Neuron: 7 of 121
# -----
# binaryclassifier unshuffled
# y: (60,)
# X: (60, 1)
# Unshuffled accuracy: 0.75
# -----
# binaryclassifier shuffled
# y: (60,)
# X: (60, 1)
# Shuffled accuracy: 0.5166666666666666
# -----
#
# Group: Early
# Animal: CTL1
# Trials: 30
# Neuron: 8 of 121
# -----
# binaryclassifier unshuffled
# y: (60,)
# X: (60, 1)
# Unshuffled accuracy: 0.7333333333333333
# -----
# binaryclassifier shuffled
# y: (60,)
# X: (60, 1)
# Shuffled accuracy: 0.4333333333333333
# -----
#
# Group: Early
# Animal: CTL1
# Trials: 30
# Neuron: 9 of 121
# -----
# binaryclassifier unshuffled
# y: (60,)
# X: (60, 1)
# Unshuffled accuracy: 0.6166666666666668
# -----
# binaryclassifier shuffled
# y: (60,)
# X: (60, 1)
# Shuffled accuracy: 0.5499999999999999
# -----
#
# Group: Early
# Animal: CTL1
# Trials: 30
# Neuron: 10 of 121
# -----
# binaryclassifier unshuffled
# y: (60,)
# X: (60, 1)
# Unshuffled accuracy: 0.6166666666666667
# -----
# binaryclassifier shuffled
# y: (60,)
# X: (60, 1)
# Shuffled accuracy: 0.5833333333333333
# -----
#
# Group: Early
# Animal: CTL1
# Trials: 30
# Neuron: 11 of 121
# -----
# binaryclassifier unshuffled
# y: (60,)
# X: (60, 1)
# Unshuffled accuracy: 0.6666666666666666
# -----
# binaryclassifier shuffled
# y: (60,)
# X: (60, 1)
# Shuffled accuracy: 0.5666666666666667
# -----
#
# Group: Early
# Animal: CTL1
# Trials: 30
# Neuron: 12 of 121
# -----
# binaryclassifier unshuffled
# y: (60,)
# X: (60, 1)
# Unshuffled accuracy: 0.75
# -----
# binaryclassifier shuffled
# y: (60,)
# X: (60, 1)
# Shuffled accuracy: 0.5833333333333334
# -----
#
# Group: Early
# Animal: CTL1
# Trials: 30
# Neuron: 13 of 121
# -----
# binaryclassifier unshuffled
# y: (60,)
# X: (60, 1)
# Unshuffled accuracy: 0.4833333333333333
# -----
# binaryclassifier shuffled
# y: (60,)
# X: (60, 1)
# Shuffled accuracy: 0.6166666666666667
# -----
#
# Group: Early
# Animal: CTL1
# Trials: 30
# Neuron: 14 of 121
# -----
# binaryclassifier unshuffled
# y: (60,)
# X: (60, 1)
# Unshuffled accuracy: 0.7
# -----
# binaryclassifier shuffled
# y: (60,)
# X: (60, 1)
# Shuffled accuracy: 0.6166666666666667
# -----
#
# Group: Early
# Animal: CTL1
# Trials: 30
# Neuron: 15 of 121
# -----
# binaryclassifier unshuffled
# y: (60,)
# X: (60, 1)
# Unshuffled accuracy: 0.8166666666666667
# -----
# binaryclassifier shuffled
# y: (60,)
# X: (60, 1)
# Shuffled accuracy: 0.5666666666666667
# -----
#
# Group: Early
# Animal: CTL1
# Trials: 30
# Neuron: 16 of 121
# -----
# binaryclassifier unshuffled
# y: (60,)
# X: (60, 1)
# Unshuffled accuracy: 0.6666666666666666
# -----
# binaryclassifier shuffled
# y: (60,)
# X: (60, 1)
# Shuffled accuracy: 0.6
# -----
#
# Group: Early
# Animal: CTL1
# Trials: 30
# Neuron: 17 of 121
# -----
# binaryclassifier unshuffled
# y: (60,)
# X: (60, 1)
# Unshuffled accuracy: 0.6333333333333333
# -----
# binaryclassifier shuffled
# y: (60,)
# X: (60, 1)
# Shuffled accuracy: 0.38333333333333336
# -----
#
# Group: Early
# Animal: CTL1
# Trials: 30
# Neuron: 18 of 121
# -----
# binaryclassifier unshuffled
# y: (60,)
# X: (60, 1)
# Unshuffled accuracy: 0.5833333333333333
# -----
# binaryclassifier shuffled
# y: (60,)
# X: (60, 1)
# Shuffled accuracy: 0.55
# -----
#
# Group: Early
# Animal: CTL1
# Trials: 30
# Neuron: 19 of 121
# -----
# binaryclassifier unshuffled
# y: (60,)
# X: (60, 1)
# Unshuffled accuracy: 0.85
# -----
# binaryclassifier shuffled
# y: (60,)
# X: (60, 1)
# Shuffled accuracy: 0.5666666666666667
# -----
#
# Group: Early
# Animal: CTL1
# Trials: 30
# Neuron: 20 of 121
# -----
# binaryclassifier unshuffled
# y: (60,)
# X: (60, 1)
# Unshuffled accuracy: 0.7500000000000001
# -----
# binaryclassifier shuffled
# y: (60,)
# X: (60, 1)
# Shuffled accuracy: 0.5166666666666667
# -----
#
# Group: Early
# Animal: CTL1
# Trials: 30
# Neuron: 21 of 121
# -----
# binaryclassifier unshuffled
# y: (60,)
# X: (60, 1)
# Unshuffled accuracy: 0.7833333333333334
# -----
# binaryclassifier shuffled
# y: (60,)
# X: (60, 1)
# Shuffled accuracy: 0.5833333333333333
# -----
#
# Group: Early
# Animal: CTL1
# Trials: 30
# Neuron: 22 of 121
# -----
# binaryclassifier unshuffled
# y: (60,)
# X: (60, 1)
# Unshuffled accuracy: 0.8166666666666668
# -----
# binaryclassifier shuffled
# y: (60,)
# X: (60, 1)
# Shuffled accuracy: 0.6166666666666667
# -----
#
# Group: Early
# Animal: CTL1
# Trials: 30
# Neuron: 23 of 121
# -----
# binaryclassifier unshuffled
# y: (60,)
# X: (60, 1)
# Unshuffled accuracy: 0.7833333333333334
# -----
# binaryclassifier shuffled
# y: (60,)
# X: (60, 1)
# Shuffled accuracy: 0.5666666666666667
# -----
#
# Group: Early
# Animal: CTL1
# Trials: 30
# Neuron: 24 of 121
# -----
# binaryclassifier unshuffled
# y: (60,)
# X: (60, 1)
# Unshuffled accuracy: 0.8166666666666668
# -----
# binaryclassifier shuffled
# y: (60,)
# X: (60, 1)
# Shuffled accuracy: 0.6166666666666667
# -----
#
# Group: Early
# Animal: CTL1
# Trials: 30
# Neuron: 25 of 121
# -----
# binaryclassifier unshuffled
# y: (60,)
# X: (60, 1)
# Unshuffled accuracy: 0.7
# -----
# binaryclassifier shuffled
# y: (60,)
# X: (60, 1)
# Shuffled accuracy: 0.5666666666666667
# -----
#
# Group: Early
# Animal: CTL1
# Trials: 30
# Neuron: 26 of 121
# -----
# binaryclassifier unshuffled
# y: (60,)
# X: (60, 1)
# Unshuffled accuracy: 0.7166666666666667
# -----
# binaryclassifier shuffled
# y: (60,)
# X: (60, 1)
# Shuffled accuracy: 0.5333333333333334
# -----
#
# Group: Early
# Animal: CTL1
# Trials: 30
# Neuron: 27 of 121
# -----
# binaryclassifier unshuffled
# y: (60,)
# X: (60, 1)
# Unshuffled accuracy: 0.7
# -----
# binaryclassifier shuffled
# y: (60,)
# X: (60, 1)
# Shuffled accuracy: 0.5666666666666667
# -----
#
# Group: Early
# Animal: CTL1
# Trials: 30
# Neuron: 28 of 121
# -----
# binaryclassifier unshuffled
# y: (60,)
# X: (60, 1)
# Unshuffled accuracy: 0.6833333333333333
# -----
# binaryclassifier shuffled
# y: (60,)
# X: (60, 1)
# Shuffled accuracy: 0.6000000000000001
# -----
#
# Group: Early
# Animal: CTL1
# Trials: 30
# Neuron: 29 of 121
# -----
# binaryclassifier unshuffled
# y: (60,)
# X: (60, 1)
# Unshuffled accuracy: 0.85
# -----
# binaryclassifier shuffled
# y: (60,)
# X: (60, 1)
# Shuffled accuracy: 0.5833333333333334
# -----
#
# Group: Early
# Animal: CTL1
# Trials: 30
# Neuron: 30 of 121
# -----
# binaryclassifier unshuffled
# y: (60,)
# X: (60, 1)
# Unshuffled accuracy: 0.5499999999999999
# -----
# binaryclassifier shuffled
# y: (60,)
# X: (60, 1)
# Shuffled accuracy: 0.6166666666666668
# -----
#
# Group: Early
# Animal: CTL1
# Trials: 30
# Neuron: 31 of 121
# -----
# binaryclassifier unshuffled
# y: (60,)
# X: (60, 1)
# Unshuffled accuracy: 0.85
# -----
# binaryclassifier shuffled
# y: (60,)
# X: (60, 1)
# Shuffled accuracy: 0.5833333333333333
# -----
#
# Group: Early
# Animal: CTL1
# Trials: 30
# Neuron: 32 of 121
# -----
# binaryclassifier unshuffled
# y: (60,)
# X: (60, 1)
# Unshuffled accuracy: 0.7166666666666667
# -----
# binaryclassifier shuffled
# y: (60,)
# X: (60, 1)
# Shuffled accuracy: 0.55
# -----
#
# Group: Early
# Animal: CTL1
# Trials: 30
# Neuron: 33 of 121
# -----
# binaryclassifier unshuffled
# y: (60,)
# X: (60, 1)
# Unshuffled accuracy: 0.8166666666666668
# -----
# binaryclassifier shuffled
# y: (60,)
# X: (60, 1)
# Shuffled accuracy: 0.55
# -----
#
# Group: Early
# Animal: CTL1
# Trials: 30
# Neuron: 34 of 121
# -----
# binaryclassifier unshuffled
# y: (60,)
# X: (60, 1)
# Unshuffled accuracy: 0.7166666666666666
# -----
# binaryclassifier shuffled
# y: (60,)
# X: (60, 1)
# Shuffled accuracy: 0.6
# -----
#
# Group: Early
# Animal: CTL1
# Trials: 30
# Neuron: 35 of 121
# -----
# binaryclassifier unshuffled
# y: (60,)
# X: (60, 1)
# Unshuffled accuracy: 0.7166666666666668
# -----
# binaryclassifier shuffled
# y: (60,)
# X: (60, 1)
# Shuffled accuracy: 0.5166666666666667
# -----
#
# Group: Early
# Animal: CTL1
# Trials: 30
# Neuron: 36 of 121
# -----
# binaryclassifier unshuffled
# y: (60,)
# X: (60, 1)
# Unshuffled accuracy: 0.75
# -----
# binaryclassifier shuffled
# y: (60,)
# X: (60, 1)
# Shuffled accuracy: 0.5666666666666667
# -----
#
# Group: Early
# Animal: CTL1
# Trials: 30
# Neuron: 37 of 121
# -----
# binaryclassifier unshuffled
# y: (60,)
# X: (60, 1)
# Unshuffled accuracy: 0.5833333333333333
# -----
# binaryclassifier shuffled
# y: (60,)
# X: (60, 1)
# Shuffled accuracy: 0.5166666666666667
# -----
#
# Group: Early
# Animal: CTL1
# Trials: 30
# Neuron: 38 of 121
# -----
# binaryclassifier unshuffled
# y: (60,)
# X: (60, 1)
# Unshuffled accuracy: 0.9
# -----
# binaryclassifier shuffled
# y: (60,)
# X: (60, 1)
# Shuffled accuracy: 0.4833333333333333
# -----
#
# Group: Early
# Animal: CTL1
# Trials: 30
# Neuron: 39 of 121
# -----
# binaryclassifier unshuffled
# y: (60,)
# X: (60, 1)
# Unshuffled accuracy: 0.9166666666666667
# -----
# binaryclassifier shuffled
# y: (60,)
# X: (60, 1)
# Shuffled accuracy: 0.5666666666666667
# -----
#
# Group: Early
# Animal: CTL1
# Trials: 30
# Neuron: 40 of 121
# -----
# binaryclassifier unshuffled
# y: (60,)
# X: (60, 1)
# Unshuffled accuracy: 0.65
# -----
# binaryclassifier shuffled
# y: (60,)
# X: (60, 1)
# Shuffled accuracy: 0.4666666666666667
# -----
#
# Group: Early
# Animal: CTL1
# Trials: 30
# Neuron: 41 of 121
# -----
# binaryclassifier unshuffled
# y: (60,)
# X: (60, 1)
# Unshuffled accuracy: 0.6333333333333333
# -----
# binaryclassifier shuffled
# y: (60,)
# X: (60, 1)
# Shuffled accuracy: 0.6
# -----
#
# Group: Early
# Animal: CTL1
# Trials: 30
# Neuron: 42 of 121
# -----
# binaryclassifier unshuffled
# y: (60,)
# X: (60, 1)
# Unshuffled accuracy: 0.7166666666666666
# -----
# binaryclassifier shuffled
# y: (60,)
# X: (60, 1)
# Shuffled accuracy: 0.4666666666666667
# -----
#
# Group: Early
# Animal: CTL1
# Trials: 30
# Neuron: 43 of 121
# -----
# binaryclassifier unshuffled
# y: (60,)
# X: (60, 1)
# Unshuffled accuracy: 0.55
# -----
# binaryclassifier shuffled
# y: (60,)
# X: (60, 1)
# Shuffled accuracy: 0.7000000000000001
# -----
#
# Group: Early
# Animal: CTL1
# Trials: 30
# Neuron: 44 of 121
# -----
# binaryclassifier unshuffled
# y: (60,)
# X: (60, 1)
# Unshuffled accuracy: 0.6333333333333334
# -----
# binaryclassifier shuffled
# y: (60,)
# X: (60, 1)
# Shuffled accuracy: 0.5666666666666667
# -----
#
# Group: Early
# Animal: CTL1
# Trials: 30
# Neuron: 45 of 121
# -----
# binaryclassifier unshuffled
# y: (60,)
# X: (60, 1)
# Unshuffled accuracy: 0.5833333333333333
# -----
# binaryclassifier shuffled
# y: (60,)
# X: (60, 1)
# Shuffled accuracy: 0.4666666666666666
# -----
#
# Group: Early
# Animal: CTL1
# Trials: 30
# Neuron: 46 of 121
# -----
# binaryclassifier unshuffled
# y: (60,)
# X: (60, 1)
# Unshuffled accuracy: 0.7500000000000001
# -----
# binaryclassifier shuffled
# y: (60,)
# X: (60, 1)
# Shuffled accuracy: 0.55
# -----
#
# Group: Early
# Animal: CTL1
# Trials: 30
# Neuron: 47 of 121
# -----
# binaryclassifier unshuffled
# y: (60,)
# X: (60, 1)
# Unshuffled accuracy: 0.9
# -----
# binaryclassifier shuffled
# y: (60,)
# X: (60, 1)
# Shuffled accuracy: 0.6
# -----
#
# Group: Early
# Animal: CTL1
# Trials: 30
# Neuron: 48 of 121
# -----
# binaryclassifier unshuffled
# y: (60,)
# X: (60, 1)
# Unshuffled accuracy: 0.6333333333333334
# -----
# binaryclassifier shuffled
# y: (60,)
# X: (60, 1)
# Shuffled accuracy: 0.55
# -----
#
# Group: Early
# Animal: CTL1
# Trials: 30
# Neuron: 49 of 121
# -----
# binaryclassifier unshuffled
# y: (60,)
# X: (60, 1)
# Unshuffled accuracy: 0.5666666666666667
# -----
# binaryclassifier shuffled
# y: (60,)
# X: (60, 1)
# Shuffled accuracy: 0.6333333333333333
# -----
#
# Group: Early
# Animal: CTL1
# Trials: 30
# Neuron: 50 of 121
# -----
# binaryclassifier unshuffled
# y: (60,)
# X: (60, 1)
# Unshuffled accuracy: 0.65
# -----
# binaryclassifier shuffled
# y: (60,)
# X: (60, 1)
# Shuffled accuracy: 0.6333333333333333
# -----
#
# Group: Early
# Animal: CTL1
# Trials: 30
# Neuron: 51 of 121
# -----
# binaryclassifier unshuffled
# y: (60,)
# X: (60, 1)
# Unshuffled accuracy: 0.75
# -----
# binaryclassifier shuffled
# y: (60,)
# X: (60, 1)
# Shuffled accuracy: 0.5
# -----
#
# Group: Early
# Animal: CTL1
# Trials: 30
# Neuron: 52 of 121
# -----
# binaryclassifier unshuffled
# y: (60,)
# X: (60, 1)
# Unshuffled accuracy: 0.6833333333333332
# -----
# binaryclassifier shuffled
# y: (60,)
# X: (60, 1)
# Shuffled accuracy: 0.5666666666666667
# -----
#
# Group: Early
# Animal: CTL1
# Trials: 30
# Neuron: 53 of 121
# -----
# binaryclassifier unshuffled
# y: (60,)
# X: (60, 1)
# Unshuffled accuracy: 0.5666666666666667
# -----
# binaryclassifier shuffled
# y: (60,)
# X: (60, 1)
# Shuffled accuracy: 0.5333333333333333
# -----
#
# Group: Early
# Animal: CTL1
# Trials: 30
# Neuron: 54 of 121
# -----
# binaryclassifier unshuffled
# y: (60,)
# X: (60, 1)
# Unshuffled accuracy: 0.65
# -----
# binaryclassifier shuffled
# y: (60,)
# X: (60, 1)
# Shuffled accuracy: 0.7666666666666667
# -----
#
# Group: Early
# Animal: CTL1
# Trials: 30
# Neuron: 55 of 121
# -----
# binaryclassifier unshuffled
# y: (60,)
# X: (60, 1)
# Unshuffled accuracy: 0.6666666666666667
# -----
# binaryclassifier shuffled
# y: (60,)
# X: (60, 1)
# Shuffled accuracy: 0.4833333333333333
# -----
#
# Group: Early
# Animal: CTL1
# Trials: 30
# Neuron: 56 of 121
# -----
# binaryclassifier unshuffled
# y: (60,)
# X: (60, 1)
# Unshuffled accuracy: 0.7333333333333332
# -----
# binaryclassifier shuffled
# y: (60,)
# X: (60, 1)
# Shuffled accuracy: 0.5833333333333333
# -----
#
# Group: Early
# Animal: CTL1
# Trials: 30
# Neuron: 57 of 121
# -----
# binaryclassifier unshuffled
# y: (60,)
# X: (60, 1)
# Unshuffled accuracy: 0.7166666666666668
# -----
# binaryclassifier shuffled
# y: (60,)
# X: (60, 1)
# Shuffled accuracy: 0.4333333333333334
# -----
#
# Group: Early
# Animal: CTL1
# Trials: 30
# Neuron: 58 of 121
# -----
# binaryclassifier unshuffled
# y: (60,)
# X: (60, 1)
# Unshuffled accuracy: 0.65
# -----
# binaryclassifier shuffled
# y: (60,)
# X: (60, 1)
# Shuffled accuracy: 0.6166666666666667
# -----
#
# Group: Early
# Animal: CTL1
# Trials: 30
# Neuron: 59 of 121
# -----
# binaryclassifier unshuffled
# y: (60,)
# X: (60, 1)
# Unshuffled accuracy: 0.8166666666666667
# -----
# binaryclassifier shuffled
# y: (60,)
# X: (60, 1)
# Shuffled accuracy: 0.4666666666666667
# -----
#
# Group: Early
# Animal: CTL1
# Trials: 30
# Neuron: 60 of 121
# -----
# binaryclassifier unshuffled
# y: (60,)
# X: (60, 1)
# Unshuffled accuracy: 0.5666666666666667
# -----
# binaryclassifier shuffled
# y: (60,)
# X: (60, 1)
# Shuffled accuracy: 0.6333333333333334
# -----
#
# Group: Early
# Animal: CTL1
# Trials: 30
# Neuron: 61 of 121
# -----
# binaryclassifier unshuffled
# y: (60,)
# X: (60, 1)
# Unshuffled accuracy: 0.8
# -----
# binaryclassifier shuffled
# y: (60,)
# X: (60, 1)
# Shuffled accuracy: 0.5833333333333333
# -----
#
# Group: Early
# Animal: CTL1
# Trials: 30
# Neuron: 62 of 121
# -----
# binaryclassifier unshuffled
# y: (60,)
# X: (60, 1)
# Unshuffled accuracy: 0.75
# -----
# binaryclassifier shuffled
# y: (60,)
# X: (60, 1)
# Shuffled accuracy: 0.6
# -----
#
# Group: Early
# Animal: CTL1
# Trials: 30
# Neuron: 63 of 121
# -----
# binaryclassifier unshuffled
# y: (60,)
# X: (60, 1)
# Unshuffled accuracy: 0.6833333333333333
# -----
# binaryclassifier shuffled
# y: (60,)
# X: (60, 1)
# Shuffled accuracy: 0.5833333333333333
# -----
#
# Group: Early
# Animal: CTL1
# Trials: 30
# Neuron: 64 of 121
# -----
# binaryclassifier unshuffled
# y: (60,)
# X: (60, 1)
# Unshuffled accuracy: 0.7166666666666666
# -----
# binaryclassifier shuffled
# y: (60,)
# X: (60, 1)
# Shuffled accuracy: 0.6166666666666666
# -----
#
# Group: Early
# Animal: CTL1
# Trials: 30
# Neuron: 65 of 121
# -----
# binaryclassifier unshuffled
# y: (60,)
# X: (60, 1)
# Unshuffled accuracy: 0.7999999999999999
# -----
# binaryclassifier shuffled
# y: (60,)
# X: (60, 1)
# Shuffled accuracy: 0.55
# -----
#
# Group: Early
# Animal: CTL1
# Trials: 30
# Neuron: 66 of 121
# -----
# binaryclassifier unshuffled
# y: (60,)
# X: (60, 1)
# Unshuffled accuracy: 0.7
# -----
# binaryclassifier shuffled
# y: (60,)
# X: (60, 1)
# Shuffled accuracy: 0.6
# -----
#
# Group: Early
# Animal: CTL1
# Trials: 30
# Neuron: 67 of 121
# -----
# binaryclassifier unshuffled
# y: (60,)
# X: (60, 1)
# Unshuffled accuracy: 0.8333333333333333
# -----
# binaryclassifier shuffled
# y: (60,)
# X: (60, 1)
# Shuffled accuracy: 0.6
# -----
#
# Group: Early
# Animal: CTL1
# Trials: 30
# Neuron: 68 of 121
# -----
# binaryclassifier unshuffled
# y: (60,)
# X: (60, 1)
# Unshuffled accuracy: 0.8166666666666668
# -----
# binaryclassifier shuffled
# y: (60,)
# X: (60, 1)
# Shuffled accuracy: 0.6666666666666667
# -----
#
# Group: Early
# Animal: CTL1
# Trials: 30
# Neuron: 69 of 121
# -----
# binaryclassifier unshuffled
# y: (60,)
# X: (60, 1)
# Unshuffled accuracy: 0.7333333333333333
# -----
# binaryclassifier shuffled
# y: (60,)
# X: (60, 1)
# Shuffled accuracy: 0.5333333333333333
# -----
#
# Group: Early
# Animal: CTL1
# Trials: 30
# Neuron: 70 of 121
# -----
# binaryclassifier unshuffled
# y: (60,)
# X: (60, 1)
# Unshuffled accuracy: 0.6833333333333333
# -----
# binaryclassifier shuffled
# y: (60,)
# X: (60, 1)
# Shuffled accuracy: 0.55
# -----
#
# Group: Early
# Animal: CTL1
# Trials: 30
# Neuron: 71 of 121
# -----
# binaryclassifier unshuffled
# y: (60,)
# X: (60, 1)
# Unshuffled accuracy: 0.6833333333333333
# -----
# binaryclassifier shuffled
# y: (60,)
# X: (60, 1)
# Shuffled accuracy: 0.5166666666666666
# -----
#
# Group: Early
# Animal: CTL1
# Trials: 30
# Neuron: 72 of 121
# -----
# binaryclassifier unshuffled
# y: (60,)
# X: (60, 1)
# Unshuffled accuracy: 0.75
# -----
# binaryclassifier shuffled
# y: (60,)
# X: (60, 1)
# Shuffled accuracy: 0.6
# -----
#
# Group: Early
# Animal: CTL1
# Trials: 30
# Neuron: 73 of 121
# -----
# binaryclassifier unshuffled
# y: (60,)
# X: (60, 1)
# Unshuffled accuracy: 0.8333333333333334
# -----
# binaryclassifier shuffled
# y: (60,)
# X: (60, 1)
# Shuffled accuracy: 0.5333333333333333
# -----
#
# Group: Early
# Animal: CTL1
# Trials: 30
# Neuron: 74 of 121
# -----
# binaryclassifier unshuffled
# y: (60,)
# X: (60, 1)
# Unshuffled accuracy: 0.7
# -----
# binaryclassifier shuffled
# y: (60,)
# X: (60, 1)
# Shuffled accuracy: 0.5
# -----
#
# Group: Early
# Animal: CTL1
# Trials: 30
# Neuron: 75 of 121
# -----
# binaryclassifier unshuffled
# y: (60,)
# X: (60, 1)
# Unshuffled accuracy: 0.6166666666666666
# -----
# binaryclassifier shuffled
# y: (60,)
# X: (60, 1)
# Shuffled accuracy: 0.5166666666666666
# -----
#
# Group: Early
# Animal: CTL1
# Trials: 30
# Neuron: 76 of 121
# -----
# binaryclassifier unshuffled
# y: (60,)
# X: (60, 1)
# Unshuffled accuracy: 0.7
# -----
# binaryclassifier shuffled
# y: (60,)
# X: (60, 1)
# Shuffled accuracy: 0.5166666666666666
# -----
#
# Group: Early
# Animal: CTL1
# Trials: 30
# Neuron: 77 of 121
# -----
# binaryclassifier unshuffled
# y: (60,)
# X: (60, 1)
# Unshuffled accuracy: 0.8833333333333332
# -----
# binaryclassifier shuffled
# y: (60,)
# X: (60, 1)
# Shuffled accuracy: 0.5666666666666667
# -----
#
# Group: Early
# Animal: CTL1
# Trials: 30
# Neuron: 78 of 121
# -----
# binaryclassifier unshuffled
# y: (60,)
# X: (60, 1)
# Unshuffled accuracy: 0.6166666666666667
# -----
# binaryclassifier shuffled
# y: (60,)
# X: (60, 1)
# Shuffled accuracy: 0.5666666666666667
# -----
#
# Group: Early
# Animal: CTL1
# Trials: 30
# Neuron: 79 of 121
# -----
# binaryclassifier unshuffled
# y: (60,)
# X: (60, 1)
# Unshuffled accuracy: 0.6166666666666666
# -----
# binaryclassifier shuffled
# y: (60,)
# X: (60, 1)
# Shuffled accuracy: 0.6
# -----
#
# Group: Early
# Animal: CTL1
# Trials: 30
# Neuron: 80 of 121
# -----
# binaryclassifier unshuffled
# y: (60,)
# X: (60, 1)
# Unshuffled accuracy: 0.8166666666666668
# -----
# binaryclassifier shuffled
# y: (60,)
# X: (60, 1)
# Shuffled accuracy: 0.4833333333333333
# -----
#
# Group: Early
# Animal: CTL1
# Trials: 30
# Neuron: 81 of 121
# -----
# binaryclassifier unshuffled
# y: (60,)
# X: (60, 1)
# Unshuffled accuracy: 0.6833333333333333
# -----
# binaryclassifier shuffled
# y: (60,)
# X: (60, 1)
# Shuffled accuracy: 0.5
# -----
#
# Group: Early
# Animal: CTL1
# Trials: 30
# Neuron: 82 of 121
# -----
# binaryclassifier unshuffled
# y: (60,)
# X: (60, 1)
# Unshuffled accuracy: 0.7
# -----
# binaryclassifier shuffled
# y: (60,)
# X: (60, 1)
# Shuffled accuracy: 0.6166666666666667
# -----
#
# Group: Early
# Animal: CTL1
# Trials: 30
# Neuron: 83 of 121
# -----
# binaryclassifier unshuffled
# y: (60,)
# X: (60, 1)
# Unshuffled accuracy: 0.7666666666666666
# -----
# binaryclassifier shuffled
# y: (60,)
# X: (60, 1)
# Shuffled accuracy: 0.5333333333333334
# -----
#
# Group: Early
# Animal: CTL1
# Trials: 30
# Neuron: 84 of 121
# -----
# binaryclassifier unshuffled
# y: (60,)
# X: (60, 1)
# Unshuffled accuracy: 0.7833333333333334
# -----
# binaryclassifier shuffled
# y: (60,)
# X: (60, 1)
# Shuffled accuracy: 0.6
# -----
#
# Group: Early
# Animal: CTL1
# Trials: 30
# Neuron: 85 of 121
# -----
# binaryclassifier unshuffled
# y: (60,)
# X: (60, 1)
# Unshuffled accuracy: 0.7166666666666667
# -----
# binaryclassifier shuffled
# y: (60,)
# X: (60, 1)
# Shuffled accuracy: 0.5
# -----
#
# Group: Early
# Animal: CTL1
# Trials: 30
# Neuron: 86 of 121
# -----
# binaryclassifier unshuffled
# y: (60,)
# X: (60, 1)
# Unshuffled accuracy: 0.6833333333333333
# -----
# binaryclassifier shuffled
# y: (60,)
# X: (60, 1)
# Shuffled accuracy: 0.5833333333333333
# -----
#
# Group: Early
# Animal: CTL1
# Trials: 30
# Neuron: 87 of 121
# -----
# binaryclassifier unshuffled
# y: (60,)
# X: (60, 1)
# Unshuffled accuracy: 0.8
# -----
# binaryclassifier shuffled
# y: (60,)
# X: (60, 1)
# Shuffled accuracy: 0.5166666666666666
# -----
#
# Group: Early
# Animal: CTL1
# Trials: 30
# Neuron: 88 of 121
# -----
# binaryclassifier unshuffled
# y: (60,)
# X: (60, 1)
# Unshuffled accuracy: 0.8666666666666668
# -----
# binaryclassifier shuffled
# y: (60,)
# X: (60, 1)
# Shuffled accuracy: 0.6833333333333333
# -----
#
# Group: Early
# Animal: CTL1
# Trials: 30
# Neuron: 89 of 121
# -----
# binaryclassifier unshuffled
# y: (60,)
# X: (60, 1)
# Unshuffled accuracy: 0.8166666666666668
# -----
# binaryclassifier shuffled
# y: (60,)
# X: (60, 1)
# Shuffled accuracy: 0.6
# -----
#
# Group: Early
# Animal: CTL1
# Trials: 30
# Neuron: 90 of 121
# -----
# binaryclassifier unshuffled
# y: (60,)
# X: (60, 1)
# Unshuffled accuracy: 0.7166666666666666
# -----
# binaryclassifier shuffled
# y: (60,)
# X: (60, 1)
# Shuffled accuracy: 0.5833333333333334
# -----
#
# Group: Early
# Animal: CTL1
# Trials: 30
# Neuron: 91 of 121
# -----
# binaryclassifier unshuffled
# y: (60,)
# X: (60, 1)
# Unshuffled accuracy: 0.5999999999999999
# -----
# binaryclassifier shuffled
# y: (60,)
# X: (60, 1)
# Shuffled accuracy: 0.5
# -----
#
# Group: Early
# Animal: CTL1
# Trials: 30
# Neuron: 92 of 121
# -----
# binaryclassifier unshuffled
# y: (60,)
# X: (60, 1)
# Unshuffled accuracy: 0.6333333333333333
# -----
# binaryclassifier shuffled
# y: (60,)
# X: (60, 1)
# Shuffled accuracy: 0.5833333333333334
# -----
#
# Group: Early
# Animal: CTL1
# Trials: 30
# Neuron: 93 of 121
# -----
# binaryclassifier unshuffled
# y: (60,)
# X: (60, 1)
# Unshuffled accuracy: 0.4833333333333333
# -----
# binaryclassifier shuffled
# y: (60,)
# X: (60, 1)
# Shuffled accuracy: 0.5666666666666667
# -----
#
# Group: Early
# Animal: CTL1
# Trials: 30
# Neuron: 94 of 121
# -----
# binaryclassifier unshuffled
# y: (60,)
# X: (60, 1)
# Unshuffled accuracy: 0.6333333333333334
# -----
# binaryclassifier shuffled
# y: (60,)
# X: (60, 1)
# Shuffled accuracy: 0.6166666666666667
# -----
#
# Group: Early
# Animal: CTL1
# Trials: 30
# Neuron: 95 of 121
# -----
# binaryclassifier unshuffled
# y: (60,)
# X: (60, 1)
# Unshuffled accuracy: 0.5833333333333333
# -----
# binaryclassifier shuffled
# y: (60,)
# X: (60, 1)
# Shuffled accuracy: 0.4666666666666667
# -----
#
# Group: Early
# Animal: CTL1
# Trials: 30
# Neuron: 96 of 121
# -----
# binaryclassifier unshuffled
# y: (60,)
# X: (60, 1)
# Unshuffled accuracy: 0.7666666666666666
# -----
# binaryclassifier shuffled
# y: (60,)
# X: (60, 1)
# Shuffled accuracy: 0.55
# -----
#
# Group: Early
# Animal: CTL1
# Trials: 30
# Neuron: 97 of 121
# -----
# binaryclassifier unshuffled
# y: (60,)
# X: (60, 1)
# Unshuffled accuracy: 0.6833333333333333
# -----
# binaryclassifier shuffled
# y: (60,)
# X: (60, 1)
# Shuffled accuracy: 0.5333333333333333
# -----
#
# Group: Early
# Animal: CTL1
# Trials: 30
# Neuron: 98 of 121
# -----
# binaryclassifier unshuffled
# y: (60,)
# X: (60, 1)
# Unshuffled accuracy: 0.7166666666666667
# -----
# binaryclassifier shuffled
# y: (60,)
# X: (60, 1)
# Shuffled accuracy: 0.5666666666666668
# -----
#
# Group: Early
# Animal: CTL1
# Trials: 30
# Neuron: 99 of 121
# -----
# binaryclassifier unshuffled
# y: (60,)
# X: (60, 1)
# Unshuffled accuracy: 0.6833333333333333
# -----
# binaryclassifier shuffled
# y: (60,)
# X: (60, 1)
# Shuffled accuracy: 0.5666666666666667
# -----
#
# Group: Early
# Animal: CTL1
# Trials: 30
# Neuron: 100 of 121
# -----
# binaryclassifier unshuffled
# y: (60,)
# X: (60, 1)
# Unshuffled accuracy: 0.6
# -----
# binaryclassifier shuffled
# y: (60,)
# X: (60, 1)
# Shuffled accuracy: 0.5999999999999999
# -----
#
# Group: Early
# Animal: CTL1
# Trials: 30
# Neuron: 101 of 121
# -----
# binaryclassifier unshuffled
# y: (60,)
# X: (60, 1)
# Unshuffled accuracy: 0.7000000000000001
# -----
# binaryclassifier shuffled
# y: (60,)
# X: (60, 1)
# Shuffled accuracy: 0.6166666666666667
# -----
#
# Group: Early
# Animal: CTL1
# Trials: 30
# Neuron: 102 of 121
# -----
# binaryclassifier unshuffled
# y: (60,)
# X: (60, 1)
# Unshuffled accuracy: 0.8666666666666668
# -----
# binaryclassifier shuffled
# y: (60,)
# X: (60, 1)
# Shuffled accuracy: 0.5666666666666667
# -----
#
# Group: Early
# Animal: CTL1
# Trials: 30
# Neuron: 103 of 121
# -----
# binaryclassifier unshuffled
# y: (60,)
# X: (60, 1)
# Unshuffled accuracy: 0.65
# -----
# binaryclassifier shuffled
# y: (60,)
# X: (60, 1)
# Shuffled accuracy: 0.4666666666666666
# -----
#
# Group: Early
# Animal: CTL1
# Trials: 30
# Neuron: 104 of 121
# -----
# binaryclassifier unshuffled
# y: (60,)
# X: (60, 1)
# Unshuffled accuracy: 0.6166666666666667
# -----
# binaryclassifier shuffled
# y: (60,)
# X: (60, 1)
# Shuffled accuracy: 0.5333333333333333
# -----
#
# Group: Early
# Animal: CTL1
# Trials: 30
# Neuron: 105 of 121
# -----
# binaryclassifier unshuffled
# y: (60,)
# X: (60, 1)
# Unshuffled accuracy: 0.8333333333333334
# -----
# binaryclassifier shuffled
# y: (60,)
# X: (60, 1)
# Shuffled accuracy: 0.6499999999999999
# -----
#
# Group: Early
# Animal: CTL1
# Trials: 30
# Neuron: 106 of 121
# -----
# binaryclassifier unshuffled
# y: (60,)
# X: (60, 1)
# Unshuffled accuracy: 0.6666666666666666
# -----
# binaryclassifier shuffled
# y: (60,)
# X: (60, 1)
# Shuffled accuracy: 0.6333333333333334
# -----
#
# Group: Early
# Animal: CTL1
# Trials: 30
# Neuron: 107 of 121
# -----
# binaryclassifier unshuffled
# y: (60,)
# X: (60, 1)
# Unshuffled accuracy: 0.7833333333333334
# -----
# binaryclassifier shuffled
# y: (60,)
# X: (60, 1)
# Shuffled accuracy: 0.5666666666666667
# -----
#
# Group: Early
# Animal: CTL1
# Trials: 30
# Neuron: 108 of 121
# -----
# binaryclassifier unshuffled
# y: (60,)
# X: (60, 1)
# Unshuffled accuracy: 0.6500000000000001
# -----
# binaryclassifier shuffled
# y: (60,)
# X: (60, 1)
# Shuffled accuracy: 0.5833333333333334
# -----
#
# Group: Early
# Animal: CTL1
# Trials: 30
# Neuron: 109 of 121
# -----
# binaryclassifier unshuffled
# y: (60,)
# X: (60, 1)
# Unshuffled accuracy: 0.8166666666666667
# -----
# binaryclassifier shuffled
# y: (60,)
# X: (60, 1)
# Shuffled accuracy: 0.5499999999999999
# -----
#
# Group: Early
# Animal: CTL1
# Trials: 30
# Neuron: 110 of 121
# -----
# binaryclassifier unshuffled
# y: (60,)
# X: (60, 1)
# Unshuffled accuracy: 0.55
# -----
# binaryclassifier shuffled
# y: (60,)
# X: (60, 1)
# Shuffled accuracy: 0.5833333333333333
# -----
#
# Group: Early
# Animal: CTL1
# Trials: 30
# Neuron: 111 of 121
# -----
# binaryclassifier unshuffled
# y: (60,)
# X: (60, 1)
# Unshuffled accuracy: 0.7166666666666667
# -----
# binaryclassifier shuffled
# y: (60,)
# X: (60, 1)
# Shuffled accuracy: 0.55
# -----
#
# Group: Early
# Animal: CTL1
# Trials: 30
# Neuron: 112 of 121
# -----
# binaryclassifier unshuffled
# y: (60,)
# X: (60, 1)
# Unshuffled accuracy: 0.7
# -----
# binaryclassifier shuffled
# y: (60,)
# X: (60, 1)
# Shuffled accuracy: 0.6666666666666667
# -----
#
# Group: Early
# Animal: CTL1
# Trials: 30
# Neuron: 113 of 121
# -----
# binaryclassifier unshuffled
# y: (60,)
# X: (60, 1)
# Unshuffled accuracy: 0.5
# -----
# binaryclassifier shuffled
# y: (60,)
# X: (60, 1)
# Shuffled accuracy: 0.5333333333333333
# -----
#
# Group: Early
# Animal: CTL1
# Trials: 30
# Neuron: 114 of 121
# -----
# binaryclassifier unshuffled
# y: (60,)
# X: (60, 1)
# Unshuffled accuracy: 0.9000000000000001
# -----
# binaryclassifier shuffled
# y: (60,)
# X: (60, 1)
# Shuffled accuracy: 0.7166666666666667
# -----
#
# Group: Early
# Animal: CTL1
# Trials: 30
# Neuron: 115 of 121
# -----
# binaryclassifier unshuffled
# y: (60,)
# X: (60, 1)
# Unshuffled accuracy: 0.8
# -----
# binaryclassifier shuffled
# y: (60,)
# X: (60, 1)
# Shuffled accuracy: 0.5666666666666667
# -----
#
# Group: Early
# Animal: CTL1
# Trials: 30
# Neuron: 116 of 121
# -----
# binaryclassifier unshuffled
# y: (60,)
# X: (60, 1)
# Unshuffled accuracy: 0.65
# -----
# binaryclassifier shuffled
# y: (60,)
# X: (60, 1)
# Shuffled accuracy: 0.5666666666666667
# -----
#
# Group: Early
# Animal: CTL1
# Trials: 30
# Neuron: 117 of 121
# -----
# binaryclassifier unshuffled
# y: (60,)
# X: (60, 1)
# Unshuffled accuracy: 0.6666666666666667
# -----
# binaryclassifier shuffled
# y: (60,)
# X: (60, 1)
# Shuffled accuracy: 0.5
# -----
#
# Group: Early
# Animal: CTL1
# Trials: 30
# Neuron: 118 of 121
# -----
# binaryclassifier unshuffled
# y: (60,)
# X: (60, 1)
# Unshuffled accuracy: 0.7833333333333334
# -----
# binaryclassifier shuffled
# y: (60,)
# X: (60, 1)
# Shuffled accuracy: 0.45
# -----
#
# Group: Early
# Animal: CTL1
# Trials: 30
# Neuron: 119 of 121
# -----
# binaryclassifier unshuffled
# y: (60,)
# X: (60, 1)
# Unshuffled accuracy: 0.9
# -----
# binaryclassifier shuffled
# y: (60,)
# X: (60, 1)
# Shuffled accuracy: 0.4833333333333333
# -----
#
# Group: Early
# Animal: CTL1
# Trials: 30
# Neuron: 120 of 121
# -----
# binaryclassifier unshuffled
# y: (60,)
# X: (60, 1)
# Unshuffled accuracy: 0.6833333333333333
# -----
# binaryclassifier shuffled
# y: (60,)
# X: (60, 1)
# Shuffled accuracy: 0.6
# -----
#
# Group: Early
# Animal: ER-L1
# Trials: 28
# Neuron: 0 of 257
# -----
# binaryclassifier unshuffled
# y: (56,)
# X: (56, 1)
# Unshuffled accuracy: 0.48
# -----
# binaryclassifier shuffled
# y: (56,)
# X: (56, 1)
# Shuffled accuracy: 0.5233333333333333
# -----
#
# Group: Early
# Animal: ER-L1
# Trials: 28
# Neuron: 1 of 257
# -----
# binaryclassifier unshuffled
# y: (56,)
# X: (56, 1)
# Unshuffled accuracy: 0.5399999999999999
# -----
# binaryclassifier shuffled
# y: (56,)
# X: (56, 1)
# Shuffled accuracy: 0.6
# -----
#
# Group: Early
# Animal: ER-L1
# Trials: 28
# Neuron: 2 of 257
# -----
# binaryclassifier unshuffled
# y: (56,)
# X: (56, 1)
# Unshuffled accuracy: 0.6799999999999999
# -----
# binaryclassifier shuffled
# y: (56,)
# X: (56, 1)
# Shuffled accuracy: 0.5666666666666667
# -----
#
# Group: Early
# Animal: ER-L1
# Trials: 28
# Neuron: 3 of 257
# -----
# binaryclassifier unshuffled
# y: (56,)
# X: (56, 1)
# Unshuffled accuracy: 0.5933333333333333
# -----
# binaryclassifier shuffled
# y: (56,)
# X: (56, 1)
# Shuffled accuracy: 0.7133333333333333
# -----
#
# Group: Early
# Animal: ER-L1
# Trials: 28
# Neuron: 4 of 257
# -----
# binaryclassifier unshuffled
# y: (56,)
# X: (56, 1)
# Unshuffled accuracy: 0.65
# -----
# binaryclassifier shuffled
# y: (56,)
# X: (56, 1)
# Shuffled accuracy: 0.4766666666666667
# -----
#
# Group: Early
# Animal: ER-L1
# Trials: 28
# Neuron: 5 of 257
# -----
# binaryclassifier unshuffled
# y: (56,)
# X: (56, 1)
# Unshuffled accuracy: 0.44666666666666666
# -----
# binaryclassifier shuffled
# y: (56,)
# X: (56, 1)
# Shuffled accuracy: 0.59
# -----
#
# Group: Early
# Animal: ER-L1
# Trials: 28
# Neuron: 6 of 257
# -----
# binaryclassifier unshuffled
# y: (56,)
# X: (56, 1)
# Unshuffled accuracy: 0.7033333333333334
# -----
# binaryclassifier shuffled
# y: (56,)
# X: (56, 1)
# Shuffled accuracy: 0.5700000000000001
# -----
#
# Group: Early
# Animal: ER-L1
# Trials: 28
# Neuron: 7 of 257
# -----
# binaryclassifier unshuffled
# y: (56,)
# X: (56, 1)
# Unshuffled accuracy: 0.6433333333333333
# -----
# binaryclassifier shuffled
# y: (56,)
# X: (56, 1)
# Shuffled accuracy: 0.6
# -----
#
# Group: Early
# Animal: ER-L1
# Trials: 28
# Neuron: 8 of 257
# -----
# binaryclassifier unshuffled
# y: (56,)
# X: (56, 1)
# Unshuffled accuracy: 0.5366666666666665
# -----
# binaryclassifier shuffled
# y: (56,)
# X: (56, 1)
# Shuffled accuracy: 0.6433333333333333
# -----
#
# Group: Early
# Animal: ER-L1
# Trials: 28
# Neuron: 9 of 257
# -----
# binaryclassifier unshuffled
# y: (56,)
# X: (56, 1)
# Unshuffled accuracy: 0.5533333333333333
# -----
# binaryclassifier shuffled
# y: (56,)
# X: (56, 1)
# Shuffled accuracy: 0.5833333333333334
# -----
#
# Group: Early
# Animal: ER-L1
# Trials: 28
# Neuron: 10 of 257
# -----
# binaryclassifier unshuffled
# y: (56,)
# X: (56, 1)
# Unshuffled accuracy: 0.48666666666666664
# -----
# binaryclassifier shuffled
# y: (56,)
# X: (56, 1)
# Shuffled accuracy: 0.49333333333333335
# -----
#
# Group: Early
# Animal: ER-L1
# Trials: 28
# Neuron: 11 of 257
# -----
# binaryclassifier unshuffled
# y: (56,)
# X: (56, 1)
# Unshuffled accuracy: 0.7166666666666666
# -----
# binaryclassifier shuffled
# y: (56,)
# X: (56, 1)
# Shuffled accuracy: 0.6066666666666667
# -----
#
# Group: Early
# Animal: ER-L1
# Trials: 28
# Neuron: 12 of 257
# -----
# binaryclassifier unshuffled
# y: (56,)
# X: (56, 1)
# Unshuffled accuracy: 0.6133333333333333
# -----
# binaryclassifier shuffled
# y: (56,)
# X: (56, 1)
# Shuffled accuracy: 0.5233333333333333
# -----
#
# Group: Early
# Animal: ER-L1
# Trials: 28
# Neuron: 13 of 257
# -----
# binaryclassifier unshuffled
# y: (56,)
# X: (56, 1)
# Unshuffled accuracy: 0.57
# -----
# binaryclassifier shuffled
# y: (56,)
# X: (56, 1)
# Shuffled accuracy: 0.5866666666666667
# -----
#
# Group: Early
# Animal: ER-L1
# Trials: 28
# Neuron: 14 of 257
# -----
# binaryclassifier unshuffled
# y: (56,)
# X: (56, 1)
# Unshuffled accuracy: 0.6100000000000001
# -----
# binaryclassifier shuffled
# y: (56,)
# X: (56, 1)
# Shuffled accuracy: 0.6799999999999999
# -----
#
# Group: Early
# Animal: ER-L1
# Trials: 28
# Neuron: 15 of 257
# -----
# binaryclassifier unshuffled
# y: (56,)
# X: (56, 1)
# Unshuffled accuracy: 0.5866666666666667
# -----
# binaryclassifier shuffled
# y: (56,)
# X: (56, 1)
# Shuffled accuracy: 0.5399999999999999
# -----
#
# Group: Early
# Animal: ER-L1
# Trials: 28
# Neuron: 16 of 257
# -----
# binaryclassifier unshuffled
# y: (56,)
# X: (56, 1)
# Unshuffled accuracy: 0.6733333333333332
# -----
# binaryclassifier shuffled
# y: (56,)
# X: (56, 1)
# Shuffled accuracy: 0.6799999999999999
# -----
#
# Group: Early
# Animal: ER-L1
# Trials: 28
# Neuron: 17 of 257
# -----
# binaryclassifier unshuffled
# y: (56,)
# X: (56, 1)
# Unshuffled accuracy: 0.3933333333333333
# -----
# binaryclassifier shuffled
# y: (56,)
# X: (56, 1)
# Shuffled accuracy: 0.3933333333333333
# -----
#
# Group: Early
# Animal: ER-L1
# Trials: 28
# Neuron: 18 of 257
# -----
# binaryclassifier unshuffled
# y: (56,)
# X: (56, 1)
# Unshuffled accuracy: 0.42000000000000004
# -----
# binaryclassifier shuffled
# y: (56,)
# X: (56, 1)
# Shuffled accuracy: 0.4966666666666667
# -----
#
# Group: Early
# Animal: ER-L1
# Trials: 28
# Neuron: 19 of 257
# -----
# binaryclassifier unshuffled
# y: (56,)
# X: (56, 1)
# Unshuffled accuracy: 0.49000000000000005
# -----
# binaryclassifier shuffled
# y: (56,)
# X: (56, 1)
# Shuffled accuracy: 0.42666666666666664
# -----
#
# Group: Early
# Animal: ER-L1
# Trials: 28
# Neuron: 20 of 257
# -----
# binaryclassifier unshuffled
# y: (56,)
# X: (56, 1)
# Unshuffled accuracy: 0.6533333333333333
# -----
# binaryclassifier shuffled
# y: (56,)
# X: (56, 1)
# Shuffled accuracy: 0.63
# -----
#
# Group: Early
# Animal: ER-L1
# Trials: 28
# Neuron: 21 of 257
# -----
# binaryclassifier unshuffled
# y: (56,)
# X: (56, 1)
# Unshuffled accuracy: 0.63
# -----
# binaryclassifier shuffled
# y: (56,)
# X: (56, 1)
# Shuffled accuracy: 0.4833333333333333
# -----
#
# Group: Early
# Animal: ER-L1
# Trials: 28
# Neuron: 22 of 257
# -----
# binaryclassifier unshuffled
# y: (56,)
# X: (56, 1)
# Unshuffled accuracy: 0.44333333333333336
# -----
# binaryclassifier shuffled
# y: (56,)
# X: (56, 1)
# Shuffled accuracy: 0.6433333333333333
# -----
#
# Group: Early
# Animal: ER-L1
# Trials: 28
# Neuron: 23 of 257
# -----
# binaryclassifier unshuffled
# y: (56,)
# X: (56, 1)
# Unshuffled accuracy: 0.64
# -----
# binaryclassifier shuffled
# y: (56,)
# X: (56, 1)
# Shuffled accuracy: 0.66
# -----
#
# Group: Early
# Animal: ER-L1
# Trials: 28
# Neuron: 24 of 257
# -----
# binaryclassifier unshuffled
# y: (56,)
# X: (56, 1)
# Unshuffled accuracy: 0.6466666666666666
# -----
# binaryclassifier shuffled
# y: (56,)
# X: (56, 1)
# Shuffled accuracy: 0.7366666666666666
# -----
#
# Group: Early
# Animal: ER-L1
# Trials: 28
# Neuron: 25 of 257
# -----
# binaryclassifier unshuffled
# y: (56,)
# X: (56, 1)
# Unshuffled accuracy: 0.6833333333333333
# -----
# binaryclassifier shuffled
# y: (56,)
# X: (56, 1)
# Shuffled accuracy: 0.54
# -----
#
# Group: Early
# Animal: ER-L1
# Trials: 28
# Neuron: 26 of 257
# -----
# binaryclassifier unshuffled
# y: (56,)
# X: (56, 1)
# Unshuffled accuracy: 0.5199999999999999
# -----
# binaryclassifier shuffled
# y: (56,)
# X: (56, 1)
# Shuffled accuracy: 0.6233333333333333
# -----
#
# Group: Early
# Animal: ER-L1
# Trials: 28
# Neuron: 27 of 257
# -----
# binaryclassifier unshuffled
# y: (56,)
# X: (56, 1)
# Unshuffled accuracy: 0.6466666666666667
# -----
# binaryclassifier shuffled
# y: (56,)
# X: (56, 1)
# Shuffled accuracy: 0.5
# -----
#
# Group: Early
# Animal: ER-L1
# Trials: 28
# Neuron: 28 of 257
# -----
# binaryclassifier unshuffled
# y: (56,)
# X: (56, 1)
# Unshuffled accuracy: 0.5999999999999999
# -----
# binaryclassifier shuffled
# y: (56,)
# X: (56, 1)
# Shuffled accuracy: 0.5733333333333333
# -----
#
# Group: Early
# Animal: ER-L1
# Trials: 28
# Neuron: 29 of 257
# -----
# binaryclassifier unshuffled
# y: (56,)
# X: (56, 1)
# Unshuffled accuracy: 0.4166666666666667
# -----
# binaryclassifier shuffled
# y: (56,)
# X: (56, 1)
# Shuffled accuracy: 0.5333333333333333
# -----
#
# Group: Early
# Animal: ER-L1
# Trials: 28
# Neuron: 30 of 257
# -----
# binaryclassifier unshuffled
# y: (56,)
# X: (56, 1)
# Unshuffled accuracy: 0.6533333333333333
# -----
# binaryclassifier shuffled
# y: (56,)
# X: (56, 1)
# Shuffled accuracy: 0.5700000000000001
# -----
#
# Group: Early
# Animal: ER-L1
# Trials: 28
# Neuron: 31 of 257
# -----
# binaryclassifier unshuffled
# y: (56,)
# X: (56, 1)
# Unshuffled accuracy: 0.63
# -----
# binaryclassifier shuffled
# y: (56,)
# X: (56, 1)
# Shuffled accuracy: 0.5166666666666666
# -----
#
# Group: Early
# Animal: ER-L1
# Trials: 28
# Neuron: 32 of 257
# -----
# binaryclassifier unshuffled
# y: (56,)
# X: (56, 1)
# Unshuffled accuracy: 0.6366666666666666
# -----
# binaryclassifier shuffled
# y: (56,)
# X: (56, 1)
# Shuffled accuracy: 0.5866666666666667
# -----
#
# Group: Early
# Animal: ER-L1
# Trials: 28
# Neuron: 33 of 257
# -----
# binaryclassifier unshuffled
# y: (56,)
# X: (56, 1)
# Unshuffled accuracy: 0.6399999999999999
# -----
# binaryclassifier shuffled
# y: (56,)
# X: (56, 1)
# Shuffled accuracy: 0.4966666666666667
# -----
#
# Group: Early
# Animal: ER-L1
# Trials: 28
# Neuron: 34 of 257
# -----
# binaryclassifier unshuffled
# y: (56,)
# X: (56, 1)
# Unshuffled accuracy: 0.6566666666666666
# -----
# binaryclassifier shuffled
# y: (56,)
# X: (56, 1)
# Shuffled accuracy: 0.7
# -----
#
# Group: Early
# Animal: ER-L1
# Trials: 28
# Neuron: 35 of 257
# -----
# binaryclassifier unshuffled
# y: (56,)
# X: (56, 1)
# Unshuffled accuracy: 0.6533333333333333
# -----
# binaryclassifier shuffled
# y: (56,)
# X: (56, 1)
# Shuffled accuracy: 0.5533333333333333
# -----
#
# Group: Early
# Animal: ER-L1
# Trials: 28
# Neuron: 36 of 257
# -----
# binaryclassifier unshuffled
# y: (56,)
# X: (56, 1)
# Unshuffled accuracy: 0.67
# -----
# binaryclassifier shuffled
# y: (56,)
# X: (56, 1)
# Shuffled accuracy: 0.6233333333333333
# -----
#
# Group: Early
# Animal: ER-L1
# Trials: 28
# Neuron: 37 of 257
# -----
# binaryclassifier unshuffled
# y: (56,)
# X: (56, 1)
# Unshuffled accuracy: 0.6966666666666667
# -----
# binaryclassifier shuffled
# y: (56,)
# X: (56, 1)
# Shuffled accuracy: 0.4766666666666667
# -----
#
# Group: Early
# Animal: ER-L1
# Trials: 28
# Neuron: 38 of 257
# -----
# binaryclassifier unshuffled
# y: (56,)
# X: (56, 1)
# Unshuffled accuracy: 0.5966666666666666
# -----
# binaryclassifier shuffled
# y: (56,)
# X: (56, 1)
# Shuffled accuracy: 0.5533333333333333
# -----
#
# Group: Early
# Animal: ER-L1
# Trials: 28
# Neuron: 39 of 257
# -----
# binaryclassifier unshuffled
# y: (56,)
# X: (56, 1)
# Unshuffled accuracy: 0.5866666666666667
# -----
# binaryclassifier shuffled
# y: (56,)
# X: (56, 1)
# Shuffled accuracy: 0.47666666666666674
# -----
#
# Group: Early
# Animal: ER-L1
# Trials: 28
# Neuron: 40 of 257
# -----
# binaryclassifier unshuffled
# y: (56,)
# X: (56, 1)
# Unshuffled accuracy: 0.6633333333333333
# -----
# binaryclassifier shuffled
# y: (56,)
# X: (56, 1)
# Shuffled accuracy: 0.6533333333333332
# -----
#
# Group: Early
# Animal: ER-L1
# Trials: 28
# Neuron: 41 of 257
# -----
# binaryclassifier unshuffled
# y: (56,)
# X: (56, 1)
# Unshuffled accuracy: 0.6633333333333333
# -----
# binaryclassifier shuffled
# y: (56,)
# X: (56, 1)
# Shuffled accuracy: 0.5633333333333334
# -----
#
# Group: Early
# Animal: ER-L1
# Trials: 28
# Neuron: 42 of 257
# -----
# binaryclassifier unshuffled
# y: (56,)
# X: (56, 1)
# Unshuffled accuracy: 0.5666666666666667
# -----
# binaryclassifier shuffled
# y: (56,)
# X: (56, 1)
# Shuffled accuracy: 0.6599999999999999
# -----
#
# Group: Early
# Animal: ER-L1
# Trials: 28
# Neuron: 43 of 257
# -----
# binaryclassifier unshuffled
# y: (56,)
# X: (56, 1)
# Unshuffled accuracy: 0.6466666666666667
# -----
# binaryclassifier shuffled
# y: (56,)
# X: (56, 1)
# Shuffled accuracy: 0.5033333333333334
# -----
#
# Group: Early
# Animal: ER-L1
# Trials: 28
# Neuron: 44 of 257
# -----
# binaryclassifier unshuffled
# y: (56,)
# X: (56, 1)
# Unshuffled accuracy: 0.5900000000000001
# -----
# binaryclassifier shuffled
# y: (56,)
# X: (56, 1)
# Shuffled accuracy: 0.69
# -----
#
# Group: Early
# Animal: ER-L1
# Trials: 28
# Neuron: 45 of 257
# -----
# binaryclassifier unshuffled
# y: (56,)
# X: (56, 1)
# Unshuffled accuracy: 0.6166666666666666
# -----
# binaryclassifier shuffled
# y: (56,)
# X: (56, 1)
# Shuffled accuracy: 0.4699999999999999
# -----
#
# Group: Early
# Animal: ER-L1
# Trials: 28
# Neuron: 46 of 257
# -----
# binaryclassifier unshuffled
# y: (56,)
# X: (56, 1)
# Unshuffled accuracy: 0.49333333333333346
# -----
# binaryclassifier shuffled
# y: (56,)
# X: (56, 1)
# Shuffled accuracy: 0.61
# -----
#
# Group: Early
# Animal: ER-L1
# Trials: 28
# Neuron: 47 of 257
# -----
# binaryclassifier unshuffled
# y: (56,)
# X: (56, 1)
# Unshuffled accuracy: 0.4333333333333333
# -----
# binaryclassifier shuffled
# y: (56,)
# X: (56, 1)
# Shuffled accuracy: 0.48666666666666664
# -----
#
# Group: Early
# Animal: ER-L1
# Trials: 28
# Neuron: 48 of 257
# -----
# binaryclassifier unshuffled
# y: (56,)
# X: (56, 1)
# Unshuffled accuracy: 0.6000000000000001
# -----
# binaryclassifier shuffled
# y: (56,)
# X: (56, 1)
# Shuffled accuracy: 0.5899999999999999
# -----
#
# Group: Early
# Animal: ER-L1
# Trials: 28
# Neuron: 49 of 257
# -----
# binaryclassifier unshuffled
# y: (56,)
# X: (56, 1)
# Unshuffled accuracy: 0.5566666666666666
# -----
# binaryclassifier shuffled
# y: (56,)
# X: (56, 1)
# Shuffled accuracy: 0.3933333333333333
# -----
#
# Group: Early
# Animal: ER-L1
# Trials: 28
# Neuron: 50 of 257
# -----
# binaryclassifier unshuffled
# y: (56,)
# X: (56, 1)
# Unshuffled accuracy: 0.5599999999999998
# -----
# binaryclassifier shuffled
# y: (56,)
# X: (56, 1)
# Shuffled accuracy: 0.6266666666666666
# -----
#
# Group: Early
# Animal: ER-L1
# Trials: 28
# Neuron: 51 of 257
# -----
# binaryclassifier unshuffled
# y: (56,)
# X: (56, 1)
# Unshuffled accuracy: 0.6233333333333333
# -----
# binaryclassifier shuffled
# y: (56,)
# X: (56, 1)
# Shuffled accuracy: 0.49333333333333335
# -----
#
# Group: Early
# Animal: ER-L1
# Trials: 28
# Neuron: 52 of 257
# -----
# binaryclassifier unshuffled
# y: (56,)
# X: (56, 1)
# Unshuffled accuracy: 0.6599999999999999
# -----
# binaryclassifier shuffled
# y: (56,)
# X: (56, 1)
# Shuffled accuracy: 0.39666666666666667
# -----
#
# Group: Early
# Animal: ER-L1
# Trials: 28
# Neuron: 53 of 257
# -----
# binaryclassifier unshuffled
# y: (56,)
# X: (56, 1)
# Unshuffled accuracy: 0.5933333333333332
# -----
# binaryclassifier shuffled
# y: (56,)
# X: (56, 1)
# Shuffled accuracy: 0.6066666666666667
# -----
#
# Group: Early
# Animal: ER-L1
# Trials: 28
# Neuron: 54 of 257
# -----
# binaryclassifier unshuffled
# y: (56,)
# X: (56, 1)
# Unshuffled accuracy: 0.41
# -----
# binaryclassifier shuffled
# y: (56,)
# X: (56, 1)
# Shuffled accuracy: 0.5866666666666667
# -----
#
# Group: Early
# Animal: ER-L1
# Trials: 28
# Neuron: 55 of 257
# -----
# binaryclassifier unshuffled
# y: (56,)
# X: (56, 1)
# Unshuffled accuracy: 0.6000000000000001
# -----
# binaryclassifier shuffled
# y: (56,)
# X: (56, 1)
# Shuffled accuracy: 0.6266666666666666
# -----
#
# Group: Early
# Animal: ER-L1
# Trials: 28
# Neuron: 56 of 257
# -----
# binaryclassifier unshuffled
# y: (56,)
# X: (56, 1)
# Unshuffled accuracy: 0.5700000000000001
# -----
# binaryclassifier shuffled
# y: (56,)
# X: (56, 1)
# Shuffled accuracy: 0.64
# -----
#
# Group: Early
# Animal: ER-L1
# Trials: 28
# Neuron: 57 of 257
# -----
# binaryclassifier unshuffled
# y: (56,)
# X: (56, 1)
# Unshuffled accuracy: 0.6533333333333332
# -----
# binaryclassifier shuffled
# y: (56,)
# X: (56, 1)
# Shuffled accuracy: 0.5299999999999999
# -----
#
# Group: Early
# Animal: ER-L1
# Trials: 28
# Neuron: 58 of 257
# -----
# binaryclassifier unshuffled
# y: (56,)
# X: (56, 1)
# Unshuffled accuracy: 0.5033333333333333
# -----
# binaryclassifier shuffled
# y: (56,)
# X: (56, 1)
# Shuffled accuracy: 0.43666666666666665
# -----
#
# Group: Early
# Animal: ER-L1
# Trials: 28
# Neuron: 59 of 257
# -----
# binaryclassifier unshuffled
# y: (56,)
# X: (56, 1)
# Unshuffled accuracy: 0.6266666666666667
# -----
# binaryclassifier shuffled
# y: (56,)
# X: (56, 1)
# Shuffled accuracy: 0.5733333333333334
# -----
#
# Group: Early
# Animal: ER-L1
# Trials: 28
# Neuron: 60 of 257
# -----
# binaryclassifier unshuffled
# y: (56,)
# X: (56, 1)
# Unshuffled accuracy: 0.4166666666666667
# -----
# binaryclassifier shuffled
# y: (56,)
# X: (56, 1)
# Shuffled accuracy: 0.5266666666666666
# -----
#
# Group: Early
# Animal: ER-L1
# Trials: 28
# Neuron: 61 of 257
# -----
# binaryclassifier unshuffled
# y: (56,)
# X: (56, 1)
# Unshuffled accuracy: 0.5366666666666666
# -----
# binaryclassifier shuffled
# y: (56,)
# X: (56, 1)
# Shuffled accuracy: 0.6566666666666667
# -----
#
# Group: Early
# Animal: ER-L1
# Trials: 28
# Neuron: 62 of 257
# -----
# binaryclassifier unshuffled
# y: (56,)
# X: (56, 1)
# Unshuffled accuracy: 0.49333333333333335
# -----
# binaryclassifier shuffled
# y: (56,)
# X: (56, 1)
# Shuffled accuracy: 0.5599999999999999
# -----
#
# Group: Early
# Animal: ER-L1
# Trials: 28
# Neuron: 63 of 257
# -----
# binaryclassifier unshuffled
# y: (56,)
# X: (56, 1)
# Unshuffled accuracy: 0.4666666666666667
# -----
# binaryclassifier shuffled
# y: (56,)
# X: (56, 1)
# Shuffled accuracy: 0.6133333333333332
# -----
#
# Group: Early
# Animal: ER-L1
# Trials: 28
# Neuron: 64 of 257
# -----
# binaryclassifier unshuffled
# y: (56,)
# X: (56, 1)
# Unshuffled accuracy: 0.64
# -----
# binaryclassifier shuffled
# y: (56,)
# X: (56, 1)
# Shuffled accuracy: 0.5033333333333333
# -----
#
# Group: Early
# Animal: ER-L1
# Trials: 28
# Neuron: 65 of 257
# -----
# binaryclassifier unshuffled
# y: (56,)
# X: (56, 1)
# Unshuffled accuracy: 0.6066666666666667
# -----
# binaryclassifier shuffled
# y: (56,)
# X: (56, 1)
# Shuffled accuracy: 0.5
# -----
#
# Group: Early
# Animal: ER-L1
# Trials: 28
# Neuron: 66 of 257
# -----
# binaryclassifier unshuffled
# y: (56,)
# X: (56, 1)
# Unshuffled accuracy: 0.6
# -----
# binaryclassifier shuffled
# y: (56,)
# X: (56, 1)
# Shuffled accuracy: 0.6066666666666667
# -----
#
# Group: Early
# Animal: ER-L1
# Trials: 28
# Neuron: 67 of 257
# -----
# binaryclassifier unshuffled
# y: (56,)
# X: (56, 1)
# Unshuffled accuracy: 0.6066666666666667
# -----
# binaryclassifier shuffled
# y: (56,)
# X: (56, 1)
# Shuffled accuracy: 0.6066666666666667
# -----
#
# Group: Early
# Animal: ER-L1
# Trials: 28
# Neuron: 68 of 257
# -----
# binaryclassifier unshuffled
# y: (56,)
# X: (56, 1)
# Unshuffled accuracy: 0.55
# -----
# binaryclassifier shuffled
# y: (56,)
# X: (56, 1)
# Shuffled accuracy: 0.47333333333333344
# -----
#
# Group: Early
# Animal: ER-L1
# Trials: 28
# Neuron: 69 of 257
# -----
# binaryclassifier unshuffled
# y: (56,)
# X: (56, 1)
# Unshuffled accuracy: 0.5100000000000001
# -----
# binaryclassifier shuffled
# y: (56,)
# X: (56, 1)
# Shuffled accuracy: 0.61
# -----
#
# Group: Early
# Animal: ER-L1
# Trials: 28
# Neuron: 70 of 257
# -----
# binaryclassifier unshuffled
# y: (56,)
# X: (56, 1)
# Unshuffled accuracy: 0.37666666666666665
# -----
# binaryclassifier shuffled
# y: (56,)
# X: (56, 1)
# Shuffled accuracy: 0.51
# -----
#
# Group: Early
# Animal: ER-L1
# Trials: 28
# Neuron: 71 of 257
# -----
# binaryclassifier unshuffled
# y: (56,)
# X: (56, 1)
# Unshuffled accuracy: 0.57
# -----
# binaryclassifier shuffled
# y: (56,)
# X: (56, 1)
# Shuffled accuracy: 0.6233333333333333
# -----
#
# Group: Early
# Animal: ER-L1
# Trials: 28
# Neuron: 72 of 257
# -----
# binaryclassifier unshuffled
# y: (56,)
# X: (56, 1)
# Unshuffled accuracy: 0.44666666666666666
# -----
# binaryclassifier shuffled
# y: (56,)
# X: (56, 1)
# Shuffled accuracy: 0.6
# -----
#
# Group: Early
# Animal: ER-L1
# Trials: 28
# Neuron: 73 of 257
# -----
# binaryclassifier unshuffled
# y: (56,)
# X: (56, 1)
# Unshuffled accuracy: 0.5433333333333334
# -----
# binaryclassifier shuffled
# y: (56,)
# X: (56, 1)
# Shuffled accuracy: 0.5833333333333333
# -----
#
# Group: Early
# Animal: ER-L1
# Trials: 28
# Neuron: 74 of 257
# -----
# binaryclassifier unshuffled
# y: (56,)
# X: (56, 1)
# Unshuffled accuracy: 0.5633333333333332
# -----
# binaryclassifier shuffled
# y: (56,)
# X: (56, 1)
# Shuffled accuracy: 0.6233333333333334
# -----
#
# Group: Early
# Animal: ER-L1
# Trials: 28
# Neuron: 75 of 257
# -----
# binaryclassifier unshuffled
# y: (56,)
# X: (56, 1)
# Unshuffled accuracy: 0.6300000000000001
# -----
# binaryclassifier shuffled
# y: (56,)
# X: (56, 1)
# ...
# X: (12, 1)
# -----
# binaryclassifier shuffled
# y: (12,)
# X: (12, 1)
# Shuffled accuracy: 0.8333333333333334
# -----
#
# Group: Middle
# Animal: PGa-T2
# Trials: 6
# Neuron: 72 of 148
# -----
# binaryclassifier unshuffled
# y: (12,)
# X: (12, 1)
# -----
# binaryclassifier shuffled
# y: (12,)
# X: (12, 1)
# Shuffled accuracy: 0.5833333333333334
# -----
#
# Group: Middle
# Animal: PGa-T2
# Trials: 6
# Neuron: 73 of 148
# -----
# binaryclassifier unshuffled
# y: (12,)
# X: (12, 1)
# -----
# binaryclassifier shuffled
# y: (12,)
# X: (12, 1)
# Shuffled accuracy: 0.4166666666666667
# -----
#
# Group: Middle
# Animal: PGa-T2
# Trials: 6
# Neuron: 74 of 148
# -----
# binaryclassifier unshuffled
# y: (12,)
# X: (12, 1)
# -----
# binaryclassifier shuffled
# y: (12,)
# X: (12, 1)
# Shuffled accuracy: 0.75
# -----
#
# Group: Middle
# Animal: PGa-T2
# Trials: 6
# Neuron: 75 of 148
# -----
# binaryclassifier unshuffled
# y: (12,)
# X: (12, 1)
# -----
# binaryclassifier shuffled
# y: (12,)
# X: (12, 1)
# Shuffled accuracy: 0.5833333333333334
# -----
#
# Group: Middle
# Animal: PGa-T2
# Trials: 6
# Neuron: 76 of 148
# -----
# binaryclassifier unshuffled
# y: (12,)
# X: (12, 1)
# -----
# binaryclassifier shuffled
# y: (12,)
# X: (12, 1)
# Shuffled accuracy: 0.6666666666666666
# -----
#
# Group: Middle
# Animal: PGa-T2
# Trials: 6
# Neuron: 77 of 148
# -----
# binaryclassifier unshuffled
# y: (12,)
# X: (12, 1)
# -----
# binaryclassifier shuffled
# y: (12,)
# X: (12, 1)
# Shuffled accuracy: 0.5833333333333334
# -----
#
# Group: Middle
# Animal: PGa-T2
# Trials: 6
# Neuron: 78 of 148
# -----
# binaryclassifier unshuffled
# y: (12,)
# X: (12, 1)
# -----
# binaryclassifier shuffled
# y: (12,)
# X: (12, 1)
# Shuffled accuracy: 0.5833333333333334
# -----
#
# Group: Middle
# Animal: PGa-T2
# Trials: 6
# Neuron: 79 of 148
# -----
# binaryclassifier unshuffled
# y: (12,)
# X: (12, 1)
# -----
# binaryclassifier shuffled
# y: (12,)
# X: (12, 1)
# Shuffled accuracy: 0.8333333333333334
# -----
#
# Group: Middle
# Animal: PGa-T2
# Trials: 6
# Neuron: 80 of 148
# -----
# binaryclassifier unshuffled
# y: (12,)
# X: (12, 1)
# -----
# binaryclassifier shuffled
# y: (12,)
# X: (12, 1)
# Shuffled accuracy: 0.75
# -----
#
# Group: Middle
# Animal: PGa-T2
# Trials: 6
# Neuron: 81 of 148
# -----
# binaryclassifier unshuffled
# y: (12,)
# X: (12, 1)
# -----
# binaryclassifier shuffled
# y: (12,)
# X: (12, 1)
# Shuffled accuracy: 0.6666666666666666
# -----
#
# Group: Middle
# Animal: PGa-T2
# Trials: 6
# Neuron: 82 of 148
# -----
# binaryclassifier unshuffled
# y: (12,)
# X: (12, 1)
# -----
# binaryclassifier shuffled
# y: (12,)
# X: (12, 1)
# Shuffled accuracy: 0.6666666666666666
# -----
#
# Group: Middle
# Animal: PGa-T2
# Trials: 6
# Neuron: 83 of 148
# -----
# binaryclassifier unshuffled
# y: (12,)
# X: (12, 1)
# -----
# binaryclassifier shuffled
# y: (12,)
# X: (12, 1)
# Shuffled accuracy: 0.5833333333333334
# -----
#
# Group: Middle
# Animal: PGa-T2
# Trials: 6
# Neuron: 84 of 148
# -----
# binaryclassifier unshuffled
# y: (12,)
# X: (12, 1)
# -----
# binaryclassifier shuffled
# y: (12,)
# X: (12, 1)
# Shuffled accuracy: 0.5
# -----
#
# Group: Middle
# Animal: PGa-T2
# Trials: 6
# Neuron: 85 of 148
# -----
# binaryclassifier unshuffled
# y: (12,)
# X: (12, 1)
# -----
# binaryclassifier shuffled
# y: (12,)
# X: (12, 1)
# Shuffled accuracy: 0.5833333333333334
# -----
#
# Group: Middle
# Animal: PGa-T2
# Trials: 6
# Neuron: 86 of 148
# -----
# binaryclassifier unshuffled
# y: (12,)
# X: (12, 1)
# -----
# binaryclassifier shuffled
# y: (12,)
# X: (12, 1)
# Shuffled accuracy: 0.75
# -----
#
# Group: Middle
# Animal: PGa-T2
# Trials: 6
# Neuron: 87 of 148
# -----
# binaryclassifier unshuffled
# y: (12,)
# X: (12, 1)
# -----
# binaryclassifier shuffled
# y: (12,)
# X: (12, 1)
# Shuffled accuracy: 0.5833333333333334
# -----
#
# Group: Middle
# Animal: PGa-T2
# Trials: 6
# Neuron: 88 of 148
# -----
# binaryclassifier unshuffled
# y: (12,)
# X: (12, 1)
# -----
# binaryclassifier shuffled
# y: (12,)
# X: (12, 1)
# Shuffled accuracy: 0.8333333333333334
# -----
#
# Group: Middle
# Animal: PGa-T2
# Trials: 6
# Neuron: 89 of 148
# -----
# binaryclassifier unshuffled
# y: (12,)
# X: (12, 1)
# -----
# binaryclassifier shuffled
# y: (12,)
# X: (12, 1)
# Shuffled accuracy: 0.5833333333333334
# -----
#
# Group: Middle
# Animal: PGa-T2
# Trials: 6
# Neuron: 90 of 148
# -----
# binaryclassifier unshuffled
# y: (12,)
# X: (12, 1)
# -----
# binaryclassifier shuffled
# y: (12,)
# X: (12, 1)
# Shuffled accuracy: 0.5833333333333334
# -----
#
# Group: Middle
# Animal: PGa-T2
# Trials: 6
# Neuron: 91 of 148
# -----
# binaryclassifier unshuffled
# y: (12,)
# X: (12, 1)
# -----
# binaryclassifier shuffled
# y: (12,)
# X: (12, 1)
# Shuffled accuracy: 0.6666666666666666
# -----
#
# Group: Middle
# Animal: PGa-T2
# Trials: 6
# Neuron: 92 of 148
# -----
# binaryclassifier unshuffled
# y: (12,)
# X: (12, 1)
# -----
# binaryclassifier shuffled
# y: (12,)
# X: (12, 1)
# Shuffled accuracy: 0.75
# -----
#
# Group: Middle
# Animal: PGa-T2
# Trials: 6
# Neuron: 93 of 148
# -----
# binaryclassifier unshuffled
# y: (12,)
# X: (12, 1)
# -----
# binaryclassifier shuffled
# y: (12,)
# X: (12, 1)
# Shuffled accuracy: 0.6666666666666666
# -----
#
# Group: Middle
# Animal: PGa-T2
# Trials: 6
# Neuron: 94 of 148
# -----
# binaryclassifier unshuffled
# y: (12,)
# X: (12, 1)
# -----
# binaryclassifier shuffled
# y: (12,)
# X: (12, 1)
# Shuffled accuracy: 0.5
# -----
#
# Group: Middle
# Animal: PGa-T2
# Trials: 6
# Neuron: 95 of 148
# -----
# binaryclassifier unshuffled
# y: (12,)
# X: (12, 1)
# -----
# binaryclassifier shuffled
# y: (12,)
# X: (12, 1)
# Shuffled accuracy: 0.9166666666666666
# -----
#
# Group: Middle
# Animal: PGa-T2
# Trials: 6
# Neuron: 96 of 148
# -----
# binaryclassifier unshuffled
# y: (12,)
# X: (12, 1)
# -----
# binaryclassifier shuffled
# y: (12,)
# X: (12, 1)
# Shuffled accuracy: 0.8333333333333334
# -----
#
# Group: Middle
# Animal: PGa-T2
# Trials: 6
# Neuron: 97 of 148
# -----
# binaryclassifier unshuffled
# y: (12,)
# X: (12, 1)
# -----
# binaryclassifier shuffled
# y: (12,)
# X: (12, 1)
# Shuffled accuracy: 0.75
# -----
#
# Group: Middle
# Animal: PGa-T2
# Trials: 6
# Neuron: 98 of 148
# -----
# binaryclassifier unshuffled
# y: (12,)
# X: (12, 1)
# -----
# binaryclassifier shuffled
# y: (12,)
# X: (12, 1)
# Shuffled accuracy: 0.75
# -----
#
# Group: Middle
# Animal: PGa-T2
# Trials: 6
# Neuron: 99 of 148
# -----
# binaryclassifier unshuffled
# y: (12,)
# X: (12, 1)
# -----
# binaryclassifier shuffled
# y: (12,)
# X: (12, 1)
# Shuffled accuracy: 0.6666666666666666
# -----
#
# Group: Middle
# Animal: PGa-T2
# Trials: 6
# Neuron: 100 of 148
# -----
# binaryclassifier unshuffled
# y: (12,)
# X: (12, 1)
# -----
# binaryclassifier shuffled
# y: (12,)
# X: (12, 1)
# Shuffled accuracy: 0.6666666666666666
# -----
#
# Group: Middle
# Animal: PGa-T2
# Trials: 6
# Neuron: 101 of 148
# -----
# binaryclassifier unshuffled
# y: (12,)
# X: (12, 1)
# -----
# binaryclassifier shuffled
# y: (12,)
# X: (12, 1)
# Shuffled accuracy: 0.6666666666666666
# -----
#
# Group: Middle
# Animal: PGa-T2
# Trials: 6
# Neuron: 102 of 148
# -----
# binaryclassifier unshuffled
# y: (12,)
# X: (12, 1)
# -----
# binaryclassifier shuffled
# y: (12,)
# X: (12, 1)
# Shuffled accuracy: 0.5833333333333334
# -----
#
# Group: Middle
# Animal: PGa-T2
# Trials: 6
# Neuron: 103 of 148
# -----
# binaryclassifier unshuffled
# y: (12,)
# X: (12, 1)
# -----
# binaryclassifier shuffled
# y: (12,)
# X: (12, 1)
# Shuffled accuracy: 0.75
# -----
#
# Group: Middle
# Animal: PGa-T2
# Trials: 6
# Neuron: 104 of 148
# -----
# binaryclassifier unshuffled
# y: (12,)
# X: (12, 1)
# -----
# binaryclassifier shuffled
# y: (12,)
# X: (12, 1)
# Shuffled accuracy: 0.75
# -----
#
# Group: Middle
# Animal: PGa-T2
# Trials: 6
# Neuron: 105 of 148
# -----
# binaryclassifier unshuffled
# y: (12,)
# X: (12, 1)
# -----
# binaryclassifier shuffled
# y: (12,)
# X: (12, 1)
# Shuffled accuracy: 0.8333333333333334
# -----
#
# Group: Middle
# Animal: PGa-T2
# Trials: 6
# Neuron: 106 of 148
# -----
# binaryclassifier unshuffled
# y: (12,)
# X: (12, 1)
# -----
# binaryclassifier shuffled
# y: (12,)
# X: (12, 1)
# Shuffled accuracy: 0.8333333333333334
# -----
#
# Group: Middle
# Animal: PGa-T2
# Trials: 6
# Neuron: 107 of 148
# -----
# binaryclassifier unshuffled
# y: (12,)
# X: (12, 1)
# -----
# binaryclassifier shuffled
# y: (12,)
# X: (12, 1)
# Shuffled accuracy: 0.4166666666666667
# -----
#
# Group: Middle
# Animal: PGa-T2
# Trials: 6
# Neuron: 108 of 148
# -----
# binaryclassifier unshuffled
# y: (12,)
# X: (12, 1)
# -----
# binaryclassifier shuffled
# y: (12,)
# X: (12, 1)
# Shuffled accuracy: 0.6666666666666666
# -----
#
# Group: Middle
# Animal: PGa-T2
# Trials: 6
# Neuron: 109 of 148
# -----
# binaryclassifier unshuffled
# y: (12,)
# X: (12, 1)
# -----
# binaryclassifier shuffled
# y: (12,)
# X: (12, 1)
# Shuffled accuracy: 0.75
# -----
#
# Group: Middle
# Animal: PGa-T2
# Trials: 6
# Neuron: 110 of 148
# -----
# binaryclassifier unshuffled
# y: (12,)
# X: (12, 1)
# -----
# binaryclassifier shuffled
# y: (12,)
# X: (12, 1)
# Shuffled accuracy: 0.6666666666666666
# -----
#
# Group: Middle
# Animal: PGa-T2
# Trials: 6
# Neuron: 111 of 148
# -----
# binaryclassifier unshuffled
# y: (12,)
# X: (12, 1)
# -----
# binaryclassifier shuffled
# y: (12,)
# X: (12, 1)
# Shuffled accuracy: 0.75
# -----
#
# Group: Middle
# Animal: PGa-T2
# Trials: 6
# Neuron: 112 of 148
# -----
# binaryclassifier unshuffled
# y: (12,)
# X: (12, 1)
# -----
# binaryclassifier shuffled
# y: (12,)
# X: (12, 1)
# Shuffled accuracy: 0.6666666666666666
# -----
#
# Group: Middle
# Animal: PGa-T2
# Trials: 6
# Neuron: 113 of 148
# -----
# binaryclassifier unshuffled
# y: (12,)
# X: (12, 1)
# -----
# binaryclassifier shuffled
# y: (12,)
# X: (12, 1)
# Shuffled accuracy: 0.5833333333333334
# -----
#
# Group: Middle
# Animal: PGa-T2
# Trials: 6
# Neuron: 114 of 148
# -----
# binaryclassifier unshuffled
# y: (12,)
# X: (12, 1)
# -----
# binaryclassifier shuffled
# y: (12,)
# X: (12, 1)
# Shuffled accuracy: 0.5833333333333334
# -----
#
# Group: Middle
# Animal: PGa-T2
# Trials: 6
# Neuron: 115 of 148
# -----
# binaryclassifier unshuffled
# y: (12,)
# X: (12, 1)
# -----
# binaryclassifier shuffled
# y: (12,)
# X: (12, 1)
# Shuffled accuracy: 0.5
# -----
#
# Group: Middle
# Animal: PGa-T2
# Trials: 6
# Neuron: 116 of 148
# -----
# binaryclassifier unshuffled
# y: (12,)
# X: (12, 1)
# -----
# binaryclassifier shuffled
# y: (12,)
# X: (12, 1)
# Shuffled accuracy: 0.5833333333333334
# -----
#
# Group: Middle
# Animal: PGa-T2
# Trials: 6
# Neuron: 117 of 148
# -----
# binaryclassifier unshuffled
# y: (12,)
# X: (12, 1)
# -----
# binaryclassifier shuffled
# y: (12,)
# X: (12, 1)
# Shuffled accuracy: 0.5833333333333334
# -----
#
# Group: Middle
# Animal: PGa-T2
# Trials: 6
# Neuron: 118 of 148
# -----
# binaryclassifier unshuffled
# y: (12,)
# X: (12, 1)
# -----
# binaryclassifier shuffled
# y: (12,)
# X: (12, 1)
# Shuffled accuracy: 0.5833333333333334
# -----
#
# Group: Middle
# Animal: PGa-T2
# Trials: 6
# Neuron: 119 of 148
# -----
# binaryclassifier unshuffled
# y: (12,)
# X: (12, 1)
# -----
# binaryclassifier shuffled
# y: (12,)
# X: (12, 1)
# Shuffled accuracy: 0.6666666666666666
# -----
#
# Group: Middle
# Animal: PGa-T2
# Trials: 6
# Neuron: 120 of 148
# -----
# binaryclassifier unshuffled
# y: (12,)
# X: (12, 1)
# -----
# binaryclassifier shuffled
# y: (12,)
# X: (12, 1)
# Shuffled accuracy: 0.3333333333333333
# -----
#
# Group: Middle
# Animal: PGa-T2
# Trials: 6
# Neuron: 121 of 148
# -----
# binaryclassifier unshuffled
# y: (12,)
# X: (12, 1)
# -----
# binaryclassifier shuffled
# y: (12,)
# X: (12, 1)
# Shuffled accuracy: 0.6666666666666666
# -----
#
# Group: Middle
# Animal: PGa-T2
# Trials: 6
# Neuron: 122 of 148
# -----
# binaryclassifier unshuffled
# y: (12,)
# X: (12, 1)
# -----
# binaryclassifier shuffled
# y: (12,)
# X: (12, 1)
# Shuffled accuracy: 0.75
# -----
#
# Group: Middle
# Animal: PGa-T2
# Trials: 6
# Neuron: 123 of 148
# -----
# binaryclassifier unshuffled
# y: (12,)
# X: (12, 1)
# -----
# binaryclassifier shuffled
# y: (12,)
# X: (12, 1)
# Shuffled accuracy: 0.3333333333333333
# -----
#
# Group: Middle
# Animal: PGa-T2
# Trials: 6
# Neuron: 124 of 148
# -----
# binaryclassifier unshuffled
# y: (12,)
# X: (12, 1)
# -----
# binaryclassifier shuffled
# y: (12,)
# X: (12, 1)
# Shuffled accuracy: 0.75
# -----
#
# Group: Middle
# Animal: PGa-T2
# Trials: 6
# Neuron: 125 of 148
# -----
# binaryclassifier unshuffled
# y: (12,)
# X: (12, 1)
# -----
# binaryclassifier shuffled
# y: (12,)
# X: (12, 1)
# Shuffled accuracy: 0.75
# -----
#
# Group: Middle
# Animal: PGa-T2
# Trials: 6
# Neuron: 126 of 148
# -----
# binaryclassifier unshuffled
# y: (12,)
# X: (12, 1)
# -----
# binaryclassifier shuffled
# y: (12,)
# X: (12, 1)
# Shuffled accuracy: 0.5833333333333334
# -----
#
# Group: Middle
# Animal: PGa-T2
# Trials: 6
# Neuron: 127 of 148
# -----
# binaryclassifier unshuffled
# y: (12,)
# X: (12, 1)
# -----
# binaryclassifier shuffled
# y: (12,)
# X: (12, 1)
# Shuffled accuracy: 0.6666666666666666
# -----
#
# Group: Middle
# Animal: PGa-T2
# Trials: 6
# Neuron: 128 of 148
# -----
# binaryclassifier unshuffled
# y: (12,)
# X: (12, 1)
# -----
# binaryclassifier shuffled
# y: (12,)
# X: (12, 1)
# Shuffled accuracy: 0.8333333333333334
# -----
#
# Group: Middle
# Animal: PGa-T2
# Trials: 6
# Neuron: 129 of 148
# -----
# binaryclassifier unshuffled
# y: (12,)
# X: (12, 1)
# -----
# binaryclassifier shuffled
# y: (12,)
# X: (12, 1)
# Shuffled accuracy: 0.9166666666666666
# -----
#
# Group: Middle
# Animal: PGa-T2
# Trials: 6
# Neuron: 130 of 148
# -----
# binaryclassifier unshuffled
# y: (12,)
# X: (12, 1)
# -----
# binaryclassifier shuffled
# y: (12,)
# X: (12, 1)
# Shuffled accuracy: 0.9166666666666666
# -----
#
# Group: Middle
# Animal: PGa-T2
# Trials: 6
# Neuron: 131 of 148
# -----
# binaryclassifier unshuffled
# y: (12,)
# X: (12, 1)
# -----
# binaryclassifier shuffled
# y: (12,)
# X: (12, 1)
# Shuffled accuracy: 0.75
# -----
#
# Group: Middle
# Animal: PGa-T2
# Trials: 6
# Neuron: 132 of 148
# -----
# binaryclassifier unshuffled
# y: (12,)
# X: (12, 1)
# -----
# binaryclassifier shuffled
# y: (12,)
# X: (12, 1)
# Shuffled accuracy: 0.75
# -----
#
# Group: Middle
# Animal: PGa-T2
# Trials: 6
# Neuron: 133 of 148
# -----
# binaryclassifier unshuffled
# y: (12,)
# X: (12, 1)
# -----
# binaryclassifier shuffled
# y: (12,)
# X: (12, 1)
# Shuffled accuracy: 0.6666666666666666
# -----
#
# Group: Middle
# Animal: PGa-T2
# Trials: 6
# Neuron: 134 of 148
# -----
# binaryclassifier unshuffled
# y: (12,)
# X: (12, 1)
# -----
# binaryclassifier shuffled
# y: (12,)
# X: (12, 1)
# Shuffled accuracy: 0.6666666666666666
# -----
#
# Group: Middle
# Animal: PGa-T2
# Trials: 6
# Neuron: 135 of 148
# -----
# binaryclassifier unshuffled
# y: (12,)
# X: (12, 1)
# -----
# binaryclassifier shuffled
# y: (12,)
# X: (12, 1)
# Shuffled accuracy: 0.6666666666666666
# -----
#
# Group: Middle
# Animal: PGa-T2
# Trials: 6
# Neuron: 136 of 148
# -----
# binaryclassifier unshuffled
# y: (12,)
# X: (12, 1)
# -----
# binaryclassifier shuffled
# y: (12,)
# X: (12, 1)
# Shuffled accuracy: 0.3333333333333333
# -----
#
# Group: Middle
# Animal: PGa-T2
# Trials: 6
# Neuron: 137 of 148
# -----
# binaryclassifier unshuffled
# y: (12,)
# X: (12, 1)
# -----
# binaryclassifier shuffled
# y: (12,)
# X: (12, 1)
# Shuffled accuracy: 0.5833333333333334
# -----
#
# Group: Middle
# Animal: PGa-T2
# Trials: 6
# Neuron: 138 of 148
# -----
# binaryclassifier unshuffled
# y: (12,)
# X: (12, 1)
# -----
# binaryclassifier shuffled
# y: (12,)
# X: (12, 1)
# Shuffled accuracy: 0.5833333333333334
# -----
#
# Group: Middle
# Animal: PGa-T2
# Trials: 6
# Neuron: 139 of 148
# -----
# binaryclassifier unshuffled
# y: (12,)
# X: (12, 1)
# -----
# binaryclassifier shuffled
# y: (12,)
# X: (12, 1)
# Shuffled accuracy: 0.75
# -----
#
# Group: Middle
# Animal: PGa-T2
# Trials: 6
# Neuron: 140 of 148
# -----
# binaryclassifier unshuffled
# y: (12,)
# X: (12, 1)
# -----
# binaryclassifier shuffled
# y: (12,)
# X: (12, 1)
# Shuffled accuracy: 0.9166666666666666
# -----
#
# Group: Middle
# Animal: PGa-T2
# Trials: 6
# Neuron: 141 of 148
# -----
# binaryclassifier unshuffled
# y: (12,)
# X: (12, 1)
# -----
# binaryclassifier shuffled
# y: (12,)
# X: (12, 1)
# Shuffled accuracy: 0.5
# -----
#
# Group: Middle
# Animal: PGa-T2
# Trials: 6
# Neuron: 142 of 148
# -----
# binaryclassifier unshuffled
# y: (12,)
# X: (12, 1)
# -----
# binaryclassifier shuffled
# y: (12,)
# X: (12, 1)
# Shuffled accuracy: 0.5
# -----
#
# Group: Middle
# Animal: PGa-T2
# Trials: 6
# Neuron: 143 of 148
# -----
# binaryclassifier unshuffled
# y: (12,)
# X: (12, 1)
# -----
# binaryclassifier shuffled
# y: (12,)
# X: (12, 1)
# Shuffled accuracy: 0.5
# -----
#
# Group: Middle
# Animal: PGa-T2
# Trials: 6
# Neuron: 144 of 148
# -----
# binaryclassifier unshuffled
# y: (12,)
# X: (12, 1)
# -----
# binaryclassifier shuffled
# y: (12,)
# X: (12, 1)
# Shuffled accuracy: 0.5833333333333334
# -----
#
# Group: Middle
# Animal: PGa-T2
# Trials: 6
# Neuron: 145 of 148
# -----
# binaryclassifier unshuffled
# y: (12,)
# X: (12, 1)
# -----
# binaryclassifier shuffled
# y: (12,)
# X: (12, 1)
# Shuffled accuracy: 0.6666666666666666
# -----
#
# Group: Middle
# Animal: PGa-T2
# Trials: 6
# Neuron: 146 of 148
# -----
# binaryclassifier unshuffled
# y: (12,)
# X: (12, 1)
# -----
# binaryclassifier shuffled
# y: (12,)
# X: (12, 1)
# Shuffled accuracy: 0.6666666666666666
# -----
#
# Group: Middle
# Animal: PGa-T2
# Trials: 6
# Neuron: 147 of 148
# -----
# binaryclassifier unshuffled
# y: (12,)
# X: (12, 1)
# -----
# binaryclassifier shuffled
# y: (12,)
# X: (12, 1)
# Shuffled accuracy: 0.6666666666666666
# -----
#
# END: Middle
#
# ========== FINISHED ==========

# %%
###THIS SECTION IS TO SAVE DECODING DATA AS NUMPY ARRAYS
variable_to_save = 'ActivePress-All'
decoding_dict_results_dir = os.path.join(results,'decoding','dictionaries')
groups = ['Early','Middle', 'Late'] ###INSERT YOUR GROUPS (E.G., EARLY AND LATE LEARNING)

for g, group in enumerate (groups):
    unshuffled = np.array(list(dict.items(classification_accuracy[group]['individualneurons']['unshuffled'])))
    shuffled = np.array(list(dict.items(classification_accuracy[group]['individualneurons']['shuffled'])))
    if unshuffled.shape[0] > 0:
        print(unshuffled.shape)
        print(shuffled.shape)
        stacked = np.vstack((unshuffled[:,1], shuffled[:,1]))
    np.save(os.path.join(decoding_dict_results_dir,'PFC-HeroinSA_%s_%s_Decoding-dict.npy'%(group,variable_to_save,decoding[0])),stacked)
# Out:
# (1401, 2)
# (1401, 2)
# (637, 2)
# (637, 2)
# C:\Users\jboqu\AppData\Local\Temp\ipykernel_8340\4066295191.py:18: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   shuffled = np.array(list(dict.items(classification_accuracy[group]['individualneurons']['shuffled'])))

# %%
#show what's in each file
for i in os.listdir(decoding_dict_results_dir):
    print(i)
    infile = np.load(os.path.join(decoding_dict_results_dir, i), allow_pickle=True)
    print(infile.shape)
# Out:
# PFC-HeroinSA_Early_ActivePress-All_Neuron_Decoding-dict.npy
# (2, 1401)
# PFC-HeroinSA_Middle_ActivePress-All_Neuron_Decoding-dict.npy
# (2, 637)

# %%
### DECODING CDF PLOTS FOR EARLY, MIDDLE, AND LATE DATA
analyze_by = 'Neuron' ###Session or Neuron
variables_to_analyze = ['ActivePress-All']
groups = ['Early', 'Middle'] 
color = (['k'],['tab:red'], ['tab:green'],['tab:blue'])
ls = ['--','solid']
decode_results_dir = r'C:\Users\jboqu\Dropbox\2P Imaging Projects\Beth\Josh\Repositories\PFC_Self-Admin_Analysis\PFC_Self-Admin_Analysis\active-inactive_analysis\extinction\results\decoding'

d = {}
###THIS SECTION IS FOR LOADING AND PLOTTING SAVED POPULATION DECODING ARRAYS (BY NEURON OR SESSION)
for v, variable in enumerate (variables_to_analyze):
    d[variable] = {}
    all_shuffle_for_variable=[]
    fig, ax = plt.subplots(1, 2, figsize = (16,4))
    for g, group in enumerate(groups):
        d[variable][group] = {}
        d[variable][group] = np.array(np.load(os.path.join(decoding_dict_results_dir,
                                                           'PFC-HeroinSA_%s_%s_%s_Decoding-dict.npy'%(group,variable,analyze_by)), 
                                                           allow_pickle = True).astype(float))
        temp_unshuffle_nonans, temp_shuffle_nonans = ([],[])
        temp_unshuffle,temp_shuffle = (d[variable][group][0],d[variable][group][1])

        for i in range(len(temp_unshuffle)):
            if np.isfinite(temp_unshuffle[i]):
                temp_unshuffle_nonans = np.append(temp_unshuffle_nonans, temp_unshuffle[i])
        for i in range(len(temp_shuffle)):
            if np.isfinite(temp_shuffle[i]):
                temp_shuffle_nonans = np.append(temp_shuffle_nonans, temp_shuffle[i])
                
       ##NORMALIZING
        mean_shuffle = np.mean(temp_shuffle_nonans)
        temp_unshuffle_nonans = temp_unshuffle_nonans - mean_shuffle
        temp_shuffle_nonans = temp_shuffle_nonans - mean_shuffle

        plt.hist((temp_unshuffle_nonans),  density=True, cumulative=True,\
            label = ['%s-Unshuffle'%(group)], histtype='step',\
            linestyle = ('-'), bins = 'auto', color = color[g], linewidth=2)

        all_shuffle_for_variable = np.append(all_shuffle_for_variable, d[variable][group][1])
        if g == len(groups)-1:
            plt.hist((temp_shuffle_nonans),  density=True, cumulative=True,\
                label = ['Shuffle','%sUnhuffle'%(group)], histtype='step',\
                linestyle = ('--'), bins ='auto', color = 'k', alpha=.7, linewidth=2)
                
        ax[0].text(.2,1-g*.5,'%s-Shuffle: Mean = '%(group) + '{0:.3g}'.format(np.mean(temp_shuffle_nonans)) + \
            ', SEM = ' + '{0:.3g}'.format(stats.sem(temp_shuffle_nonans)) + ', N = ' + '{0:.3g}'.format(len(temp_shuffle_nonans)))
        ax[0].text(.2, .9-g*.5,'%s-Unhuffle: Mean = '%(group) + '{0:.3g}'.format(np.mean(temp_unshuffle_nonans)) + \
            ', SEM = ' + '{0:.3g}'.format(stats.sem(temp_unshuffle_nonans)) + ', N = ' + '{0:.3g}'.format(len(temp_unshuffle_nonans)))
        t, p = stats.ttest_ind(temp_shuffle_nonans,\
            temp_unshuffle_nonans, equal_var=False)
        ax[0].text(.2, .8-g*.5, '%s T-test: t = '%(group) + '{0:.3g}'.format(t) + ', p = ' + '{0:.3g}'.format(p))

    ax[0].get_xaxis().set_visible(False)
    ax[0].get_yaxis().set_visible(False)
    ax[0].spines['top'].set_visible(False)
    ax[0].spines['right'].set_visible(False)
    ax[0].spines['left'].set_visible(False)
    ax[0].spines['bottom'].set_visible(False)

    plt.legend(loc=2)
    plt.title('%s-level analysis | Population: %s | Decoding: %s'%(analyze_by, population, variable))
    
    plt.savefig(os.path.join(decode_results_dir, 'PFC-HeroinSA_%s_%s_%s_Decoding.PDF'%(population, variable, analyze_by)), format = 'PDF')

    plt.show()

# %% [markdown]
# ### Decoding: Cluster, ActivePress-all

# %%
numclusters = 4 ###SET TO NUMBER OF CLUSTERS FOR DATASET
uniquelabels = np.arange(numclusters)

### DECODING CDF PLOTS FOR EARLY, MIDDLE, AND LATE DATA
analyze_by = 'Neuron' ###Session or Neuron
variables_to_analyze = ['ActivePress-All']
groups = ['Early', 'Middle'] 
dir_list = [earlybasedir, middlebasedir]
color = (['k'],['tab:red'], ['tab:green'],['tab:blue'], ['tab:yellow'])
ls = ['--','solid']
bins = np.arange(0.4,0.8,0.01)  

for index in range(len(groups)):
    group = groups[index]
    newlabels = np.load((os.path.join(dir_list[index], 'cluster_list_per_session_Extinction.npy')))
    dict_file = np.load(os.path.join(decoding_dict_results_dir, 'PFC-HeroinSA_%s_ActivePress-All_Neuron_Decoding-dict.npy'%(group)),allow_pickle = True).astype(float)
    for variable in variables_to_analyze:
        print('Group:', group)
        d = {}
        d[variable]={}
        all_shuffle_for_variable = []
        fig, ax = plt.subplots(1, 2, figsize = (16,4))
        for cluster in range(numclusters):
            d[variable][cluster] = {}
            file_max = len(dict_file[1])
            fit = np.array(newlabels[:file_max])
            temp_array = np.squeeze(dict_file[:,np.where(fit==cluster)[0]])
            d[variable][cluster] = temp_array
            all_shuffle_for_variable = np.append(all_shuffle_for_variable, d[variable][cluster])

            plt.hist((d[variable][cluster][0]), density=True, cumulative=True,\
                                label = ['Cluster %s'%(cluster+1)], histtype='step', linestyle = '-',\
                                bins = bins, linewidth=2)
            plt.text(-0.15, (1.1-cluster*.16), 
                    ('Ensemble '+str(cluster+1)+' (shuffled) -> ' +
                    'Mean: ' + '%.3g'%(np.nanmean((d[variable][cluster][1]))) +
                    ', SEM: ' + '%.3g'%(stats.sem(d[variable][cluster][1]))) +
                    ', N: ' + str(len(d[variable][cluster][1])))
            plt.text(-0.15, 1.03-cluster*.16, 
                    ('Ensemble '+str(cluster+1)+' (unshuffled) -> ' +
                    'Mean: ' + '%.3g'%(np.nanmean((d[variable][cluster][0]))) +
                    ', SEM: ' + '%.3g'%(stats.sem(d[variable][cluster][0]))) +
                    ', N: ' + str(len(d[variable][cluster][0])))
            #t, p = stats.ttest_ind(temp_shuffle_nonans, temp_unshuffle_nonans, equal_var=False)
            #ax[0].text(.2, .8-g*.5, '%s T-test: t = '%(group) + '{0:.3g}'.format(t) + ', p = ' + '{0:.3g}'.format(p))
            if cluster == len(uniquelabels)-1:
                plt.hist((all_shuffle_for_variable), density=True, cumulative=True,\
                    label = ['Shuffled'], histtype='step', linestyle = '--',\
                    bins = bins, linewidth=2, color = 'k', alpha = .8)
                plt.text(-0.15, .8-cluster*.16, 
                    ('All shuffled stats -> ' +
                    'Mean: ' + '%.3g'%(np.nanmean(all_shuffle_for_variable)) +
                    ', SEM: ' + '%.3g'%(stats.sem(all_shuffle_for_variable))) +
                    ', N: ' + str(len(all_shuffle_for_variable)))

            ax[0].get_xaxis().set_visible(False)
            ax[0].get_yaxis().set_visible(False)
            ax[0].spines['top'].set_visible(False)
            ax[0].spines['right'].set_visible(False)
            ax[0].spines['left'].set_visible(False)
            ax[0].spines['bottom'].set_visible(False)

            plt.legend(loc=2)
            plt.title('%s-level Cluster analysis | Population: %s | Decoding: %s'%(analyze_by, population, variable))
        plt.savefig(os.path.join(decode_results_dir, 'PFC-HeroinSA_%s_%s_%s_%s_Cluster_Decoding.PDF'%(population, group, variable, analyze_by)), format = 'PDF')
        plt.show()
# Out:
# Group: Early
# Group: Middle
