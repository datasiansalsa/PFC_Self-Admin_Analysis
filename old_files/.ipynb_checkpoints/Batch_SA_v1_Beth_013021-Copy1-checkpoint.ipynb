# %%
###IMPORT NECESSARY MODULES FOR BELOW CODE
import numpy as np
import os
import scipy.io as sio
import matplotlib.pyplot as plt
from matplotlib.patches import Patch
# %matplotlib inline

# %%
###THESE FUNCTIONS ARE USED IN THE BELOW CODE

###THIS FUNCTION ALLOWS US TO LOAD MATLAB BEHAVIORAL FILES INTO PYTHON
def find_matfiles(indir):
    tempfiles = next(os.walk(indir))[2]
    matfiles = [f for f in tempfiles if os.path.splitext(f)[1]=='.mat']
    matfiles = sorted(matfiles)
    return matfiles

###TAKES DATA OUT OF 'EVENTLOG_TEMP' THAT IS BEYOND SESSION LENGTH, SAVES AS 'EVENTLOG'
def find_session_length(data):    
    sessionlength = (max(data[:,1]))
    session_length_in_minutes = round((sessionlength/1000/60), 2)
    return session_length_in_minutes

###EXTRACT PRESSING DATA FROM EACH EVENTLOG
def extract_presses(eventlog):
    ###FINDS ACTIVE LEVER DATA AND CONVERTS TO MINUTES
    x = (eventlog[eventlog[:,0]==22,1])/(1000*60) ###not during timeout
    y = (eventlog[eventlog[:,0]==222,1])/(1000*60) ###during timeout
    z = np.concatenate((x,y))
    ###FINDS INACTIVE LEVER DATA AND CONVERTS TO MINUTES
    q = (eventlog[eventlog[:,0]==21,1])/(1000*60) ###not during timeout
    r = eventlog[eventlog[:,0]==212,1]/(1000*60) ###during timeout
    s = np.concatenate((q,r))
    return x, y, z, q, r, s

###EXTRACT INFUSION DATA FROM EACH EVENTLOG
def extract_infusions(eventlog):
    ###FINDS TOTAL NUMBER OF INFUSIONS
    a =(eventlog[eventlog[:,0]==4,1])/(1000*60)
    #infusions = (eventlog[eventlog[:,0]]==4,1)
    #total_infusions = sum(infusions)
    return a

###EXTRACT MOUSE IDS FROM MATLAB FILENAMES
def extract_id(files):
    for i in range(len(files)): 
        if files[i].isnumeric():
            if files[i+1].isnumeric():
                if files[i+1].isnumeric():
                    mouse_id = files[i:i+2]
                    break
                else:
                    mouse_id = files[i]
                    break
    return mouse_id

# %%
###EDIT THIS SECTION

###WHAT FOLDER HOUSES THE EXPERIMENT OF INTEREST?
# basedir = r"/Users/elizabethdoncheck/Dropbox/Operant Data/
basedir = r"C:\Users\OtisLab\Dropbox\Operant Data"

batchfolder = "2022_03_25" ###'experiment' will be used as filename for saved figures. Can be whatever you want

# %%
matfiles = find_matfiles(os.path.join(basedir, batchfolder))

###THIS SECTION LOADS EACH MATLABFILE AS 'EVENTLOG_TEMP'
for m, matfile in enumerate(matfiles):
    behaviordata = sio.loadmat(os.path.join(basedir,batchfolder, matfile))
    eventlog = np.squeeze(behaviordata['eventlog'])

    ###CUTS DATA TO SESSION LENGTH IN CASE SESSION WENT OVER TIME USING A FUNCTION DEFINED ABOVE
    session_length_in_minutes = find_session_length(eventlog)

    ###EXTRACTS LEVER PRESS DATA USING A FUNCTION DEFINED ABOVE
    activelever, activelevertimeout, allactivepresses, inactivelever, \
        inactivelevertimeout, allinactivepresses = extract_presses(eventlog)
    
    ###EXTRACTS INFUSION DATA USING A FUNCTION DEFINED ABOVE
    infusions = extract_infusions(eventlog)


    print (matfile)
    print ('MINIMUM Session Length = %s minutes'%session_length_in_minutes)
    print ('Active Lever = %s, Active Lever Timeout = %s, Inactive Lever = %s, Inactive Lever Timeout = %s'\
           %(len(activelever), len(activelevertimeout), len(inactivelever), len(inactivelevertimeout)))
    print ('TOTAL ACTIVE = %s, TOTAL INACTIVE = %s, TOTAL INFUSIONS = %s\n'%(len(allactivepresses), len(allinactivepresses), len(infusions)))
# Out:
# LCDD48_HER_RST-CUE_cue-stopped-working_0_6000_220325-140803.mat
# MINIMUM Session Length = 42.0 minutes
# Active Lever = 0, Active Lever Timeout = 0, Inactive Lever = 0, Inactive Lever Timeout = 0
# TOTAL ACTIVE = 0, TOTAL INACTIVE = 0, TOTAL INFUSIONS = 0
#
# LCDD48_HER_WASH-D4_0_6000_220325-152507.mat
# MINIMUM Session Length = 74.0 minutes
# Active Lever = 0, Active Lever Timeout = 0, Inactive Lever = 0, Inactive Lever Timeout = 0
# TOTAL ACTIVE = 0, TOTAL INACTIVE = 0, TOTAL INFUSIONS = 0
#
# PFC-Gi14_HER_LOW-D9_0_6000_220325-144400.mat
# MINIMUM Session Length = 22.0 minutes
# Active Lever = 42, Active Lever Timeout = 279, Inactive Lever = 0, Inactive Lever Timeout = 0
# TOTAL ACTIVE = 321, TOTAL INACTIVE = 0, TOTAL INFUSIONS = 42
#
# PFC-Gi15_HER_LOW-D8_0_6000_220325-153608.mat
# MINIMUM Session Length = 120.0 minutes
# Active Lever = 44, Active Lever Timeout = 113, Inactive Lever = 40, Inactive Lever Timeout = 4
# TOTAL ACTIVE = 157, TOTAL INACTIVE = 44, TOTAL INFUSIONS = 44
#
# PFC-Gi17_HER_LOW-D9_0_6000_220325-141536.mat
# MINIMUM Session Length = 23.0 minutes
# Active Lever = 44, Active Lever Timeout = 369, Inactive Lever = 0, Inactive Lever Timeout = 0
# TOTAL ACTIVE = 413, TOTAL INACTIVE = 0, TOTAL INFUSIONS = 44
#
# PFC-Gi18_HER_LOW-D9_0_6000_220325-142253.mat
# MINIMUM Session Length = 33.0 minutes
# Active Lever = 54, Active Lever Timeout = 521, Inactive Lever = 0, Inactive Lever Timeout = 0
# TOTAL ACTIVE = 575, TOTAL INACTIVE = 0, TOTAL INFUSIONS = 53
#
# PFC-eYFPC11_HER_WASH-D1_0_6000_220325-160120.mat
# MINIMUM Session Length = 120.0 minutes
# Active Lever = 2, Active Lever Timeout = 0, Inactive Lever = 1, Inactive Lever Timeout = 0
# TOTAL ACTIVE = 2, TOTAL INACTIVE = 1, TOTAL INFUSIONS = 0
#
# PFC-eYFPC12_HER_LOW-D9_0_6000_220325-140405.mat
# MINIMUM Session Length = 19.0 minutes
# Active Lever = 40, Active Lever Timeout = 140, Inactive Lever = 0, Inactive Lever Timeout = 0
# TOTAL ACTIVE = 180, TOTAL INACTIVE = 0, TOTAL INFUSIONS = 40
#
# PFC-eYFPC13_HER_LOW-D9_0_6000_220325-140412.mat
# MINIMUM Session Length = 24.0 minutes
# Active Lever = 40, Active Lever Timeout = 208, Inactive Lever = 0, Inactive Lever Timeout = 2
# TOTAL ACTIVE = 248, TOTAL INACTIVE = 2, TOTAL INFUSIONS = 40
#
# PFC-eYFPC15_HER_LOW-D9_0_6000_220325-160041.mat
# MINIMUM Session Length = 133.0 minutes
# Active Lever = 27, Active Lever Timeout = 43, Inactive Lever = 3, Inactive Lever Timeout = 5
# TOTAL ACTIVE = 70, TOTAL INACTIVE = 8, TOTAL INFUSIONS = 27
#
# PFC-eYFPC15_HER_LOW-D9_PT2_0_6000_220325-161048.mat
# MINIMUM Session Length = 9.0 minutes
# Active Lever = 3, Active Lever Timeout = 5, Inactive Lever = 3, Inactive Lever Timeout = 5
# TOTAL ACTIVE = 8, TOTAL INACTIVE = 8, TOTAL INFUSIONS = 3
#
# PNAC-E1_ALC_SA_D13_0_6000_220325-091922.mat
# MINIMUM Session Length = 60.0 minutes
# Active Lever = 79, Active Lever Timeout = 211, Inactive Lever = 0, Inactive Lever Timeout = 0
# TOTAL ACTIVE = 290, TOTAL INACTIVE = 0, TOTAL INFUSIONS = 79
#
# PNAC-E2_ALC_SA_D13_0_6000_220325-102448.mat
# MINIMUM Session Length = 61.0 minutes
# Active Lever = 94, Active Lever Timeout = 377, Inactive Lever = 0, Inactive Lever Timeout = 0
# TOTAL ACTIVE = 471, TOTAL INACTIVE = 0, TOTAL INFUSIONS = 94
#
# PNAC-E3_ALC_SA_D13_0_6000_220325-104637.mat
# MINIMUM Session Length = 61.0 minutes
# Active Lever = 42, Active Lever Timeout = 146, Inactive Lever = 7, Inactive Lever Timeout = 76
# TOTAL ACTIVE = 188, TOTAL INACTIVE = 83, TOTAL INFUSIONS = 42
#
# PNAC-E5_ALC_SA_D13_0_6000_220325-112510.mat
# MINIMUM Session Length = 59.0 minutes
# Active Lever = 29, Active Lever Timeout = 52, Inactive Lever = 52, Inactive Lever Timeout = 25
# TOTAL ACTIVE = 81, TOTAL INACTIVE = 77, TOTAL INFUSIONS = 29
#
# PNAC-E6_ALC_SA_D_0_6000_220325-110417.mat
# MINIMUM Session Length = 48.0 minutes
# Active Lever = 95, Active Lever Timeout = 576, Inactive Lever = 0, Inactive Lever Timeout = 0
# TOTAL ACTIVE = 671, TOTAL INACTIVE = 0, TOTAL INFUSIONS = 95
#
# PNAC-KW10_ALC_SA_D13_0_6000_220325-114944.mat
# MINIMUM Session Length = 59.0 minutes
# Active Lever = 26, Active Lever Timeout = 67, Inactive Lever = 5, Inactive Lever Timeout = 33
# TOTAL ACTIVE = 93, TOTAL INACTIVE = 38, TOTAL INFUSIONS = 26
#
# PNAC-KW9_ALC_SA_TMT_OPTO_0_6000_220325-105005.mat
# MINIMUM Session Length = 61.0 minutes
# Active Lever = 25, Active Lever Timeout = 74, Inactive Lever = 0, Inactive Lever Timeout = 1
# TOTAL ACTIVE = 99, TOTAL INACTIVE = 1, TOTAL INFUSIONS = 25
#
# PNAC-MORs10_SUC_SA_WASH_0_6000_220325-104149.mat
# MINIMUM Session Length = 45.0 minutes
# Active Lever = 21, Active Lever Timeout = 30, Inactive Lever = 28, Inactive Lever Timeout = 9
# TOTAL ACTIVE = 51, TOTAL INACTIVE = 37, TOTAL INFUSIONS = 21
#
# PNAC-MORs11_SUC_SA_OPTO_DAMGO_0_6000_220325-111403.mat
# MINIMUM Session Length = 44.0 minutes
# Active Lever = 34, Active Lever Timeout = 158, Inactive Lever = 0, Inactive Lever Timeout = 0
# TOTAL ACTIVE = 192, TOTAL INACTIVE = 0, TOTAL INFUSIONS = 34
#
# PNAC-MORs1_SUC_SA_WASH_0_6000_220325-084913.mat
# MINIMUM Session Length = 47.0 minutes
# Active Lever = 27, Active Lever Timeout = 31, Inactive Lever = 0, Inactive Lever Timeout = 0
# TOTAL ACTIVE = 58, TOTAL INACTIVE = 0, TOTAL INFUSIONS = 27
#
# PNAC-MORs2_SUC_SA_WASH_0_6000_220325-085120.mat
# MINIMUM Session Length = 45.0 minutes
# Active Lever = 89, Active Lever Timeout = 226, Inactive Lever = 0, Inactive Lever Timeout = 7
# TOTAL ACTIVE = 315, TOTAL INACTIVE = 7, TOTAL INFUSIONS = 89
#
# PNAC-MORs3_SUC_SA_WASH_0_6000_220325-085501.mat
# MINIMUM Session Length = 46.0 minutes
# Active Lever = 14, Active Lever Timeout = 24, Inactive Lever = 7, Inactive Lever Timeout = 6
# TOTAL ACTIVE = 38, TOTAL INACTIVE = 13, TOTAL INFUSIONS = 14
#
# PNAC-MORs4_SUC_SA_WASH_0_6000_220325-085659.mat
# MINIMUM Session Length = 45.0 minutes
# Active Lever = 62, Active Lever Timeout = 143, Inactive Lever = 0, Inactive Lever Timeout = 0
# TOTAL ACTIVE = 205, TOTAL INACTIVE = 0, TOTAL INFUSIONS = 62
#
# PNAC-MORs5_SUC_SA_OPTO_DAMGO_0_6000_220325-100226.mat
# MINIMUM Session Length = 45.0 minutes
# Active Lever = 99, Active Lever Timeout = 602, Inactive Lever = 7, Inactive Lever Timeout = 49
# TOTAL ACTIVE = 701, TOTAL INACTIVE = 56, TOTAL INFUSIONS = 99
#
# PNAC-MORs6_SUC_SA_OPTO_DAMGO_0_6000_220325-132951.mat
# MINIMUM Session Length = 0.0 minutes
# Active Lever = 1, Active Lever Timeout = 0, Inactive Lever = 0, Inactive Lever Timeout = 0
# TOTAL ACTIVE = 1, TOTAL INACTIVE = 0, TOTAL INFUSIONS = 1
#
# PNAC-MORs6_SUC_SA_OPTO_DAMGO_0_6000_220325-141542.mat
# MINIMUM Session Length = 45.0 minutes
# Active Lever = 89, Active Lever Timeout = 786, Inactive Lever = 0, Inactive Lever Timeout = 4
# TOTAL ACTIVE = 875, TOTAL INACTIVE = 4, TOTAL INFUSIONS = 89
#
# PNAC-MORs6_SUC_SA_WASH_0_6000_220325-094857.mat
# MINIMUM Session Length = 52.0 minutes
# Active Lever = 36, Active Lever Timeout = 57, Inactive Lever = 23, Inactive Lever Timeout = 53
# TOTAL ACTIVE = 93, TOTAL INACTIVE = 76, TOTAL INFUSIONS = 36
#
# PNAC-MORs7_SUC_SA_OPTO_DAMGO_0_6000_220325-090647.mat
# MINIMUM Session Length = 0.0 minutes
# Active Lever = 1, Active Lever Timeout = 0, Inactive Lever = 0, Inactive Lever Timeout = 0
# TOTAL ACTIVE = 1, TOTAL INACTIVE = 0, TOTAL INFUSIONS = 1
#
# PNAC-MORs7_SUC_SA_OPTO_DAMGO_0_6000_220325-091011.mat
# MINIMUM Session Length = 3.0 minutes
# Active Lever = 3, Active Lever Timeout = 4, Inactive Lever = 0, Inactive Lever Timeout = 0
# TOTAL ACTIVE = 7, TOTAL INACTIVE = 0, TOTAL INFUSIONS = 3
#
# PNAC-MORs7_SUC_SA_OPTO_DAMGO_PT2_0_6000_220325-095202.mat
# MINIMUM Session Length = 41.0 minutes
# Active Lever = 9, Active Lever Timeout = 9, Inactive Lever = 0, Inactive Lever Timeout = 0
# TOTAL ACTIVE = 18, TOTAL INACTIVE = 0, TOTAL INFUSIONS = 9
#
# PNAC-MORs8_SUC_SA_OPTO_DAMGO_0_6000_220325-112627.mat
# MINIMUM Session Length = 44.0 minutes
# Active Lever = 74, Active Lever Timeout = 379, Inactive Lever = 0, Inactive Lever Timeout = 0
# TOTAL ACTIVE = 453, TOTAL INACTIVE = 0, TOTAL INFUSIONS = 74
#
# PNAC-MORs9_SUC_SA_WASH_0_6000_220325-095912.mat
# MINIMUM Session Length = 44.0 minutes
# Active Lever = 64, Active Lever Timeout = 191, Inactive Lever = 0, Inactive Lever Timeout = 0
# TOTAL ACTIVE = 255, TOTAL INACTIVE = 0, TOTAL INFUSIONS = 64
#
# PNAC-OPTO-CAN17_HER_EXT_WASH_0_6000_220325-100016.mat
# MINIMUM Session Length = 120.0 minutes
# Active Lever = 8, Active Lever Timeout = 0, Inactive Lever = 0, Inactive Lever Timeout = 0
# TOTAL ACTIVE = 8, TOTAL INACTIVE = 0, TOTAL INFUSIONS = 0
#
# PNAC-OPTO-CAN18_HER_RST_OPTO_CNO_0_6000_220325-130231.mat
# MINIMUM Session Length = 120.0 minutes
# Active Lever = 202, Active Lever Timeout = 0, Inactive Lever = 8, Inactive Lever Timeout = 0
# TOTAL ACTIVE = 202, TOTAL INACTIVE = 8, TOTAL INFUSIONS = 0
# PNAC-OPTO-CAN19_HER_EXT_WASH_0_6000_220325-100317.mat
# MINIMUM Session Length = 120.0 minutes
# Active Lever = 3, Active Lever Timeout = 0, Inactive Lever = 2, Inactive Lever Timeout = 0
# TOTAL ACTIVE = 3, TOTAL INACTIVE = 2, TOTAL INFUSIONS = 0
#
# PNAC-OPTO-CAN20_ALC_SA_TMT_OPTO_0_6000_220325-070735.mat
# MINIMUM Session Length = 0.0 minutes
# Active Lever = 0, Active Lever Timeout = 0, Inactive Lever = 0, Inactive Lever Timeout = 0
# TOTAL ACTIVE = 0, TOTAL INACTIVE = 0, TOTAL INFUSIONS = 0
#
# PNAC-OPTO-CAN20_ALC_SA_TMT_OPTO_0_6000_220325-094119.mat
# MINIMUM Session Length = 60.0 minutes
# Active Lever = 4, Active Lever Timeout = 1, Inactive Lever = 7, Inactive Lever Timeout = 2
# TOTAL ACTIVE = 5, TOTAL INACTIVE = 9, TOTAL INFUSIONS = 4
#
# PNAC-OPTO-CAN21_ALC_SA_TMT_OPTO_0_6000_220325-093920.mat
# MINIMUM Session Length = 62.0 minutes
# Active Lever = 17, Active Lever Timeout = 58, Inactive Lever = 0, Inactive Lever Timeout = 0
# TOTAL ACTIVE = 75, TOTAL INACTIVE = 0, TOTAL INFUSIONS = 17
#
# PNAC-OPTO26_ALC_SA_D_0_6000_220325-113326.mat
# MINIMUM Session Length = 58.0 minutes
# Active Lever = 30, Active Lever Timeout = 51, Inactive Lever = 0, Inactive Lever Timeout = 0
# TOTAL ACTIVE = 81, TOTAL INACTIVE = 0, TOTAL INFUSIONS = 30
#
# PNAC_E4_ALC_SA_D13_0_6000_220325-110735.mat
# MINIMUM Session Length = 59.0 minutes
# Active Lever = 56, Active Lever Timeout = 171, Inactive Lever = 0, Inactive Lever Timeout = 0
# TOTAL ACTIVE = 227, TOTAL INACTIVE = 0, TOTAL INFUSIONS = 56
#
# PrL-NAc-5M-HALO_HER_LOW-D3_0_6000_220325-171401.mat
# MINIMUM Session Length = 21.0 minutes
# Active Lever = 47, Active Lever Timeout = 328, Inactive Lever = 0, Inactive Lever Timeout = 7
# TOTAL ACTIVE = 375, TOTAL INACTIVE = 7, TOTAL INFUSIONS = 47
#
# PrL-NAc-HALO-1M_HER_EXT-D15_0_6000_220325-154953.mat
# MINIMUM Session Length = 60.0 minutes
# Active Lever = 160, Active Lever Timeout = 0, Inactive Lever = 0, Inactive Lever Timeout = 0
# TOTAL ACTIVE = 160, TOTAL INACTIVE = 0, TOTAL INFUSIONS = 0
#
# PrL-NAc-HALO-2F-CUE-RST_LASER_OFF_0_6000_220325-165711.mat
# MINIMUM Session Length = 60.0 minutes
# Active Lever = 13, Active Lever Timeout = 15, Inactive Lever = 0, Inactive Lever Timeout = 0
# TOTAL ACTIVE = 28, TOTAL INACTIVE = 0, TOTAL INFUSIONS = 13
#
# PrL-NAc-HALO-3F_HER_EXT-D15_0_6000_220325-150408.mat
# MINIMUM Session Length = 1.0 minutes
# Active Lever = 0, Active Lever Timeout = 0, Inactive Lever = 0, Inactive Lever Timeout = 0
# TOTAL ACTIVE = 0, TOTAL INACTIVE = 0, TOTAL INFUSIONS = 0
#
# PrL-NAc-HALO-3F_HER_EXT-D15_0_6000_220325-160926.mat
# MINIMUM Session Length = 60.0 minutes
# Active Lever = 14, Active Lever Timeout = 0, Inactive Lever = 0, Inactive Lever Timeout = 0
# TOTAL ACTIVE = 14, TOTAL INACTIVE = 0, TOTAL INFUSIONS = 0
#
# PrL-NAc-HALO-4F_LOW-D10_0_6000_220325-162118.mat
# MINIMUM Session Length = 0.0 minutes
# Active Lever = 1, Active Lever Timeout = 0, Inactive Lever = 0, Inactive Lever Timeout = 0
# TOTAL ACTIVE = 1, TOTAL INACTIVE = 0, TOTAL INFUSIONS = 0
#
# PrL-NAc-HALO-4F_LOW-D10_0_6000_220325-172141.mat
# MINIMUM Session Length = 59.0 minutes
# Active Lever = 17, Active Lever Timeout = 25, Inactive Lever = 0, Inactive Lever Timeout = 0
# TOTAL ACTIVE = 42, TOTAL INACTIVE = 0, TOTAL INFUSIONS = 17
#
# PrL-NAc-HALO-4M_HER_LOW-D4_0_6000_220325-173802.mat
# MINIMUM Session Length = 55.0 minutes
# Active Lever = 40, Active Lever Timeout = 132, Inactive Lever = 6, Inactive Lever Timeout = 16
# TOTAL ACTIVE = 172, TOTAL INACTIVE = 22, TOTAL INFUSIONS = 40
#
# PrL-NAc-HALO-5F_HER-LOW-D5_0_6000_220325-153545.mat
# MINIMUM Session Length = 1.0 minutes
# Active Lever = 3, Active Lever Timeout = 0, Inactive Lever = 0, Inactive Lever Timeout = 0
# TOTAL ACTIVE = 3, TOTAL INACTIVE = 0, TOTAL INFUSIONS = 0
#
# PrL-NAc-HALO-5M_HER-LOW-D3_0_6000_220325-161753.mat
# MINIMUM Session Length = 41.0 minutes
# Active Lever = 24, Active Lever Timeout = 98, Inactive Lever = 527, Inactive Lever Timeout = 118
# TOTAL ACTIVE = 122, TOTAL INACTIVE = 645, TOTAL INFUSIONS = 24
#
# PrL-NAc-HALO-5M_HER-LOW-D3_0_6000_220325-163120_PT2.mat
# MINIMUM Session Length = 11.0 minutes
# Active Lever = 16, Active Lever Timeout = 35, Inactive Lever = 5, Inactive Lever Timeout = 18
# TOTAL ACTIVE = 51, TOTAL INACTIVE = 23, TOTAL INFUSIONS = 16
#
# PrL-NAc-YFP-1F_HER_EXT-D15_0_6000_220325-160700.mat
# MINIMUM Session Length = 60.0 minutes
# Active Lever = 87, Active Lever Timeout = 0, Inactive Lever = 0, Inactive Lever Timeout = 0
# TOTAL ACTIVE = 87, TOTAL INACTIVE = 0, TOTAL INFUSIONS = 0
#
# PrL-NAc-YFP-1M_HER_WASH-D2_0_6000_220325-145727.mat
# MINIMUM Session Length = 60.0 minutes
# Active Lever = 26, Active Lever Timeout = 0, Inactive Lever = 0, Inactive Lever Timeout = 0
# TOTAL ACTIVE = 26, TOTAL INACTIVE = 0, TOTAL INFUSIONS = 0
#
# PrL-NAc-YFP-3M_HER_WASH-D1_0_6000_220325-145141.mat
# MINIMUM Session Length = 60.0 minutes
# Active Lever = 1, Active Lever Timeout = 0, Inactive Lever = 0, Inactive Lever Timeout = 0
# TOTAL ACTIVE = 1, TOTAL INACTIVE = 0, TOTAL INFUSIONS = 0
#
# PrL-NAc-YFP-4M_HER_LOW-D5_0_6000_220325-173755.mat
# MINIMUM Session Length = 29.0 minutes
# Active Lever = 42, Active Lever Timeout = 192, Inactive Lever = 0, Inactive Lever Timeout = 0
# TOTAL ACTIVE = 234, TOTAL INACTIVE = 0, TOTAL INFUSIONS = 42
#
# PrL-NAc-YFP-6M_HER-LOW-D4_0_6000_220325-130000.mat
# MINIMUM Session Length = 60.0 minutes
# Active Lever = 15, Active Lever Timeout = 8, Inactive Lever = 0, Inactive Lever Timeout = 0
# TOTAL ACTIVE = 23, TOTAL INACTIVE = 0, TOTAL INFUSIONS = 15
#
# PrL-NAc-YFP-6M_HER_LOW-D5_0_6000_220325-175041.mat
# MINIMUM Session Length = 0.0 minutes
# Active Lever = 1, Active Lever Timeout = 6, Inactive Lever = 0, Inactive Lever Timeout = 0
# TOTAL ACTIVE = 7, TOTAL INACTIVE = 0, TOTAL INFUSIONS = 1
#
# PrL-NAc-YFP-6M_HER_LOW-D5_0_6000_220325-180919.mat
# MINIMUM Session Length = 17.0 minutes
# Active Lever = 40, Active Lever Timeout = 279, Inactive Lever = 0, Inactive Lever Timeout = 0
# TOTAL ACTIVE = 319, TOTAL INACTIVE = 0, TOTAL INFUSIONS = 40
